# %% [markdown]
# ![BCC](https://bccfilkom.net/static/assets/images/BCC-Logo.svg)

# %% [markdown]
# #### <p style="background-color:#25316D;font-family:newtimeroman;color:#FEF5AC;font-size:150%;text-align:center;border-radius:10px 10px;">Diamond Price Recommendation</p>

# %%
import warnings
warnings.filterwarnings('ignore')

# Basic Library
import warnings
import os
import numpy as np
import pandas as pd
import statistics
import math
from timeit import default_timer as timer

# Preprocessing Library
#!pip install missingno
#import missingno as msno
from sklearn import metrics
from sklearn import preprocessing
from sklearn.preprocessing import LabelEncoder
from sklearn.preprocessing import OrdinalEncoder
from sklearn.preprocessing import MinMaxScaler

# Visualization Library
import matplotlib.pyplot as plt
import seaborn as sns
from scipy import stats
# !pip install ipywidgets
#import matplotlib.pylab as pylab

# Dimentionality Reduction & Normalization Library
#from sklearn.preprocessing import normalize
#from sklearn.preprocessing import MinMaxScaler
#from sklearn.decomposition import PCA
from sklearn.preprocessing import StandardScaler

# Machine Learning Library
from sklearn.model_selection import train_test_split
from sklearn.pipeline import Pipeline
from sklearn.linear_model import LinearRegression
# !pip install catboost
from catboost import CatBoostRegressor
# !pip install xgboost
from xgboost import XGBRegressor
import xgboost as xgb
from sklearn.model_selection import GridSearchCV
import pickle

# Model Evaluation Library
from sklearn.model_selection import cross_val_score
from sklearn.metrics import mean_squared_error
from sklearn.metrics import r2_score
#from sklearn.metrics import classification_report, confusion_matrix, accuracy_score
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Requirement already satisfied: ipywidgets in /usr/local/lib/python3.9/dist-packages (7.7.1)
# Requirement already satisfied: widgetsnbextension~=3.6.0 in /usr/local/lib/python3.9/dist-packages (from ipywidgets) (3.6.2)
# Requirement already satisfied: jupyterlab-widgets>=1.0.0 in /usr/local/lib/python3.9/dist-packages (from ipywidgets) (3.0.5)
# Requirement already satisfied: ipykernel>=4.5.1 in /usr/local/lib/python3.9/dist-packages (from ipywidgets) (5.3.4)
# Requirement already satisfied: traitlets>=4.3.1 in /usr/local/lib/python3.9/dist-packages (from ipywidgets) (5.7.1)
# Requirement already satisfied: ipython>=4.0.0 in /usr/local/lib/python3.9/dist-packages (from ipywidgets) (7.9.0)
# Requirement already satisfied: ipython-genutils~=0.2.0 in /usr/local/lib/python3.9/dist-packages (from ipywidgets) (0.2.0)
# Requirement already satisfied: jupyter-client in /usr/local/lib/python3.9/dist-packages (from ipykernel>=4.5.1->ipywidgets) (6.1.12)
# Requirement already satisfied: tornado>=4.2 in /usr/local/lib/python3.9/dist-packages (from ipykernel>=4.5.1->ipywidgets) (6.2)
# Requirement already satisfied: pickleshare in /usr/local/lib/python3.9/dist-packages (from ipython>=4.0.0->ipywidgets) (0.7.5)
# Requirement already satisfied: pygments in /usr/local/lib/python3.9/dist-packages (from ipython>=4.0.0->ipywidgets) (2.6.1)
# Requirement already satisfied: pexpect in /usr/local/lib/python3.9/dist-packages (from ipython>=4.0.0->ipywidgets) (4.8.0)
# Requirement already satisfied: prompt-toolkit<2.1.0,>=2.0.0 in /usr/local/lib/python3.9/dist-packages (from ipython>=4.0.0->ipywidgets) (2.0.10)
# Requirement already satisfied: decorator in /usr/local/lib/python3.9/dist-packages (from ipython>=4.0.0->ipywidgets) (4.4.2)
# Requirement already satisfied: backcall in /usr/local/lib/python3.9/dist-packages (from ipython>=4.0.0->ipywidgets) (0.2.0)
# Collecting jedi>=0.10
#   Downloading jedi-0.18.2-py2.py3-none-any.whl (1.6 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.6/1.6 MB 14.9 MB/s eta 0:00:00
# Requirement already satisfied: setuptools>=18.5 in /usr/local/lib/python3.9/dist-packages (from ipython>=4.0.0->ipywidgets) (63.4.3)
# Requirement already satisfied: notebook>=4.4.1 in /usr/local/lib/python3.9/dist-packages (from widgetsnbextension~=3.6.0->ipywidgets) (6.3.0)
# Requirement already satisfied: parso<0.9.0,>=0.8.0 in /usr/local/lib/python3.9/dist-packages (from jedi>=0.10->ipython>=4.0.0->ipywidgets) (0.8.3)
# Requirement already satisfied: Send2Trash>=1.5.0 in /usr/local/lib/python3.9/dist-packages (from notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets) (1.8.0)
# Requirement already satisfied: prometheus-client in /usr/local/lib/python3.9/dist-packages (from notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets) (0.16.0)
# Requirement already satisfied: nbformat in /usr/local/lib/python3.9/dist-packages (from notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets) (5.7.3)
# Requirement already satisfied: terminado>=0.8.3 in /usr/local/lib/python3.9/dist-packages (from notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets) (0.17.1)
# Requirement already satisfied: pyzmq>=17 in /usr/local/lib/python3.9/dist-packages (from notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets) (23.2.1)
# Requirement already satisfied: argon2-cffi in /usr/local/lib/python3.9/dist-packages (from notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets) (21.3.0)
# Requirement already satisfied: jupyter-core>=4.6.1 in /usr/local/lib/python3.9/dist-packages (from notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets) (5.2.0)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.9/dist-packages (from notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets) (3.1.2)
# Requirement already satisfied: nbconvert in /usr/local/lib/python3.9/dist-packages (from notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets) (6.5.4)
# Requirement already satisfied: python-dateutil>=2.1 in /usr/local/lib/python3.9/dist-packages (from jupyter-client->ipykernel>=4.5.1->ipywidgets) (2.8.2)
# Requirement already satisfied: wcwidth in /usr/local/lib/python3.9/dist-packages (from prompt-toolkit<2.1.0,>=2.0.0->ipython>=4.0.0->ipywidgets) (0.2.6)
# Requirement already satisfied: six>=1.9.0 in /usr/local/lib/python3.9/dist-packages (from prompt-toolkit<2.1.0,>=2.0.0->ipython>=4.0.0->ipywidgets) (1.15.0)
# Requirement already satisfied: ptyprocess>=0.5 in /usr/local/lib/python3.9/dist-packages (from pexpect->ipython>=4.0.0->ipywidgets) (0.7.0)
# Requirement already satisfied: platformdirs>=2.5 in /usr/local/lib/python3.9/dist-packages (from jupyter-core>=4.6.1->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets) (3.1.1)
# Requirement already satisfied: argon2-cffi-bindings in /usr/local/lib/python3.9/dist-packages (from argon2-cffi->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets) (21.2.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.9/dist-packages (from jinja2->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets) (2.1.2)
# Requirement already satisfied: tinycss2 in /usr/local/lib/python3.9/dist-packages (from nbconvert->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets) (1.2.1)
# Requirement already satisfied: nbclient>=0.5.0 in /usr/local/lib/python3.9/dist-packages (from nbconvert->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets) (0.7.2)
# Requirement already satisfied: lxml in /usr/local/lib/python3.9/dist-packages (from nbconvert->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets) (4.9.2)
# Requirement already satisfied: beautifulsoup4 in /usr/local/lib/python3.9/dist-packages (from nbconvert->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets) (4.9.3)
# Requirement already satisfied: defusedxml in /usr/local/lib/python3.9/dist-packages (from nbconvert->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets) (0.7.1)
# Requirement already satisfied: mistune<2,>=0.8.1 in /usr/local/lib/python3.9/dist-packages (from nbconvert->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets) (0.8.4)
# Requirement already satisfied: packaging in /usr/local/lib/python3.9/dist-packages (from nbconvert->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets) (23.0)
# Requirement already satisfied: pandocfilters>=1.4.1 in /usr/local/lib/python3.9/dist-packages (from nbconvert->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets) (1.5.0)
# Requirement already satisfied: bleach in /usr/local/lib/python3.9/dist-packages (from nbconvert->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets) (6.0.0)
# Requirement already satisfied: entrypoints>=0.2.2 in /usr/local/lib/python3.9/dist-packages (from nbconvert->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets) (0.4)
# Requirement already satisfied: jupyterlab-pygments in /usr/local/lib/python3.9/dist-packages (from nbconvert->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets) (0.2.2)
# Requirement already satisfied: fastjsonschema in /usr/local/lib/python3.9/dist-packages (from nbformat->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets) (2.16.3)
# Requirement already satisfied: jsonschema>=2.6 in /usr/local/lib/python3.9/dist-packages (from nbformat->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets) (4.3.3)
# Requirement already satisfied: pyrsistent!=0.17.0,!=0.17.1,!=0.17.2,>=0.14.0 in /usr/local/lib/python3.9/dist-packages (from jsonschema>=2.6->nbformat->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets) (0.19.3)
# Requirement already satisfied: attrs>=17.4.0 in /usr/local/lib/python3.9/dist-packages (from jsonschema>=2.6->nbformat->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets) (22.2.0)
# Requirement already satisfied: cffi>=1.0.1 in /usr/local/lib/python3.9/dist-packages (from argon2-cffi-bindings->argon2-cffi->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets) (1.15.1)
# Requirement already satisfied: soupsieve>1.2 in /usr/local/lib/python3.9/dist-packages (from beautifulsoup4->nbconvert->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets) (2.4)
# Requirement already satisfied: webencodings in /usr/local/lib/python3.9/dist-packages (from bleach->nbconvert->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets) (0.5.1)
# Requirement already satisfied: pycparser in /usr/local/lib/python3.9/dist-packages (from cffi>=1.0.1->argon2-cffi-bindings->argon2-cffi->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets) (2.21)
# Installing collected packages: jedi
# Successfully installed jedi-0.18.2
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting catboost
#   Downloading catboost-1.1.1-cp39-none-manylinux1_x86_64.whl (76.6 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 76.6/76.6 MB 9.8 MB/s eta 0:00:00
# Requirement already satisfied: six in /usr/local/lib/python3.9/dist-packages (from catboost) (1.15.0)
# Requirement already satisfied: plotly in /usr/local/lib/python3.9/dist-packages (from catboost) (5.5.0)
# Requirement already satisfied: numpy>=1.16.0 in /usr/local/lib/python3.9/dist-packages (from catboost) (1.22.4)
# Requirement already satisfied: graphviz in /usr/local/lib/python3.9/dist-packages (from catboost) (0.10.1)
# Requirement already satisfied: matplotlib in /usr/local/lib/python3.9/dist-packages (from catboost) (3.7.1)
# Requirement already satisfied: scipy in /usr/local/lib/python3.9/dist-packages (from catboost) (1.10.1)
# Requirement already satisfied: pandas>=0.24.0 in /usr/local/lib/python3.9/dist-packages (from catboost) (1.4.4)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.9/dist-packages (from pandas>=0.24.0->catboost) (2022.7.1)
# Requirement already satisfied: python-dateutil>=2.8.1 in /usr/local/lib/python3.9/dist-packages (from pandas>=0.24.0->catboost) (2.8.2)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.9/dist-packages (from matplotlib->catboost) (23.0)
# Requirement already satisfied: kiwisolver>=1.0.1 in /usr/local/lib/python3.9/dist-packages (from matplotlib->catboost) (1.4.4)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.9/dist-packages (from matplotlib->catboost) (1.0.7)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.9/dist-packages (from matplotlib->catboost) (0.11.0)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.9/dist-packages (from matplotlib->catboost) (4.39.0)
# Requirement already satisfied: importlib-resources>=3.2.0 in /usr/local/lib/python3.9/dist-packages (from matplotlib->catboost) (5.12.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.9/dist-packages (from matplotlib->catboost) (3.0.9)
# Requirement already satisfied: pillow>=6.2.0 in /usr/local/lib/python3.9/dist-packages (from matplotlib->catboost) (8.4.0)
# Requirement already satisfied: tenacity>=6.2.0 in /usr/local/lib/python3.9/dist-packages (from plotly->catboost) (8.2.2)
# Requirement already satisfied: zipp>=3.1.0 in /usr/local/lib/python3.9/dist-packages (from importlib-resources>=3.2.0->matplotlib->catboost) (3.15.0)
# Installing collected packages: catboost
# Successfully installed catboost-1.1.1
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Requirement already satisfied: xgboost in /usr/local/lib/python3.9/dist-packages (1.7.4)
# Requirement already satisfied: scipy in /usr/local/lib/python3.9/dist-packages (from xgboost) (1.10.1)
# Requirement already satisfied: numpy in /usr/local/lib/python3.9/dist-packages (from xgboost) (1.22.4)

# %%
#data = _deepnote_execute_sql("""SELECT *
#FROM 'Diamonds Prices2022.csv'
#""", 'SQL_DEEPNOTE_DATAFRAME_SQL')
#data

# %%
from google.colab import drive
drive.mount('/content/drive')
data = pd.read_csv('/content/drive/My Drive/Colab Notebooks/Diamonds Prices2022.csv')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
#data = pd.read_csv('Diamonds Prices2022.csv')

# %% [markdown]
# # <p style="background-color:#25316D;font-family:newtimeroman;color:#FEF5AC;font-size:80%;text-align:center;border-radius:10px 10px;"> DATA PROFILING </p>

# %%
data.shape
# Out:
# (53943, 11)

# %%
data.head()
# Out:
#    Unnamed: 0  carat      cut color clarity  depth  table  price     x     y  \
# 0           1   0.23    Ideal     E     SI2   61.5   55.0    326  3.95  3.98
# 1           2   0.21  Premium     E     SI1   59.8   61.0    326  3.89  3.84
# 2           3   0.23     Good     E     VS1   56.9   65.0    327  4.05  4.07
# 3           4   0.29  Premium     I     VS2   62.4   58.0    334  4.20  4.23
# 4           5   0.31     Good     J     SI2   63.3   58.0    335  4.34  4.35
#
#       z
# 0  2.43
# 1  2.31
# 2  2.31
# 3  2.63
# 4  2.75

# %%
data.describe()
# Out:
#          Unnamed: 0         carat         depth         table         price  \
# count  53943.000000  53943.000000  53943.000000  53943.000000  53943.000000
# mean   26972.000000      0.797935     61.749322     57.457251   3932.734294
# std    15572.147122      0.473999      1.432626      2.234549   3989.338447
# min        1.000000      0.200000     43.000000     43.000000    326.000000
# 25%    13486.500000      0.400000     61.000000     56.000000    950.000000
# 50%    26972.000000      0.700000     61.800000     57.000000   2401.000000
# 75%    40457.500000      1.040000     62.500000     59.000000   5324.000000
# max    53943.000000      5.010000     79.000000     95.000000  18823.000000
#
#                   x             y             z
# count  53943.000000  53943.000000  53943.000000
# mean       5.731158      5.734526      3.538730
# std        1.121730      1.142103      0.705679
# min        0.000000      0.000000      0.000000
# 25%        4.710000      4.720000      2.910000
# 50%        5.700000      5.710000      3.530000
# 75%        6.540000      6.540000      4.040000
# max       10.740000     58.900000     31.800000

# %%
data.describe(include=['O'])
# Out:
#           cut  color clarity
# count   53943  53943   53943
# unique      5      7       8
# top     Ideal      G     SI1
# freq    21551  11292   13067

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 53943 entries, 0 to 53942
# Data columns (total 11 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Unnamed: 0  53943 non-null  int64
#  1   carat       53943 non-null  float64
#  2   cut         53943 non-null  object
#  3   color       53943 non-null  object
#  4   clarity     53943 non-null  object
#  5   depth       53943 non-null  float64
#  6   table       53943 non-null  float64
#  7   price       53943 non-null  int64
#  8   x           53943 non-null  float64
#  9   y           53943 non-null  float64
#  10  z           53943 non-null  float64
# dtypes: float64(6), int64(2), object(3)
# memory usage: 4.5+ MB

# %%
data.nunique()
# Out:
# Unnamed: 0    53943
# carat           273
# cut               5
# color             7
# clarity           8
# depth           184
# table           127
# price         11602
# x               554
# y               552
# z               375
# dtype: int64

# %%
objcols = data.select_dtypes('O')
for c in objcols.columns:
    print(objcols[c].unique())
# Out:
# ['Ideal' 'Premium' 'Good' 'Very Good' 'Fair']
# ['E' 'I' 'J' 'H' 'F' 'G' 'D']
# ['SI2' 'SI1' 'VS1' 'VS2' 'VVS2' 'VVS1' 'I1' 'IF']

# %% [markdown]
# ![Picture title](image-20230227-130149.png)

# %% [markdown]
# ![Picture title](image-20230227-125906.png)

# %%
data.isna().sum()
# Out:
# Unnamed: 0    0
# carat         0
# cut           0
# color         0
# clarity       0
# depth         0
# table         0
# price         0
# x             0
# y             0
# z             0
# dtype: int64

# %%
data.duplicated().sum()
# Out:
# 0

# %% [markdown]
# # <p style="background-color:#25316D;font-family:newtimeroman;color:#FEF5AC;font-size:80%;text-align:center;border-radius:10px 10px;">DATA CLEANING & DATA PREPROCESSING</p>

# %%
dataclean = data.copy()
dataclean.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 53943 entries, 0 to 53942
# Data columns (total 11 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Unnamed: 0  53943 non-null  int64
#  1   carat       53943 non-null  float64
#  2   cut         53943 non-null  object
#  3   color       53943 non-null  object
#  4   clarity     53943 non-null  object
#  5   depth       53943 non-null  float64
#  6   table       53943 non-null  float64
#  7   price       53943 non-null  int64
#  8   x           53943 non-null  float64
#  9   y           53943 non-null  float64
#  10  z           53943 non-null  float64
# dtypes: float64(6), int64(2), object(3)
# memory usage: 4.5+ MB

# %%
dataclean.head()
# Out:
#    Unnamed: 0  carat      cut color clarity  depth  table  price     x     y  \
# 0           1   0.23    Ideal     E     SI2   61.5   55.0    326  3.95  3.98
# 1           2   0.21  Premium     E     SI1   59.8   61.0    326  3.89  3.84
# 2           3   0.23     Good     E     VS1   56.9   65.0    327  4.05  4.07
# 3           4   0.29  Premium     I     VS2   62.4   58.0    334  4.20  4.23
# 4           5   0.31     Good     J     SI2   63.3   58.0    335  4.34  4.35
#
#       z
# 0  2.43
# 1  2.31
# 2  2.31
# 3  2.63
# 4  2.75

# %%
dataclean.drop(columns=['Unnamed: 0'], axis=1, inplace=True)
dataclean.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 53943 entries, 0 to 53942
# Data columns (total 10 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   carat    53943 non-null  float64
#  1   cut      53943 non-null  object
#  2   color    53943 non-null  object
#  3   clarity  53943 non-null  object
#  4   depth    53943 non-null  float64
#  5   table    53943 non-null  float64
#  6   price    53943 non-null  int64
#  7   x        53943 non-null  float64
#  8   y        53943 non-null  float64
#  9   z        53943 non-null  float64
# dtypes: float64(6), int64(1), object(3)
# memory usage: 4.1+ MB

# %%
dataclean.describe()
# Out:
#               carat         depth         table         price             x  \
# count  53943.000000  53943.000000  53943.000000  53943.000000  53943.000000
# mean       0.797935     61.749322     57.457251   3932.734294      5.731158
# std        0.473999      1.432626      2.234549   3989.338447      1.121730
# min        0.200000     43.000000     43.000000    326.000000      0.000000
# 25%        0.400000     61.000000     56.000000    950.000000      4.710000
# 50%        0.700000     61.800000     57.000000   2401.000000      5.700000
# 75%        1.040000     62.500000     59.000000   5324.000000      6.540000
# max        5.010000     79.000000     95.000000  18823.000000     10.740000
#
#                   y             z
# count  53943.000000  53943.000000
# mean       5.734526      3.538730
# std        1.142103      0.705679
# min        0.000000      0.000000
# 25%        4.720000      2.910000
# 50%        5.710000      3.530000
# 75%        6.540000      4.040000
# max       58.900000     31.800000

# %% [markdown]
# Dari code diatas terlihat bahwa nilai minimal kolom x,y, dan z adalah 0. sedangkan untuk sebuah diamond pasti memiliki dimensi. untuk itu dilakukan pemeriksaan dahulu lalu ditentukan apakah data tersebut dihapus atau di isi dengan data yg baru.

# %%
dataclean[(dataclean['x']==0)]
# Out:
#        carat        cut color clarity  depth  table  price    x     y    z
# 11182   1.07      Ideal     F     SI2   61.6   56.0   4954  0.0  6.62  0.0
# 11963   1.00  Very Good     H     VS2   63.3   53.0   5139  0.0  0.00  0.0
# 15951   1.14       Fair     G     VS1   57.5   67.0   6381  0.0  0.00  0.0
# 24520   1.56      Ideal     G     VS2   62.2   54.0  12800  0.0  0.00  0.0
# 26243   1.20    Premium     D    VVS1   62.1   59.0  15686  0.0  0.00  0.0
# 27429   2.25    Premium     H     SI2   62.8   59.0  18034  0.0  0.00  0.0
# 49556   0.71       Good     F     SI2   64.1   60.0   2130  0.0  0.00  0.0
# 49557   0.71       Good     F     SI2   64.1   60.0   2130  0.0  0.00  0.0

# %%
dataclean[(dataclean['y']==0)]
# Out:
#        carat        cut color clarity  depth  table  price    x    y    z
# 11963   1.00  Very Good     H     VS2   63.3   53.0   5139  0.0  0.0  0.0
# 15951   1.14       Fair     G     VS1   57.5   67.0   6381  0.0  0.0  0.0
# 24520   1.56      Ideal     G     VS2   62.2   54.0  12800  0.0  0.0  0.0
# 26243   1.20    Premium     D    VVS1   62.1   59.0  15686  0.0  0.0  0.0
# 27429   2.25    Premium     H     SI2   62.8   59.0  18034  0.0  0.0  0.0
# 49556   0.71       Good     F     SI2   64.1   60.0   2130  0.0  0.0  0.0
# 49557   0.71       Good     F     SI2   64.1   60.0   2130  0.0  0.0  0.0

# %%
dataclean[(dataclean['z']==0)]
# Out:
#        carat        cut color clarity  depth  table  price     x     y    z
# 2207    1.00    Premium     G     SI2   59.1   59.0   3142  6.55  6.48  0.0
# 2314    1.01    Premium     H      I1   58.1   59.0   3167  6.66  6.60  0.0
# 4791    1.10    Premium     G     SI2   63.0   59.0   3696  6.50  6.47  0.0
# 5471    1.01    Premium     F     SI2   59.2   58.0   3837  6.50  6.47  0.0
# 10167   1.50       Good     G      I1   64.0   61.0   4731  7.15  7.04  0.0
# 11182   1.07      Ideal     F     SI2   61.6   56.0   4954  0.00  6.62  0.0
# 11963   1.00  Very Good     H     VS2   63.3   53.0   5139  0.00  0.00  0.0
# 13601   1.15      Ideal     G     VS2   59.2   56.0   5564  6.88  6.83  0.0
# 15951   1.14       Fair     G     VS1   57.5   67.0   6381  0.00  0.00  0.0
# 24394   2.18    Premium     H     SI2   59.4   61.0  12631  8.49  8.45  0.0
# 24520   1.56      Ideal     G     VS2   62.2   54.0  12800  0.00  0.00  0.0
# 26123   2.25    Premium     I     SI1   61.3   58.0  15397  8.52  8.42  0.0
# 26243   1.20    Premium     D    VVS1   62.1   59.0  15686  0.00  0.00  0.0
# 27112   2.20    Premium     H     SI1   61.2   59.0  17265  8.42  8.37  0.0
# 27429   2.25    Premium     H     SI2   62.8   59.0  18034  0.00  0.00  0.0
# 27503   2.02    Premium     H     VS2   62.7   53.0  18207  8.02  7.95  0.0
# 27739   2.80       Good     G     SI2   63.8   58.0  18788  8.90  8.85  0.0
# 49556   0.71       Good     F     SI2   64.1   60.0   2130  0.00  0.00  0.0
# 49557   0.71       Good     F     SI2   64.1   60.0   2130  0.00  0.00  0.0
# 51506   1.12    Premium     G      I1   60.4   59.0   2383  6.71  6.67  0.0

# %% [markdown]
# dari tampilan diatas diketahui bahwa ada 7 rows yang kolom x,y,z nya bernilai 0. sehingga 7 rows tersebut dihapus dan 1 rows yang kolom x, dan z nya bernilai 0 juga dihapus. sedangkan untuk rows dengan kolom z bernilai 0 tidak dihapus, karena nilai z dapat dicari dengan rumus dibawah ini

# %%
datatest = dataclean.copy()

# zerodrop = datatest[ (datatest['x'] == 0) & (datatest['y'] == 0) & (datatest['z'] == 0)].index
# datatest.drop(zerodrop , inplace=True)

xzero = datatest[ (datatest['x'] == 0)].index
datatest.drop(xzero , inplace=True)

datatest.shape
# Out:
# (53935, 10)

# %% [markdown]
# Ada sumber yang mengatakan bahwa rumus depth = z / mean(x, y) atau 2 * z / (x + y)

# %% [markdown]
# namun rumus tersebut masih harus dibuktikan kebenarannya dengan cara dibawah ini

# %%
# total depth percentage = z / mean(x, y) atau 2 * z / (x + y)

dataclean['Depth Prediction 1'] = dataclean['z'] / ((dataclean['x']+dataclean['y'])/2) * 100

dataclean['Depth Prediction 2'] = 2*dataclean['z'] / (dataclean['x']+dataclean['y'])* 100

dataclean.head()
# Out:
#    carat      cut color clarity  depth  table  price     x     y     z  \
# 0   0.23    Ideal     E     SI2   61.5   55.0    326  3.95  3.98  2.43
# 1   0.21  Premium     E     SI1   59.8   61.0    326  3.89  3.84  2.31
# 2   0.23     Good     E     VS1   56.9   65.0    327  4.05  4.07  2.31
# 3   0.29  Premium     I     VS2   62.4   58.0    334  4.20  4.23  2.63
# 4   0.31     Good     J     SI2   63.3   58.0    335  4.34  4.35  2.75
#
#    Depth Prediction 1  Depth Prediction 2
# 0           61.286255           61.286255
# 1           59.767141           59.767141
# 2           56.896552           56.896552
# 3           62.396204           62.396204
# 4           63.291139           63.291139

# %%
corrspearman1 = dataclean['depth'].corr(dataclean['Depth Prediction 1'], method='spearman')
corrspearman2 = dataclean['depth'].corr(dataclean['Depth Prediction 2'], method='spearman')

corrkendall1 = dataclean['depth'].corr(dataclean['Depth Prediction 1'], method='kendall')
corrkendall2 = dataclean['depth'].corr(dataclean['Depth Prediction 2'], method='kendall')

print('Koefisien korelasi spearman antara DP1 dan DP:', corrspearman1)
print('Koefisien korelasi spearman antara DP2 dan DP:', corrspearman2)

print('Koefisien korelasi kendall antara DP1 dan DP:', corrkendall1)
print('Koefisien korelasi kendall antara DP2 dan DP:', corrkendall2)
# Out:
# Koefisien korelasi spearman antara DP1 dan DP: 0.9964937306635858
# Koefisien korelasi spearman antara DP2 dan DP: 0.9964937306635858
# Koefisien korelasi kendall antara DP1 dan DP: 0.9807668670558525
# Koefisien korelasi kendall antara DP2 dan DP: 0.9807668670558525

# %% [markdown]
# ![Picture title](image-20230302-181652.png)

# %%
dataclean.shape
# Out:
# (53943, 12)

# %%
dataclean.drop('Depth Prediction 2', axis=1, inplace=True)
dataclean.drop('Depth Prediction 1', axis=1, inplace=True)

dataclean.shape
# Out:
# (53943, 10)

# %% [markdown]
# dari rumus depth didapatkan bahwa z = total depth percentage * (x+y)/2

# %%
# z = total depth percentage * (x+y)/2

zZero = datatest[(datatest['z']==0)]

print(zZero.shape)
# Out:
# (12, 10)

# %%
# untuk melihat hasil kolom z setelah dihitung menggunakan rumus diatas

zZero['z'] = zZero.apply(lambda z: z['depth'] * (z['x']+z['y'])/200 if z['z'] ==0 else z['z'], axis=1)

zZero.head(12)
# Out:
#        carat      cut color clarity  depth  table  price     x     y         z
# 2207    1.00  Premium     G     SI2   59.1   59.0   3142  6.55  6.48  3.850365
# 2314    1.01  Premium     H      I1   58.1   59.0   3167  6.66  6.60  3.852030
# 4791    1.10  Premium     G     SI2   63.0   59.0   3696  6.50  6.47  4.085550
# 5471    1.01  Premium     F     SI2   59.2   58.0   3837  6.50  6.47  3.839120
# 10167   1.50     Good     G      I1   64.0   61.0   4731  7.15  7.04  4.540800
# 13601   1.15    Ideal     G     VS2   59.2   56.0   5564  6.88  6.83  4.058160
# 24394   2.18  Premium     H     SI2   59.4   61.0  12631  8.49  8.45  5.031180
# 26123   2.25  Premium     I     SI1   61.3   58.0  15397  8.52  8.42  5.192110
# 27112   2.20  Premium     H     SI1   61.2   59.0  17265  8.42  8.37  5.137740
# 27503   2.02  Premium     H     VS2   62.7   53.0  18207  8.02  7.95  5.006595
# 27739   2.80     Good     G     SI2   63.8   58.0  18788  8.90  8.85  5.662250
# 51506   1.12  Premium     G      I1   60.4   59.0   2383  6.71  6.67  4.040760

# %%
datatest['z'] = datatest.apply(lambda z: z['depth'] * (z['x']+z['y'])/200 if z['z'] ==0 else z['z'], axis=1)

datatest[(datatest['z']==0)]
# Out:
# Empty DataFrame
# Columns: [carat, cut, color, clarity, depth, table, price, x, y, z]
# Index: []

# %%
numcols = datatest.select_dtypes('number')
objcols = datatest.select_dtypes('O')

i = 1
plt.figure(figsize=(19, 12))
for c in numcols.columns:
    plt.subplot(3, 3, i)
    sns.boxplot(x=datatest[c])
    i+=1

# %%
def IQR(df, column):
  Q1 = df[column].quantile(0.25)
  Q3 = df[column].quantile(0.75)
  IQR = Q3 - Q1
  Minimum = Q1 - 1.5 * IQR
  Maximum = Q3 + 1.5 * IQR
  filter_lower = df[column] < Minimum
  filter_upper = df[column] > Maximum
  return filter_lower, filter_upper

# %%
dataIQR = dataclean.copy()

i = 1
for c in numcols.columns:
    filterL, filterU = IQR(dataIQR,c)
    i+=1

# %%
dataIQR = dataIQR[filterL | filterU]

# %%
i = 1
plt.figure(figsize=(19, 12))
for c in numcols.columns:
    plt.subplot(3, 3, i)
    sns.boxplot(x=dataIQR[c])
    i+=1

# %%
dataZs = datatest.copy()
numcols = dataZs.select_dtypes('number')
objcols = dataZs.select_dtypes('O')
dataZs = dataZs[(np.abs(stats.zscore(numcols)) < 3).all(axis=1)]

# %%
i = 1
plt.figure(figsize=(19, 12))
for c in numcols.columns:
    plt.subplot(3, 3, i)
    sns.boxplot(x=dataZs[c])
    i+=1

# %%
print('Setelah menggunakan fungsi IQR',dataIQR.shape)

print('Setelah menggunakan fungsi Zscore',dataZs.shape)
# Out:
# Setelah menggunakan fungsi IQR (49, 10)
# Setelah menggunakan fungsi Zscore (51600, 10)

# %%
label_data = dataZs.copy()

numcols = label_data.select_dtypes('number')
objcols = label_data.select_dtypes('O')

mapping = {'Fair': 0, 'Good': 1, 'Very Good': 2, 'Premium': 3, 'Ideal': 4}

# membuat objek LabelEncoder
encoder = LabelEncoder()

# melakukan encoding pada kolom 'cut'
label_data['cut'] = encoder.fit_transform(label_data['cut'].replace(mapping))

# %%
mapping = {'I1': 0, 'SI1': 1, 'SI2': 2, 'VS1': 3, 'VS2': 4, 'VVS1': 5, 'VVS2': 6, 'IF': 7}

# membuat objek LabelEncoder
encoder = LabelEncoder()

# melakukan encoding pada kolom 'clarity'
label_data['clarity'] = encoder.fit_transform(label_data['clarity'].replace(mapping))

# %%
mapping = {'J': 0, 'I': 1, 'H': 2, 'G': 3, 'F': 4, 'E': 5, 'D': 6}

# membuat objek LabelEncoder
encoder = LabelEncoder()

# melakukan encoding pada kolom 'clarity'
label_data['color'] = encoder.fit_transform(label_data['color'].replace(mapping))

# %%
label_data_scalled = label_data.copy()

scaler = MinMaxScaler()

# Fit and transform the data
label_data_scalled['price'] = scaler.fit_transform(pd.DataFrame(label_data_scalled['price']))

# %% [markdown]
# # <p style="background-color:#25316D;font-family:newtimeroman;color:#FEF5AC;font-size:80%;text-align:center;border-radius:10px 10px;">EXPLORATORY DATA ANALYSIS</p>

# %%
#Pertama kita melihat semua distribusi data 

i = 1
plt.figure(figsize=(19, 12))
for c in numcols.columns:
    plt.subplot(3, 3, i)
    sns.kdeplot(data=label_data[c])
    i+=1

# %%
sns.kdeplot(data=label_data['carat'])
plt.show()

# %%
sns.kdeplot(data=label_data['price'])
plt.show()

# %%
# Selanjutnya kita gunakan pearson correlation matrix untuk mengetahui koreleasi antara price dan semua feature

CorrMat = label_data.corr()

cols = CorrMat.nlargest(10, 'price')['price'].index
cm = np.corrcoef(label_data[cols].values.T)
sns.set(font_scale=0.8)
hm = sns.heatmap(cm, cbar=True, annot=True, square=True, fmt='.2f', annot_kws={'size': 7}, yticklabels=cols.values, xticklabels=cols.values)
plt.show()

# %% [markdown]
# ## <p style="background-color:#25316D;font-family:newtimeroman;color:#FEF5AC;font-size:80%;text-align:center;border-radius:10px 10px;"> 1. Apa hubungan harga dengan 4C (Cut, Color, Carat, Clarity)?</p>

# %%
# Clarity

from scipy.stats import trim_mean

grouped = label_data.groupby('clarity')
grouped_price = grouped['price']

# Bikin class untuk bikin fungsi baru yang bisa di masukin ke pandas.agg
class Quantile:
    def __init__(self, q):
        self.q = q
        
    def __call__(self, x):
        return x.quantile(self.q)
        # Or using numpy
        # return np.quantile(x.dropna(), self.q)

avg_price = grouped_price.agg(trim_mean, 0.15)
min_price = grouped_price.agg(Quantile(0.25))

plt.figure(figsize = (6,5))
plt.bar(avg_price.index, avg_price, label = 'Trimmed Average Price')
plt.plot(min_price.index, min_price, 'k--o', label = '25-th Percentile')
plt.xlabel("Clarity")
plt.ylabel("Price")

plt.xticks([0, 1, 2, 3, 4, 5, 6, 7], ['I1', 'SI1', 'SI2', 'VS1', 'VS2', 'VVS1', 'VVS2', 'IF'])

plt.legend(loc='best')

plt.show()

# %%
# Cut
# mapping = {'Fair': 0, 'Good': 1, 'Very Good': 2, 'Premium': 3, 'Ideal': 4}

grouped = label_data.groupby('cut')
grouped_price = grouped['price']


avg_price = grouped_price.agg(trim_mean, 0.15)
min_price = grouped_price.agg(Quantile(0.25))

plt.figure(figsize = (6,4))
plt.bar(avg_price.index, avg_price, label = 'Trimmed Average Price')
plt.plot(min_price.index, min_price, 'k--o', label = '25-th Percentile')
plt.xlabel("Cut")
plt.ylabel("Price")

plt.xticks([0, 1, 2, 3, 4], ['Fair', 'Good', 'Very Good', 'Premium', 'Ideal'])

plt.legend(loc='best')

plt.show()

# %%
# Color
# mapping = {'J': 0, 'I': 1, 'H': 2, 'G': 3, 'F': 4, 'E': 5, 'D': 6}

grouped = label_data.groupby('color')
grouped_price = grouped['price']

avg_price = grouped_price.agg(trim_mean, 0.15)
min_price = grouped_price.agg(Quantile(0.25))

plt.figure(figsize = (6,4))
plt.bar(avg_price.index, avg_price, label = 'Trimmed Average Price')
plt.plot(min_price.index, min_price, 'k--o', label = '25-th Percentile')
plt.xlabel("Color")
plt.ylabel("Price")

plt.xticks([0, 1, 2, 3, 4, 5, 6 ], ['J', 'I', 'H', 'G', 'F', 'E', 'D'])

plt.legend(loc='best')

plt.show()

# %%
selected_cols = ['price', 'cut', 'color', 'carat', 'clarity']
df_selected = label_data[selected_cols]

corr_matrix = df_selected.corr()
sns.heatmap(corr_matrix, annot=True, fmt='.2f', annot_kws={'size': 7})
plt.show()

# %% [markdown]
# ## <p style="background-color:#25316D;font-family:newtimeroman;color:#FEF5AC;font-size:80%;text-align:center;border-radius:10px 10px;"> 2. Fitur apa yang paling mempengaruhi harga diamond meningkat?</p>

# %%
# Histrogram carat

plt.figure(figsize=(6, 4))
sns.histplot(
    label_data, x="carat", y="price",
    bins=40, log_scale=(False, True),
    cbar=True,
)
# Out:
# <Axes: xlabel='carat', ylabel='price'>

# %%
plt.scatter(label_data['price'], label_data['carat'])
m, b = np.polyfit(label_data['price'], label_data['carat'], 1)
plt.plot(label_data['price'], m*label_data['price']+b,color='black')

plt.xlabel('price')
plt.ylabel('carat')

plt.show()

# %% [markdown]
# ## <p style="background-color:#25316D;font-family:newtimeroman;color:#FEF5AC;font-size:80%;text-align:center;border-radius:10px 10px;"> 3. Fitur apa yang tidak mempengaruhi harga diamond?</p>

# %%
plt.scatter(label_data['price'], label_data['depth'])
m, b = np.polyfit(label_data['price'], label_data['depth'], 1)
plt.plot(label_data['price'], m*label_data['price']+b,color='black')
plt.xlabel('price')
plt.ylabel('depth')
plt.show()

# %%
label_data_cat = label_data.copy()
label_data_cat['clarity'] = label_data_cat['clarity'].map(str)
label_data_cat['cut'] = label_data_cat['cut'].map(str)
label_data_cat['color'] = label_data_cat['color'].map(str)

small_sample = label_data_cat.sample(1000)

sns.catplot(data=small_sample, x="price", y="cut", kind="violin", color=".9", inner=None)
sns.swarmplot(data=small_sample, x="price", y="cut", size=2)
sns.set(font_scale=0.5)

# %%
sns.catplot(data=small_sample, x="price", y="clarity", kind="violin", color=".9", inner=None)
sns.swarmplot(data=small_sample, x="price", y="clarity", size=2)
sns.set(font_scale=0.5)

# %%
sns.catplot(data=small_sample, x="price", y="color", kind="violin", color=".9", inner=None)
sns.swarmplot(data=small_sample, x="price", y="color", size=2)
sns.set(font_scale=0.5)

# %% [markdown]
# ## <p style="background-color:#25316D;font-family:newtimeroman;color:#FEF5AC;font-size:80%;text-align:center;border-radius:10px 10px;">4. Apakah ada feature yang mempengaruhi turunnya harga diamond?</p>

# %%
price_color_df = label_data[['color', 'price']]

from sklearn.preprocessing import OneHotEncoder

#creating instance of one-hot-encoder
encoder = OneHotEncoder(handle_unknown='ignore')

#perform one-hot encoding on 'team' column 
encoder_df = pd.DataFrame(encoder.fit_transform(price_color_df[['color']]).toarray())

#merge one-hot encoded columns back with original DataFrame
final_df = price_color_df.join(encoder_df)

final_df = final_df.drop(labels='color', axis=1)

final_df = final_df.set_axis(['Price', 'J', 'I', 'H', 'G', 'F', 'E', 'D'], axis=1, inplace=False)

corr_matrix = final_df.corr()
hm = sns.heatmap(corr_matrix, annot=True, fmt='.2f', annot_kws={'size': 7})

plt.show()

# %% [markdown]
# # <p style="background-color:#25316D;font-family:newtimeroman;color:#FEF5AC;font-size:80%;text-align:center;border-radius:10px 10px;"> MACHINE LEARNING MODELING I</p>

# %% [markdown]
# ## <p style="background-color:#25316D;font-family:newtimeroman;color:#FEF5AC;font-size:80%;text-align:center;border-radius:10px 10px;">train-test data split</p>

# %%
# train and test data split

X = label_data.drop(["price"],axis =1)
y = label_data["price"]


X_train, X_test, y_train, y_test = train_test_split(X, y,test_size=0.3, random_state=7)

# %% [markdown]
# ## <p style="background-color:#25316D;font-family:newtimeroman;color:#FEF5AC;font-size:80%;text-align:center;border-radius:10px 10px;">pipeline</p>

# %%
# Verbosity = log output(aku non-aktifkan biar bersih outputnya)
# Di Machine Learning Modeling I ini, semua model pakai default value parameter
# Hasil performa disini sebagai base score

# Linear Regression
pipeline_lr = Pipeline([("scalar1", StandardScaler()),
                        ("lr_regressor", LinearRegression())])

# XGBoost
pipeline_xgb = Pipeline([("scalar2",StandardScaler()),
                     ("xgb_regressor",XGBRegressor(verbosity=0))])

# CatBoost
pipeline_cat = Pipeline([("scalar3", StandardScaler()),
                    ("cat_regressor", CatBoostRegressor(verbose=False))])

# %% [markdown]
# ## <p style="background-color:#25316D;font-family:newtimeroman;color:#FEF5AC;font-size:80%;text-align:center;border-radius:10px 10px;">Training</p>

# %%
pipelines = [pipeline_lr, pipeline_xgb, pipeline_cat]

pipe_dict = {0: "Linear Regression", 1: "XGBRegressor", 2: "CatBoostRegressor"}

for pipe in pipelines:
    pipe.fit(X_train, y_train)

# %%
cv_results_rms = []
for i, model in enumerate(pipelines):
    cv_score = cross_val_score(model, X_train,y_train,scoring="neg_root_mean_squared_error", cv=5)
    cv_results_rms.append(cv_score)
    print("%s: %f " % (pipe_dict[i], cv_score.mean()))
# Out:
# Linear Regression: -1077.510678
# XGBRegressor: -451.422512
# CatBoostRegressor: -430.711985

# %% [markdown]
# ## <p style="background-color:#25316D;font-family:newtimeroman;color:#FEF5AC;font-size:80%;text-align:center;border-radius:10px 10px;">Model Evaluation: RMSE & MAE</p>

# %% [markdown]
# ### <p style="background-color:#25316D;font-family:newtimeroman;color:#FEF5AC;font-size:80%;text-align:center;border-radius:10px 10px;">RMSE Score antara 3 Model</p>

# %%
print("Hasil Cross-Validation-Score RMSE (train data)")
cv_results_rms = []
for i, model in enumerate(pipelines):
    cv_score = cross_val_score(model, X_train, y_train, scoring="neg_root_mean_squared_error", cv=5)
    cv_results_rms.append(cv_score)
    print("%s: %f " % (pipe_dict[i], cv_score.mean()))
# Out:
# Hasil Cross-Validation-Score RMSE (train data)
# Linear Regression: -1077.510678
# XGBRegressor: -451.422512
# CatBoostRegressor: -430.711985

# %%
print("Hasil Cross-Validation-Score RMSE (test data)")
cv_results_rms = []
for i, model in enumerate(pipelines):
    cv_score = cross_val_score(model, X_test, y_test, scoring="neg_root_mean_squared_error", cv=5)
    cv_results_rms.append(cv_score)
    print("%s: %f " % (pipe_dict[i], cv_score.mean()))
# Out:
# Hasil Cross-Validation-Score RMSE (test data)
# Linear Regression: -1069.266087
# XGBRegressor: -474.662857
# CatBoostRegressor: -453.036256

# %% [markdown]
# ### <p style="background-color:#25316D;font-family:newtimeroman;color:#FEF5AC;font-size:80%;text-align:center;border-radius:10px 10px;">MAE Score antara 3 Model</p>

# %%
print("Hasil Cross-Validation-Score MAE (train data)")
cv_results_rms = []
for i, model in enumerate(pipelines):
    cv_score = cross_val_score(model, X_train, y_train,scoring="neg_mean_absolute_error", cv=5)
    cv_results_rms.append(cv_score)
    print("%s: %f " % (pipe_dict[i], cv_score.mean()))
# Out:
# Hasil Cross-Validation-Score MAE (train data)
# Linear Regression: -730.262917
# XGBRegressor: -244.416140
# CatBoostRegressor: -236.796019

# %%
print("Hasil Cross-Validation-Score MAE (test data)")
cv_results_rms = []
for i, model in enumerate(pipelines):
    cv_score = cross_val_score(model, X_test, y_test,scoring="neg_mean_absolute_error", cv=5)
    cv_results_rms.append(cv_score)
    print("%s: %f " % (pipe_dict[i], cv_score.mean()))
# Out:
# Hasil Cross-Validation-Score MAE (test data)
# Linear Regression: -723.523121
# XGBRegressor: -253.237777
# CatBoostRegressor: -245.484155

# %% [markdown]
# # <p style="background-color:#25316D;font-family:newtimeroman;color:#FEF5AC;font-size:80%;text-align:center;border-radius:10px 10px;"> FEATURE SELECTION</p>

# %% [markdown]
# ## <p style="background-color:#25316D;font-family:newtimeroman;color:#FEF5AC;font-size:80%;text-align:center;border-radius:10px 10px;"> I. Variance Threshold</p>

# %% [markdown]
# sumber: https://towardsdatascience.com/how-to-use-variance-thresholding-for-robust-feature-selection-a4503f2b5c3f

# %%
# Variance Threshold
# Feature selector that removes all low-variance features.
# This feature selection algorithm looks only at the features (X), 
# not the desired outputs (y)

from sklearn.feature_selection import VarianceThreshold

# %%
selector = VarianceThreshold(threshold=0.15)
selector.fit(label_data.drop(["price", "cut", "color", "clarity"],axis =1))

print(label_data.drop(["price", "cut", "color", "clarity"],axis =1).columns)
print(selector.get_support())
# Out:
# Index(['carat', 'depth', 'table', 'x', 'y', 'z'], dtype='object')
# [ True  True  True  True  True  True]

# %%
# Tidak ada fitur yang memiliki Low Variation

# %% [markdown]
# ## <p style="background-color:#25316D;font-family:newtimeroman;color:#FEF5AC;font-size:80%;text-align:center;border-radius:10px 10px;">II. SHAP (from catboost)</p>

# %% [markdown]
# <img src="https://github.com/radifan9/bcc_ds7_image/blob/main/image-20230310-072017.png?raw=true">

# %% [markdown]
# Dari nilai SHAP, kita dapat melihat bahwa fitur table, depth, dan cut memiliki impact yang kecil ke output dari model.

# %% [markdown]
# ## <p style="background-color:#25316D;font-family:newtimeroman;color:#FEF5AC;font-size:80%;text-align:center;border-radius:10px 10px;">III. RFE</p>

# %%
from sklearn.feature_selection import RFE

# %%
xgb_reg = xgb.XGBRegressor(objective ='reg:linear', learning_rate = 0.15, max_depth = 5, n_estimators = 300)
rfe = RFE(estimator=xgb_reg, n_features_to_select=6)

# %%
scaler = StandardScaler()
scaler.fit_transform(X_train)
rfe.fit(X_train, y_train)
# Out:
# [15:25:42] WARNING: ../src/objective/regression_obj.cu:213: reg:linear is now deprecated in favor of reg:squarederror.
# [15:25:51] WARNING: ../src/objective/regression_obj.cu:213: reg:linear is now deprecated in favor of reg:squarederror.
# [15:25:56] WARNING: ../src/objective/regression_obj.cu:213: reg:linear is now deprecated in favor of reg:squarederror.
# [15:26:03] WARNING: ../src/objective/regression_obj.cu:213: reg:linear is now deprecated in favor of reg:squarederror.
# RFE(estimator=XGBRegressor(base_score=None, booster=None, callbacks=None,
#                            colsample_bylevel=None, colsample_bynode=None,
#                            colsample_bytree=None, early_stopping_rounds=None,
#                            enable_categorical=False, eval_metric=None,
#                            feature_types=None, gamma=None, gpu_id=None,
#                            grow_policy=None, importance_type=None,
#                            interaction_constraints=None, learning_rate=0.15,
#                            max_bin=None, max_cat_threshold=None,
#                            max_cat_to_onehot=None, max_delta_step=None,
#                            max_depth=5, max_leaves=None, min_child_weight=None,
#                            missing=nan, monotone_constraints=None,
#                            n_estimators=300, n_jobs=None,
#                            num_parallel_tree=None, objective='reg:linear',
#                            predictor=None, ...),
#     n_features_to_select=6)

# %%
for i, col in zip(range(X_train.shape[1]), X_train.columns):
    print(f"{col} selected={rfe.support_[i]} rank={rfe.ranking_[i]}")
# Out:
# carat selected=True rank=1
# cut selected=True rank=1
# color selected=True rank=1
# clarity selected=True rank=1
# depth selected=False rank=3
# table selected=False rank=4
# x selected=False rank=2
# y selected=True rank=1
# z selected=True rank=1

# %% [markdown]
# # <p style="background-color:#25316D;font-family:newtimeroman;color:#FEF5AC;font-size:80%;text-align:center;border-radius:10px 10px;"> FEATURE ENGINEERING</p>

# %% [markdown]
# tentang applying log
#
# https://towardsdatascience.com/how-to-differentiate-between-scaling-normalization-and-log-transformations-69873d365a94

# %%
# kita lakuin log ke data train_test yang terpisah 
# untuk menghindari data leakege

# log transformation fitur carat

X_train_log = X_train.copy()
X_train_log['carat'] = np.log(X_train_log['carat'])

X_test_log = X_test.copy()
X_test_log['carat'] = np.log(X_test_log['carat'])

plt.figure(figsize=(6, 4))
sns.histplot(data=X_train_log['carat'])
plt.show()

plt.figure(figsize=(6, 4))
sns.histplot(data=X_test_log['carat'])
plt.show()

# log transformation price

y_train_log = y_train.copy()
y_train_log = np.log(y_train_log)

y_test_log = y_test.copy()
y_test_log = np.log(y_test_log)

plt.figure(figsize=(6, 4))
sns.histplot(data=y_train_log)
plt.show()

plt.figure(figsize=(6, 4))
sns.histplot(data=y_test_log)
plt.show()

# %%
X_train_log.head()
# Out:
#           carat  cut  color  clarity  depth  table     x     y     z
# 15553  0.292670    2      0        3   61.7   59.0  7.03  7.14  4.37
# 53546 -0.198451    3      1        4   62.2   59.0  5.97  6.03  3.73
# 52104 -0.223144    2      4        2   61.0   60.0  5.95  5.98  3.64
# 44892 -0.693147    4      5        4   62.5   57.0  5.10  5.04  3.17
# 3308  -0.314711    2      5        3   60.9   61.0  5.79  5.81  3.53

# %% [markdown]
# ## <p style="background-color:#25316D;font-family:newtimeroman;color:#FEF5AC;font-size:80%;text-align:center;border-radius:10px 10px;">Model Evaluation: RMSE & MAE</p>

# %%
# Making a log pipeline
# Linear Regression
pipeline_lr_log = Pipeline([("scalar1", StandardScaler()),
                        ("lr_regressor", LinearRegression())])

# XGBoost
pipeline_xgb_log = Pipeline([("scalar2",StandardScaler()),
                     ("xgb_regressor",XGBRegressor(verbosity=0))])

# CatBoost
pipeline_cat_log = Pipeline([("scalar3", StandardScaler()),
                    ("cat_regressor", CatBoostRegressor(verbose=False))])


pipelines_log = [pipeline_lr_log, pipeline_xgb_log, pipeline_cat_log]


# train and cross-validate with test data
pipe_dict = {0: "Linear Regression", 1: "XGBRegressor", 2: "CatBoostRegressor"}

for pipe in pipelines_log:
    pipe.fit(X_train_log, y_train_log)

# %% [markdown]
# ### <p style="background-color:#25316D;font-family:newtimeroman;color:#FEF5AC;font-size:80%;text-align:center;border-radius:10px 10px;">RMSE Score antara 3 Model</p>

# %%
print("Hasil Cross-Validation-Score RMSE (train data)")
cv_results_rms = []
for i, model in enumerate(pipelines_log):
    cv_score = cross_val_score(model, X_train_log, y_train_log,scoring="neg_root_mean_squared_error", cv=5)
    cv_results_rms.append(cv_score)
    print("%s: %f " % (pipe_dict[i], cv_score.mean()))
# Out:
# Hasil Cross-Validation-Score RMSE (train data)
# Linear Regression: -0.172085
# XGBRegressor: -0.086693
# CatBoostRegressor: -0.084499

# %%
print("Hasil Cross-Validation-Score RMSE (test data)")
cv_results_rms = []
for i, model in enumerate(pipelines_log):
    cv_score = cross_val_score(model, X_test_log, y_test_log,scoring="neg_root_mean_squared_error", cv=5)
    cv_results_rms.append(cv_score)
    print("%s: %f " % (pipe_dict[i], cv_score.mean()))
# Out:
# Hasil Cross-Validation-Score RMSE (test data)
# Linear Regression: -0.171113
# XGBRegressor: -0.090039
# CatBoostRegressor: -0.086004

# %% [markdown]
# ### <p style="background-color:#25316D;font-family:newtimeroman;color:#FEF5AC;font-size:80%;text-align:center;border-radius:10px 10px;">MAE Score antara 3 Model</p>

# %%
print("Hasil Cross-Validation-Score MAE (train data)")
cv_results_rms = []
for i, model in enumerate(pipelines_log):
    cv_score = cross_val_score(model, X_train_log, y_train_log,scoring="neg_mean_absolute_error", cv=5)
    cv_results_rms.append(cv_score)
    print("%s: %f " % (pipe_dict[i], cv_score.mean()))
# Out:
# Hasil Cross-Validation-Score MAE (train data)
# Linear Regression: -0.137241
# XGBRegressor: -0.063154
# CatBoostRegressor: -0.061796

# %%
print("Hasil Cross-Validation-Score MAE (test data)")
cv_results_rms = []
for i, model in enumerate(pipelines_log):
    cv_score = cross_val_score(model, X_test_log, y_test_log,scoring="neg_mean_absolute_error", cv=5)
    cv_results_rms.append(cv_score)
    print("%s: %f " % (pipe_dict[i], cv_score.mean()))
# Out:
# Hasil Cross-Validation-Score MAE (test data)
# Linear Regression: -0.137321
# XGBRegressor: -0.065939
# CatBoostRegressor: -0.063161

# %% [markdown]
# ## <p style="background-color:#25316D;font-family:newtimeroman;color:#FEF5AC;font-size:80%;text-align:center;border-radius:10px 10px;">Model Evaluation: with features dropped</p>

# %%
xgb_reg = xgb.XGBRegressor(objective ='reg:linear', learning_rate = 0.15, max_depth = 5, n_estimators = 300)
xgb_reg.fit(X_train_log, y_train_log)
rmse_scores_train_log_all = cross_val_score(xgb_reg, X_train_log, y_train_log, cv=5, scoring='neg_root_mean_squared_error')
print(f"Cross-Validation-Score RMSE with all features: {rmse_scores_train_log_all.mean()}")
# Out:
# [15:29:01] WARNING: ../src/objective/regression_obj.cu:213: reg:linear is now deprecated in favor of reg:squarederror.
# [15:29:07] WARNING: ../src/objective/regression_obj.cu:213: reg:linear is now deprecated in favor of reg:squarederror.
# [15:29:15] WARNING: ../src/objective/regression_obj.cu:213: reg:linear is now deprecated in favor of reg:squarederror.
# [15:29:20] WARNING: ../src/objective/regression_obj.cu:213: reg:linear is now deprecated in favor of reg:squarederror.
# [15:29:24] WARNING: ../src/objective/regression_obj.cu:213: reg:linear is now deprecated in favor of reg:squarederror.
# [15:29:32] WARNING: ../src/objective/regression_obj.cu:213: reg:linear is now deprecated in favor of reg:squarederror.
# Cross-Validation-Score RMSE with all features: -0.08528296264850148

# %%
xgb_reg = xgb.XGBRegressor(objective ='reg:linear', learning_rate = 0.15, max_depth = 5, n_estimators = 300)

xgb_reg.fit(X_train_log.drop(columns=['cut'], axis=1), y_train_log)
rmse_scores_train_log_cut = cross_val_score(xgb_reg, X_train_log.drop(columns=['cut'], axis=1), y_train_log, cv=5, scoring='neg_root_mean_squared_error')
print(f"Cross-Validation-Score RMSE with cut dropped: {rmse_scores_train_log_cut.mean()}")
# Out:
# [15:29:37] WARNING: ../src/objective/regression_obj.cu:213: reg:linear is now deprecated in favor of reg:squarederror.
# [15:29:45] WARNING: ../src/objective/regression_obj.cu:213: reg:linear is now deprecated in favor of reg:squarederror.
# [15:29:49] WARNING: ../src/objective/regression_obj.cu:213: reg:linear is now deprecated in favor of reg:squarederror.
# [15:29:56] WARNING: ../src/objective/regression_obj.cu:213: reg:linear is now deprecated in favor of reg:squarederror.
# [15:30:01] WARNING: ../src/objective/regression_obj.cu:213: reg:linear is now deprecated in favor of reg:squarederror.
# [15:30:08] WARNING: ../src/objective/regression_obj.cu:213: reg:linear is now deprecated in favor of reg:squarederror.
# Cross-Validation-Score RMSE with cut dropped: -0.08640992917108205

# %%
xgb_reg = xgb.XGBRegressor(objective ='reg:linear', learning_rate = 0.15, max_depth = 5, n_estimators = 300)

xgb_reg.fit(X_train_log.drop(columns=['depth'], axis=1), y_train_log)
rmse_scores_train_log_depth = cross_val_score(xgb_reg, X_train_log.drop(columns=['depth'], axis=1), y_train_log, cv=5, scoring='neg_root_mean_squared_error')
print(f"Cross-Validation-Score RMSE with depth dropped: {rmse_scores_train_log_depth.mean()}")
# Out:
# [15:30:12] WARNING: ../src/objective/regression_obj.cu:213: reg:linear is now deprecated in favor of reg:squarederror.
# [15:30:18] WARNING: ../src/objective/regression_obj.cu:213: reg:linear is now deprecated in favor of reg:squarederror.
# [15:30:25] WARNING: ../src/objective/regression_obj.cu:213: reg:linear is now deprecated in favor of reg:squarederror.
# [15:30:31] WARNING: ../src/objective/regression_obj.cu:213: reg:linear is now deprecated in favor of reg:squarederror.
# [15:30:39] WARNING: ../src/objective/regression_obj.cu:213: reg:linear is now deprecated in favor of reg:squarederror.
# [15:30:43] WARNING: ../src/objective/regression_obj.cu:213: reg:linear is now deprecated in favor of reg:squarederror.
# Cross-Validation-Score RMSE with depth dropped: -0.08537041814329285

# %%
xgb_reg = xgb.XGBRegressor(objective ='reg:linear', learning_rate = 0.15, max_depth = 5, n_estimators = 300)

xgb_reg.fit(X_train_log.drop(columns=['table'], axis=1), y_train_log)
rmse_scores_train_log_table = cross_val_score(xgb_reg, X_train_log.drop(columns=['table'], axis=1), y_train_log, cv=5, scoring='neg_root_mean_squared_error')
print(f"Cross-Validation-Score RMSE with table dropped: {rmse_scores_train_log_table.mean()}")
# Out:
# [15:30:51] WARNING: ../src/objective/regression_obj.cu:213: reg:linear is now deprecated in favor of reg:squarederror.
# [15:30:56] WARNING: ../src/objective/regression_obj.cu:213: reg:linear is now deprecated in favor of reg:squarederror.
# [15:31:03] WARNING: ../src/objective/regression_obj.cu:213: reg:linear is now deprecated in favor of reg:squarederror.
# [15:31:07] WARNING: ../src/objective/regression_obj.cu:213: reg:linear is now deprecated in favor of reg:squarederror.
# [15:31:12] WARNING: ../src/objective/regression_obj.cu:213: reg:linear is now deprecated in favor of reg:squarederror.
# [15:31:19] WARNING: ../src/objective/regression_obj.cu:213: reg:linear is now deprecated in favor of reg:squarederror.
# Cross-Validation-Score RMSE with table dropped: -0.08561845983785614

# %%
xgb_reg = xgb.XGBRegressor(objective ='reg:linear', learning_rate = 0.15, max_depth = 5, n_estimators = 300)

xgb_reg.fit(X_train_log.drop(columns=['depth', 'cut', 'table'], axis=1), y_train_log)
rmse_scores_train_log_3 = cross_val_score(xgb_reg, X_train_log.drop(columns=['depth', 'cut', 'table'], axis=1), y_train_log, cv=5, scoring='neg_root_mean_squared_error')
print(f"Cross-Validation-Score RMSE with depth, cut, table dropped: {rmse_scores_train_log_3.mean()}")
# Out:
# [15:31:23] WARNING: ../src/objective/regression_obj.cu:213: reg:linear is now deprecated in favor of reg:squarederror.
# [15:31:30] WARNING: ../src/objective/regression_obj.cu:213: reg:linear is now deprecated in favor of reg:squarederror.
# [15:31:34] WARNING: ../src/objective/regression_obj.cu:213: reg:linear is now deprecated in favor of reg:squarederror.
# [15:31:38] WARNING: ../src/objective/regression_obj.cu:213: reg:linear is now deprecated in favor of reg:squarederror.
# [15:31:44] WARNING: ../src/objective/regression_obj.cu:213: reg:linear is now deprecated in favor of reg:squarederror.
# [15:31:48] WARNING: ../src/objective/regression_obj.cu:213: reg:linear is now deprecated in favor of reg:squarederror.
# Cross-Validation-Score RMSE with depth, cut, table dropped: -0.08821037591635318

# %%
models = pd.DataFrame({'Model': ['All features', 'Cut Dropped', 'Depth Dropped', 'Table Dropped', 'Cut, Depth, Table Dropped'],
                       'RMSE Score (train data)': [rmse_scores_train_log_all.mean(), rmse_scores_train_log_cut.mean(), rmse_scores_train_log_depth.mean(), rmse_scores_train_log_table.mean(), rmse_scores_train_log_3.mean()]})

models.sort_values(by = 'RMSE Score (train data)', ascending = False, ignore_index = True)
# Out:
#                        Model  RMSE Score (train data)
# 0               All features                -0.085283
# 1              Depth Dropped                -0.085370
# 2              Table Dropped                -0.085618
# 3                Cut Dropped                -0.086410
# 4  Cut, Depth, Table Dropped                -0.088210

# %% [markdown]
# # <p style="background-color:#25316D;font-family:newtimeroman;color:#FEF5AC;font-size:80%;text-align:center;border-radius:10px 10px;"> MACHINE LEARNING MODELING II</p>

# %% [markdown]
# ## <p style="background-color:#25316D;font-family:newtimeroman;color:#FEF5AC;font-size:80%;text-align:center;border-radius:10px 10px;"> Pre-Processing</p>

# %%
# Karena CatBoost dapat melakukan handling fitur kategorikal secara internal
# Kita perlu mengubah fitur yang sudah dilakukan ordinal encoding ke kategorikal
# Ga semua algoritma butuh pre-processing lagi

X_train_cat = X_train_log.copy()
X_train_cat['clarity'] = X_train_cat['clarity'].map(str)
X_train_cat['cut'] = X_train_cat['cut'].map(str)
X_train_cat['color'] = X_train_cat['color'].map(str)
X_train_cat.drop(['table', 'depth'],axis=1, inplace=True)

X_test_cat = X_test_log.copy()
X_test_cat['clarity'] = X_test_cat['clarity'].map(str)
X_test_cat['cut'] = X_test_cat['cut'].map(str)
X_test_cat['color'] = X_test_cat['color'].map(str)
X_test_cat.drop(['table', 'depth'],axis=1, inplace=True)

# %% [markdown]
# Hyperparameter Tuning

# %% [markdown]
# ## <p style="background-color:#25316D;font-family:newtimeroman;color:#FEF5AC;font-size:80%;text-align:center;border-radius:10px 10px;"> Linear Regression</p>

# %% [markdown]
# Persamaan untuk multiple Linear Regression adalah

# %% [markdown]
# y = m1x1 + m2x2 + m3x3 +.......+ c

# %% [markdown]
# di mana c adalah intersep dan m1 adalah koefisien

# %%
lr = LinearRegression() #Create an instance of a LinearRegression() model named lr

start_linear_train = timer()
lr.fit(X_train_log, y_train_log) #train/ fit lr on training data
end_linear_train = timer()
train_time_lr = end_linear_train - start_linear_train


coeffecients = pd.DataFrame(lr.coef_,X_train_log.columns)
coeffecients.columns = ['Coeffecient']
print("Intercept value is {}".format(lr.intercept_))
coeffecients
# Out:
# Intercept value is 6.79264927627449
#          Coeffecient
# carat       1.613656
# cut         0.031006
# color       0.070086
# clarity     0.090515
# depth       0.006955
# table      -0.001319
# x           0.010846
# y           0.141072
# z          -0.055985

# %%
# Persamaan linear regression

# price = 11614.026*carat+265.29*color+320.38*clarity+117.36*cut-2212.10*x+1983.28*y-1886.22*z-27.23*table+30.10*depth+88.7

# %%
pred1=lr.predict(X_test_log)

# %%
pred2=lr.predict(X_train_log)

# %% [markdown]
# ### <p style="background-color:#25316D;font-family:newtimeroman;color:#FEF5AC;font-size:80%;text-align:center;border-radius:10px 10px;">Evaluasi Model</p>

# %%
# Error Distribution
plt.figure()
sns.histplot((y_test_log-pred1))

# MAE, MSE, RMSE & R-square
lr_rsquare=metrics.r2_score(y_test_log, pred1)
print('Mean Square Error:',metrics.mean_absolute_error(y_test_log, pred1))
print('Mean Square Error:',metrics.mean_squared_error(y_test_log, pred1))
print(' Root Mean Square Error:',np.sqrt(metrics.mean_squared_error(y_test_log, pred1)))
print('R Square:', metrics.r2_score(y_test_log,pred1))
# Out:
# Mean Square Error: 0.13733327363571146
# Mean Square Error: 0.029262109384592363
#  Root Mean Square Error: 0.17106171221109756
# R Square: 0.9693320484859135

# %%
# Error Distribution
plt.figure()
sns.histplot((y_train_log-pred2))

# MAE, MSE, RMSE & R-square
lr_rsquare=metrics.r2_score(y_train_log, pred2)
print('Mean Square Error:',metrics.mean_absolute_error(y_train_log, pred2))
print('Mean Square Error:',metrics.mean_squared_error(y_train_log, pred2))
print('Root Mean Square Error:',np.sqrt(metrics.mean_squared_error(y_train_log, pred2)))
print('R Square:', metrics.r2_score(y_train_log,pred2))
# Out:
# Mean Square Error: 0.13719690496054915
# Mean Square Error: 0.029587829837271894
# Root Mean Square Error: 0.17201113288758926
# R Square: 0.9692288936520698

# %%
rmse_scores_train_lr = cross_val_score(lr, X_train_log, y_train_log, cv=5, scoring='neg_root_mean_squared_error')
rmse_scores_test_lr = cross_val_score(lr, X_test_log, y_test_log, cv=5, scoring='neg_root_mean_squared_error')

# %%
# Sebelum Tuning

print("Hasil Cross-Validation RMSE (train data)")
print(f"Linear Regression: {rmse_scores_train_lr.mean()}")

print("Hasil Cross-Validation RMSE (test data)")
print(f"Linear Regression: {rmse_scores_test_lr.mean()}")
# Out:
# Hasil Cross-Validation RMSE (train data)
# Linear Regression: -0.17208466008740192
# Hasil Cross-Validation RMSE (test data)
# Linear Regression: -0.17111266503454076

# %%
parameters = {'copy_X': [True, False], 'fit_intercept': [True, False], 'positive':[True, False]}

print(lr.get_params())
# Out:
# {'copy_X': True, 'fit_intercept': True, 'n_jobs': None, 'positive': False}

# %%
grid_search = GridSearchCV(lr, parameters, scoring='r2', cv=5)
grid_search.fit(X_train_log, y_train_log)

print(grid_search.best_params_)
print(grid_search.best_score_)
# Out:
# {'copy_X': True, 'fit_intercept': True, 'positive': True}
# 0.96919731965016

# %%
lr2 = LinearRegression(copy_X= True, fit_intercept= True, positive= True)
lr2.fit(X_train_log, y_train_log)

pred3=lr2.predict(X_test_log)

# %%
# Error Distribution
plt.figure()
sns.histplot((y_test_log-pred3))

# MAE, MSE, RMSE & R-square
lr_rsquare=metrics.r2_score(y_test_log, pred3)
print('Mean Square Error:',metrics.mean_absolute_error(y_test_log, pred3))
print('Mean Square Error:',metrics.mean_squared_error(y_test_log, pred3))
print('Root Mean Square Error:',np.sqrt(metrics.mean_squared_error(y_test_log, pred3)))
print('R Square:', metrics.r2_score(y_test_log,pred3))
# Out:
# Mean Square Error: 0.1372858991434608
# Mean Square Error: 0.029250928435482153
# Root Mean Square Error: 0.1710290280492822
# R Square: 0.9693437666023584

# %%
rmse_scores_train_lr2 = cross_val_score(lr2, X_train_log, y_train_log, cv=5, scoring='neg_root_mean_squared_error')
rmse_scores_test_lr2 = cross_val_score(lr2, X_test_log, y_test_log, cv=5, scoring='neg_root_mean_squared_error')

# %%
# Setelah Tuning

print("Hasil Cross-Validation RMSE (train data)")
print(f"Linear Regression: {rmse_scores_train_lr2.mean()}")

print("Hasil Cross-Validation RMSE (test data)")
print(f"Linear Regression: {rmse_scores_test_lr2.mean()}")
# Out:
# Hasil Cross-Validation RMSE (train data)
# Linear Regression: -0.17207563604101211
# Hasil Cross-Validation RMSE (test data)
# Linear Regression: -0.17108645787790608

# %%
mae_scores_train_lr2 = cross_val_score(lr2, X_train_log, y_train_log, cv=5, scoring='neg_mean_absolute_error')
mae_scores_test_lr2 = cross_val_score(lr2, X_test_log, y_test_log, cv=5, scoring='neg_mean_absolute_error')

# %%
print("Hasil Cross-Validation MAE (train data)")
print(f"Linear Regression: {mae_scores_train_lr2.mean()}")

print("Hasil Cross-Validation MAE (test data)")
print(f"Linear Regression: {mae_scores_test_lr2.mean()}")
# Out:
# Hasil Cross-Validation MAE (train data)
# Linear Regression: -0.13723219132544523
# Hasil Cross-Validation MAE (test data)
# Linear Regression: -0.1372878029792815

# %%
models = pd.DataFrame({'Model': ['Sebelum Tuning', 'Sesudah Tuning'],
                       'RMSE Score (test data)': [rmse_scores_test_lr.mean(), rmse_scores_test_lr2.mean()]})

models.sort_values(by = 'RMSE Score (test data)', ascending = False, ignore_index = True)
# Out:
#             Model  RMSE Score (test data)
# 0  Sesudah Tuning               -0.171086
# 1  Sebelum Tuning               -0.171113

# %% [markdown]
# ## <p style="background-color:#25316D;font-family:newtimeroman;color:#FEF5AC;font-size:80%;text-align:center;border-radius:10px 10px;"> XGBoostRegressor</p>

# %%
X_train_log1 = X_train_log.copy()
X_train_log2 = X_train_log.copy()

y_train_log1 = y_train_log.copy()
y_train_log2 = y_train_log.copy()

# %%
# buat objek XGBRegressor
xgbrrs = XGBRegressor()

# tampilkan semua parameter
params = xgbrrs.get_params()
params
# Out:
# {'objective': 'reg:squarederror',
#  'base_score': None,
#  'booster': None,
#  'callbacks': None,
#  'colsample_bylevel': None,
#  'colsample_bynode': None,
#  'colsample_bytree': None,
#  'early_stopping_rounds': None,
#  'enable_categorical': False,
#  'eval_metric': None,
#  'feature_types': None,
#  'gamma': None,
#  'gpu_id': None,
#  'grow_policy': None,
#  'importance_type': None,
#  'interaction_constraints': None,
#  'learning_rate': None,
#  'max_bin': None,
#  'max_cat_threshold': None,
#  'max_cat_to_onehot': None,
#  'max_delta_step': None,
#  'max_depth': None,
#  'max_leaves': None,
#  'min_child_weight': None,
#  'missing': nan,
#  'monotone_constraints': None,
#  'n_estimators': 100,
#  'n_jobs': None,
#  'num_parallel_tree': None,
#  'predictor': None,
#  'random_state': None,
#  'reg_alpha': None,
#  'reg_lambda': None,
#  'sampling_method': None,
#  'scale_pos_weight': None,
#  'subsample': None,
#  'tree_method': None,
#  'validate_parameters': None,
#  'verbosity': None}

# %%
# create XGBoost model
model = XGBRegressor()

# fit the model with training data
model.fit(X_train_log1, y_train_log1)
# Out:
# XGBRegressor(base_score=None, booster=None, callbacks=None,
#              colsample_bylevel=None, colsample_bynode=None,
#              colsample_bytree=None, early_stopping_rounds=None,
#              enable_categorical=False, eval_metric=None, feature_types=None,
#              gamma=None, gpu_id=None, grow_policy=None, importance_type=None,
#              interaction_constraints=None, learning_rate=None, max_bin=None,
#              max_cat_threshold=None, max_cat_to_onehot=None,
#              max_delta_step=None, max_depth=None, max_leaves=None,
#              min_child_weight=None, missing=nan, monotone_constraints=None,
#              n_estimators=100, n_jobs=None, num_parallel_tree=None,
#              predictor=None, random_state=None, ...)

# %%
# evaluate the model on test data
y_pred = model.predict(X_test_log)

# evaluate the model
r2 = r2_score(y_test_log, y_pred)
mse = mean_squared_error(y_test_log, y_pred)
rmse = np.sqrt(mse)

print("R^2 score:", r2)
print("MSE:", mse)
print("RMSE:",rmse)
# Out:
# R^2 score: 0.9925010107205996
# MSE: 0.007155229930075661
# RMSE: 0.08458859219821348

# %%
# set hyperparameters for grid search
params = {
    'learning_rate': [0.15],
    'max_depth': [3, 4, 5],
    'n_estimators': [50, 100, 200, 300]
}

# create XGBoost model
model = XGBRegressor()

# perform grid search
grid = GridSearchCV(estimator=model, param_grid=params, cv=5)
grid.fit(X_train_log1, y_train_log1)

# best hyperparameters
print("Best hyperparameters:", grid.best_params_)
# Out:
# Best hyperparameters: {'learning_rate': 0.15, 'max_depth': 5, 'n_estimators': 300}

# %%
dtrain = xgb.DMatrix(data = X_train_log2, label = y_train_log2)

xgb_reg = xgb.XGBRegressor(objective ='reg:linear', learning_rate = 0.15, max_depth = 5, n_estimators = 300)
start_xgb_train = timer()
xgb_reg.fit(X_train_log2, y_train_log2)
end_xgb_train = timer()
train_time_xgb = end_xgb_train - start_xgb_train
# Out:
# [15:34:44] WARNING: ../src/objective/regression_obj.cu:213: reg:linear is now deprecated in favor of reg:squarederror.

# %%
# evaluate the model on test data
preds = xgb_reg.predict(X_test_log)

# evaluate the model
r2 = r2_score(y_test_log, preds)
mse = mean_squared_error(y_test_log, preds)
rmse = np.sqrt(mse)

print("R^2 score:", r2)
print("MSE:", mse)
print("RMSE:",rmse)
# Out:
# R^2 score: 0.992772681213889
# MSE: 0.006896013017998975
# RMSE: 0.08304223634993807

# %%
rmse_scores_train_xgb = cross_val_score(xgb_reg, X_train_log2, y_train_log2, cv=5, scoring='neg_root_mean_squared_error')
rmse_scores_test_xgb = cross_val_score(xgb_reg, X_test_log, y_test_log, cv=5, scoring='neg_root_mean_squared_error')
# Out:
# [15:34:53] WARNING: ../src/objective/regression_obj.cu:213: reg:linear is now deprecated in favor of reg:squarederror.
# [15:34:57] WARNING: ../src/objective/regression_obj.cu:213: reg:linear is now deprecated in favor of reg:squarederror.
# [15:35:05] WARNING: ../src/objective/regression_obj.cu:213: reg:linear is now deprecated in favor of reg:squarederror.
# [15:35:10] WARNING: ../src/objective/regression_obj.cu:213: reg:linear is now deprecated in favor of reg:squarederror.
# [15:35:17] WARNING: ../src/objective/regression_obj.cu:213: reg:linear is now deprecated in favor of reg:squarederror.
# [15:35:22] WARNING: ../src/objective/regression_obj.cu:213: reg:linear is now deprecated in favor of reg:squarederror.
# [15:35:25] WARNING: ../src/objective/regression_obj.cu:213: reg:linear is now deprecated in favor of reg:squarederror.
# [15:35:30] WARNING: ../src/objective/regression_obj.cu:213: reg:linear is now deprecated in favor of reg:squarederror.
# [15:35:32] WARNING: ../src/objective/regression_obj.cu:213: reg:linear is now deprecated in favor of reg:squarederror.
# [15:35:34] WARNING: ../src/objective/regression_obj.cu:213: reg:linear is now deprecated in favor of reg:squarederror.

# %%
print("Hasil Cross-Validation RMSE (train data)")
print(f"XGBRegressor: {rmse_scores_train_xgb.mean()}")

print("Hasil Cross-Validation RMSE (test data)")
print(f"XGBRegressor: {rmse_scores_test_xgb.mean()}")
# Out:
# Hasil Cross-Validation RMSE (train data)
# XGBRegressor: -0.08528296264850148
# Hasil Cross-Validation RMSE (test data)
# XGBRegressor: -0.08716601989105087

# %%
mae_scores_train_xgb = cross_val_score(xgb_reg, X_train_log2, y_train_log2, cv=5, scoring='neg_mean_absolute_error')
mae_scores_test_xgb = cross_val_score(xgb_reg, X_test_log, y_test_log, cv=5, scoring='neg_mean_absolute_error')
# Out:
# [15:35:36] WARNING: ../src/objective/regression_obj.cu:213: reg:linear is now deprecated in favor of reg:squarederror.
# [15:35:44] WARNING: ../src/objective/regression_obj.cu:213: reg:linear is now deprecated in favor of reg:squarederror.
# [15:35:49] WARNING: ../src/objective/regression_obj.cu:213: reg:linear is now deprecated in favor of reg:squarederror.
# [15:35:56] WARNING: ../src/objective/regression_obj.cu:213: reg:linear is now deprecated in favor of reg:squarederror.
# [15:36:01] WARNING: ../src/objective/regression_obj.cu:213: reg:linear is now deprecated in favor of reg:squarederror.
# [15:36:06] WARNING: ../src/objective/regression_obj.cu:213: reg:linear is now deprecated in favor of reg:squarederror.
# [15:36:11] WARNING: ../src/objective/regression_obj.cu:213: reg:linear is now deprecated in favor of reg:squarederror.
# [15:36:13] WARNING: ../src/objective/regression_obj.cu:213: reg:linear is now deprecated in favor of reg:squarederror.
# [15:36:15] WARNING: ../src/objective/regression_obj.cu:213: reg:linear is now deprecated in favor of reg:squarederror.
# [15:36:17] WARNING: ../src/objective/regression_obj.cu:213: reg:linear is now deprecated in favor of reg:squarederror.

# %%
print("Hasil Cross-Validation MAE (train data)")
print(f"XGBRegressor: {mae_scores_train_xgb.mean()}")

print("Hasil Cross-Validation MAE (test data)")
print(f"XGBRegressor: {mae_scores_test_xgb.mean()}")
# Out:
# Hasil Cross-Validation MAE (train data)
# XGBRegressor: -0.062141632631333835
# Hasil Cross-Validation MAE (test data)
# XGBRegressor: -0.06365182706146437

# %% [markdown]
# ## <p style="background-color:#25316D;font-family:newtimeroman;color:#FEF5AC;font-size:80%;text-align:center;border-radius:10px 10px;"> CatBoostRegressor</p>

# %% [markdown]
# Frame work modeling CatBoostRegressor
#
# Cari best parameter pake GridSearchCV -> Dari best parameter modeling pake iterasi tinggi di pipeline
#
#
# Kenapa pake CatBoost?
# - Out of the box, default parameternya bagus
# - Memiliki performa bagus di fitur kategori
# - Memiliki overfitting detector

# %%
# CatBoost using Auto Categorical
diamond_categories = np.array([1, 2, 3])

params = {'iterations':10000,
        'cat_features':diamond_categories,
        'verbose':False,
        'od_type':'Iter'}

cat_regressor = CatBoostRegressor(**params)
cat_regressor.fit(X_train_cat, y_train_log, eval_set=(X_test_cat, y_test_log), use_best_model=True, plot= True );
# Out:
# MetricVisualizer(layout=Layout(align_self='stretch', height='500px'))

# %% [markdown]
# ![Picture title](image-20230310-140338.png)

# %%
rmse_scores_train_cat = cross_val_score(cat_regressor, X_train_cat, y_train_log, cv=5, scoring='neg_root_mean_squared_error')
rmse_scores_test_cat = cross_val_score(cat_regressor, X_test_cat, y_test_log, cv=5, scoring='neg_root_mean_squared_error')

# %%
print("Hasil Cross-Validation RMSE (train data)")
print(f"CatBoost internal categorical: {rmse_scores_train_cat.mean()}")

print("Hasil Cross-Validation RMSE (test data)")
print(f"CatBoost internal categorical: {rmse_scores_test_cat.mean()}")
# Out:
# Hasil Cross-Validation RMSE (train data)
# CatBoost internal categorical: -0.08412170554546305
# Hasil Cross-Validation RMSE (test data)
# CatBoost internal categorical: -0.08619235972618064

# %%
# CatBoost No Auto Categorical (Manual Label Encoder)

params = {'iterations':10000,
        'verbose':False,
        'od_type':'Iter'}

cat_regressor_2 = CatBoostRegressor(**params)
start_cat_train = timer()
cat_regressor_2.fit(X_train_cat, y_train_log, eval_set=(X_test_cat, y_test_log), use_best_model=True, plot= True  );
end_cat_train = timer()
train_time_cat = (end_cat_train - start_cat_train)
# Out:
# MetricVisualizer(layout=Layout(align_self='stretch', height='500px'))

# %%
rmse_scores_train_nocat = cross_val_score(cat_regressor_2, X_train_log, y_train_log, cv=5, scoring='neg_root_mean_squared_error')
rmse_scores_test_nocat = cross_val_score(cat_regressor_2, X_test_log, y_test_log, cv=5, scoring='neg_root_mean_squared_error')

# %%
print("Hasil Cross-Validation RMSE (train data)")
print(f"CatBoost label encoder: {rmse_scores_train_nocat.mean()}")

print("Hasil Cross-Validation RMSE (test data)")
print(f"CatBoost label encoder: {rmse_scores_test_nocat.mean()}")
# Out:
# Hasil Cross-Validation RMSE (train data)
# CatBoost label encoder: -0.08289585090824016
# Hasil Cross-Validation RMSE (test data)
# CatBoost label encoder: -0.0847033124719891

# %% [markdown]
# ![Picture title](image-20230310-140455.png)

# %% [markdown]
# ### <p style="background-color:#25316D;font-family:newtimeroman;color:#FEF5AC;font-size:80%;text-align:center;border-radius:10px 10px;">GridSearchCV on  CatBoostRegressor</p>

# %%
from sklearn.model_selection import GridSearchCV

# In most cases, the optimal depth ranges from 4 to 10. Values in the range from 6 to 10 are recommended.
# Coefficient at the L2 regularization term of the cost function.

parameters = {
        'l2_leaf_reg': [2, 3, 4],
        'depth': [4, 6, 8],
        'iterations': [10000],
        'od_type':['Iter'],
        #'task_type':['GPU']
}

# %%
cat_regressor3 = CatBoostRegressor()

grid = GridSearchCV(estimator=cat_regressor3,
                param_grid = parameters,
                scoring='neg_root_mean_squared_error',
                cv=2,
                n_jobs=1)


grid.fit(X_train_cat, y_train_log)
# Out:
# Streaming output truncated to the last 5000 lines.
# 5000:	learn: 0.0664881	total: 57.5s	remaining: 57.5s
# 5001:	learn: 0.0664850	total: 57.5s	remaining: 57.5s
# 5002:	learn: 0.0664831	total: 57.5s	remaining: 57.5s
# 5003:	learn: 0.0664811	total: 57.5s	remaining: 57.4s
# 5004:	learn: 0.0664787	total: 57.5s	remaining: 57.4s
# 5005:	learn: 0.0664772	total: 57.5s	remaining: 57.4s
# 5006:	learn: 0.0664745	total: 57.6s	remaining: 57.4s
# 5007:	learn: 0.0664712	total: 57.6s	remaining: 57.4s
# 5008:	learn: 0.0664683	total: 57.6s	remaining: 57.4s
# 5009:	learn: 0.0664658	total: 57.6s	remaining: 57.4s
# 5010:	learn: 0.0664626	total: 57.6s	remaining: 57.3s
# 5011:	learn: 0.0664600	total: 57.6s	remaining: 57.3s
# 5012:	learn: 0.0664584	total: 57.6s	remaining: 57.3s
# 5013:	learn: 0.0664569	total: 57.6s	remaining: 57.3s
# 5014:	learn: 0.0664520	total: 57.6s	remaining: 57.3s
# 5015:	learn: 0.0664500	total: 57.6s	remaining: 57.3s
# 5016:	learn: 0.0664489	total: 57.6s	remaining: 57.3s
# 5017:	learn: 0.0664476	total: 57.7s	remaining: 57.2s
# 5018:	learn: 0.0664442	total: 57.7s	remaining: 57.2s
# 5019:	learn: 0.0664408	total: 57.7s	remaining: 57.2s
# 5020:	learn: 0.0664379	total: 57.7s	remaining: 57.2s
# 5021:	learn: 0.0664349	total: 57.7s	remaining: 57.2s
# 5022:	learn: 0.0664329	total: 57.7s	remaining: 57.2s
# 5023:	learn: 0.0664316	total: 57.7s	remaining: 57.2s
# 5024:	learn: 0.0664283	total: 57.7s	remaining: 57.1s
# 5025:	learn: 0.0664220	total: 57.7s	remaining: 57.1s
# 5026:	learn: 0.0664200	total: 57.7s	remaining: 57.1s
# 5027:	learn: 0.0664163	total: 57.7s	remaining: 57.1s
# 5028:	learn: 0.0664119	total: 57.8s	remaining: 57.1s
# 5029:	learn: 0.0664094	total: 57.8s	remaining: 57.1s
# 5030:	learn: 0.0664067	total: 57.8s	remaining: 57.1s
# 5031:	learn: 0.0664061	total: 57.8s	remaining: 57.1s
# 5032:	learn: 0.0664041	total: 57.8s	remaining: 57s
# 5033:	learn: 0.0664023	total: 57.8s	remaining: 57s
# 5034:	learn: 0.0664000	total: 57.8s	remaining: 57s
# 5035:	learn: 0.0663961	total: 57.8s	remaining: 57s
# 5036:	learn: 0.0663932	total: 57.8s	remaining: 57s
# 5037:	learn: 0.0663904	total: 57.9s	remaining: 57s
# 5038:	learn: 0.0663876	total: 57.9s	remaining: 57s
# 5039:	learn: 0.0663870	total: 57.9s	remaining: 57s
# 5040:	learn: 0.0663865	total: 57.9s	remaining: 56.9s
# 5041:	learn: 0.0663836	total: 57.9s	remaining: 56.9s
# 5042:	learn: 0.0663827	total: 57.9s	remaining: 56.9s
# 5043:	learn: 0.0663803	total: 57.9s	remaining: 56.9s
# 5044:	learn: 0.0663796	total: 57.9s	remaining: 56.9s
# 5045:	learn: 0.0663764	total: 57.9s	remaining: 56.9s
# 5046:	learn: 0.0663756	total: 57.9s	remaining: 56.9s
# 5047:	learn: 0.0663739	total: 57.9s	remaining: 56.8s
# 5048:	learn: 0.0663729	total: 57.9s	remaining: 56.8s
# 5049:	learn: 0.0663721	total: 58s	remaining: 56.8s
# 5050:	learn: 0.0663702	total: 58s	remaining: 56.8s
# 5051:	learn: 0.0663674	total: 58s	remaining: 56.8s
# 5052:	learn: 0.0663635	total: 58s	remaining: 56.8s
# 5053:	learn: 0.0663616	total: 58s	remaining: 56.8s
# 5054:	learn: 0.0663588	total: 58s	remaining: 56.7s
# 5055:	learn: 0.0663580	total: 58s	remaining: 56.7s
# 5056:	learn: 0.0663551	total: 58s	remaining: 56.7s
# 5057:	learn: 0.0663517	total: 58s	remaining: 56.7s
# 5058:	learn: 0.0663499	total: 58s	remaining: 56.7s
# 5059:	learn: 0.0663462	total: 58.1s	remaining: 56.7s
# 5060:	learn: 0.0663458	total: 58.1s	remaining: 56.7s
# 5061:	learn: 0.0663434	total: 58.1s	remaining: 56.6s
# 5062:	learn: 0.0663397	total: 58.1s	remaining: 56.6s
# 5063:	learn: 0.0663359	total: 58.1s	remaining: 56.6s
# 5064:	learn: 0.0663314	total: 58.1s	remaining: 56.6s
# 5065:	learn: 0.0663285	total: 58.1s	remaining: 56.6s
# 5066:	learn: 0.0663278	total: 58.1s	remaining: 56.6s
# 5067:	learn: 0.0663237	total: 58.1s	remaining: 56.6s
# 5068:	learn: 0.0663230	total: 58.1s	remaining: 56.6s
# 5069:	learn: 0.0663224	total: 58.1s	remaining: 56.5s
# 5070:	learn: 0.0663207	total: 58.2s	remaining: 56.5s
# 5071:	learn: 0.0663175	total: 58.2s	remaining: 56.5s
# 5072:	learn: 0.0663171	total: 58.2s	remaining: 56.5s
# 5073:	learn: 0.0663121	total: 58.2s	remaining: 56.5s
# 5074:	learn: 0.0663084	total: 58.2s	remaining: 56.5s
# 5075:	learn: 0.0663076	total: 58.2s	remaining: 56.5s
# 5076:	learn: 0.0663066	total: 58.2s	remaining: 56.4s
# 5077:	learn: 0.0663035	total: 58.2s	remaining: 56.4s
# 5078:	learn: 0.0663019	total: 58.2s	remaining: 56.4s
# 5079:	learn: 0.0663007	total: 58.3s	remaining: 56.4s
# 5080:	learn: 0.0662964	total: 58.3s	remaining: 56.4s
# 5081:	learn: 0.0662940	total: 58.3s	remaining: 56.4s
# 5082:	learn: 0.0662893	total: 58.3s	remaining: 56.4s
# 5083:	learn: 0.0662888	total: 58.3s	remaining: 56.4s
# 5084:	learn: 0.0662873	total: 58.3s	remaining: 56.3s
# 5085:	learn: 0.0662840	total: 58.3s	remaining: 56.3s
# 5086:	learn: 0.0662831	total: 58.3s	remaining: 56.3s
# 5087:	learn: 0.0662820	total: 58.3s	remaining: 56.3s
# 5088:	learn: 0.0662792	total: 58.3s	remaining: 56.3s
# 5089:	learn: 0.0662767	total: 58.3s	remaining: 56.3s
# 5090:	learn: 0.0662732	total: 58.4s	remaining: 56.3s
# 5091:	learn: 0.0662719	total: 58.4s	remaining: 56.3s
# 5092:	learn: 0.0662702	total: 58.4s	remaining: 56.2s
# 5093:	learn: 0.0662686	total: 58.4s	remaining: 56.2s
# 5094:	learn: 0.0662647	total: 58.4s	remaining: 56.2s
# 5095:	learn: 0.0662568	total: 58.4s	remaining: 56.2s
# 5096:	learn: 0.0662562	total: 58.4s	remaining: 56.2s
# 5097:	learn: 0.0662554	total: 58.4s	remaining: 56.2s
# 5098:	learn: 0.0662520	total: 58.4s	remaining: 56.2s
# 5099:	learn: 0.0662501	total: 58.4s	remaining: 56.1s
# 5100:	learn: 0.0662488	total: 58.4s	remaining: 56.1s
# 5101:	learn: 0.0662465	total: 58.5s	remaining: 56.1s
# 5102:	learn: 0.0662430	total: 58.5s	remaining: 56.1s
# 5103:	learn: 0.0662409	total: 58.5s	remaining: 56.1s
# 5104:	learn: 0.0662403	total: 58.5s	remaining: 56.1s
# 5105:	learn: 0.0662393	total: 58.5s	remaining: 56.1s
# 5106:	learn: 0.0662371	total: 58.5s	remaining: 56.1s
# 5107:	learn: 0.0662328	total: 58.5s	remaining: 56s
# 5108:	learn: 0.0662294	total: 58.5s	remaining: 56s
# 5109:	learn: 0.0662288	total: 58.5s	remaining: 56s
# 5110:	learn: 0.0662277	total: 58.5s	remaining: 56s
# 5111:	learn: 0.0662260	total: 58.5s	remaining: 56s
# 5112:	learn: 0.0662251	total: 58.6s	remaining: 56s
# 5113:	learn: 0.0662216	total: 58.6s	remaining: 56s
# 5114:	learn: 0.0662199	total: 58.6s	remaining: 55.9s
# 5115:	learn: 0.0662190	total: 58.6s	remaining: 55.9s
# 5116:	learn: 0.0662173	total: 58.6s	remaining: 55.9s
# 5117:	learn: 0.0662164	total: 58.6s	remaining: 55.9s
# 5118:	learn: 0.0662159	total: 58.6s	remaining: 55.9s
# 5119:	learn: 0.0662130	total: 58.6s	remaining: 55.9s
# 5120:	learn: 0.0662126	total: 58.6s	remaining: 55.9s
# 5121:	learn: 0.0662102	total: 58.6s	remaining: 55.8s
# 5122:	learn: 0.0662073	total: 58.6s	remaining: 55.8s
# 5123:	learn: 0.0662060	total: 58.7s	remaining: 55.8s
# 5124:	learn: 0.0662029	total: 58.7s	remaining: 55.8s
# 5125:	learn: 0.0662004	total: 58.7s	remaining: 55.8s
# 5126:	learn: 0.0661995	total: 58.7s	remaining: 55.8s
# 5127:	learn: 0.0661989	total: 58.7s	remaining: 55.8s
# 5128:	learn: 0.0661978	total: 58.7s	remaining: 55.7s
# 5129:	learn: 0.0661975	total: 58.7s	remaining: 55.7s
# 5130:	learn: 0.0661966	total: 58.7s	remaining: 55.7s
# 5131:	learn: 0.0661944	total: 58.7s	remaining: 55.7s
# 5132:	learn: 0.0661921	total: 58.7s	remaining: 55.7s
# 5133:	learn: 0.0661904	total: 58.7s	remaining: 55.7s
# 5134:	learn: 0.0661893	total: 58.8s	remaining: 55.7s
# 5135:	learn: 0.0661887	total: 58.8s	remaining: 55.6s
# 5136:	learn: 0.0661864	total: 58.8s	remaining: 55.6s
# 5137:	learn: 0.0661846	total: 58.8s	remaining: 55.6s
# 5138:	learn: 0.0661773	total: 58.8s	remaining: 55.6s
# 5139:	learn: 0.0661743	total: 58.8s	remaining: 55.6s
# 5140:	learn: 0.0661721	total: 58.8s	remaining: 55.6s
# 5141:	learn: 0.0661710	total: 58.8s	remaining: 55.6s
# 5142:	learn: 0.0661697	total: 58.8s	remaining: 55.5s
# 5143:	learn: 0.0661689	total: 58.8s	remaining: 55.5s
# 5144:	learn: 0.0661656	total: 58.8s	remaining: 55.5s
# 5145:	learn: 0.0661649	total: 58.9s	remaining: 55.5s
# 5146:	learn: 0.0661612	total: 58.9s	remaining: 55.5s
# 5147:	learn: 0.0661579	total: 58.9s	remaining: 55.5s
# 5148:	learn: 0.0661562	total: 58.9s	remaining: 55.5s
# 5149:	learn: 0.0661553	total: 58.9s	remaining: 55.5s
# 5150:	learn: 0.0661531	total: 58.9s	remaining: 55.4s
# 5151:	learn: 0.0661524	total: 58.9s	remaining: 55.4s
# 5152:	learn: 0.0661504	total: 58.9s	remaining: 55.4s
# 5153:	learn: 0.0661486	total: 58.9s	remaining: 55.4s
# 5154:	learn: 0.0661425	total: 58.9s	remaining: 55.4s
# 5155:	learn: 0.0661421	total: 58.9s	remaining: 55.4s
# 5156:	learn: 0.0661402	total: 59s	remaining: 55.4s
# 5157:	learn: 0.0661375	total: 59s	remaining: 55.3s
# 5158:	learn: 0.0661345	total: 59s	remaining: 55.3s
# 5159:	learn: 0.0661331	total: 59s	remaining: 55.3s
# 5160:	learn: 0.0661325	total: 59s	remaining: 55.3s
# 5161:	learn: 0.0661288	total: 59s	remaining: 55.3s
# 5162:	learn: 0.0661256	total: 59s	remaining: 55.3s
# 5163:	learn: 0.0661232	total: 59s	remaining: 55.3s
# 5164:	learn: 0.0661206	total: 59s	remaining: 55.3s
# 5165:	learn: 0.0661199	total: 59s	remaining: 55.2s
# 5166:	learn: 0.0661167	total: 59s	remaining: 55.2s
# 5167:	learn: 0.0661144	total: 59.1s	remaining: 55.2s
# 5168:	learn: 0.0661137	total: 59.1s	remaining: 55.2s
# 5169:	learn: 0.0661128	total: 59.1s	remaining: 55.2s
# 5170:	learn: 0.0661103	total: 59.1s	remaining: 55.2s
# 5171:	learn: 0.0661088	total: 59.1s	remaining: 55.2s
# 5172:	learn: 0.0661045	total: 59.1s	remaining: 55.1s
# 5173:	learn: 0.0661009	total: 59.1s	remaining: 55.1s
# 5174:	learn: 0.0661004	total: 59.1s	remaining: 55.1s
# 5175:	learn: 0.0660981	total: 59.1s	remaining: 55.1s
# 5176:	learn: 0.0660946	total: 59.1s	remaining: 55.1s
# 5177:	learn: 0.0660932	total: 59.1s	remaining: 55.1s
# 5178:	learn: 0.0660920	total: 59.2s	remaining: 55.1s
# 5179:	learn: 0.0660896	total: 59.2s	remaining: 55s
# 5180:	learn: 0.0660869	total: 59.2s	remaining: 55s
# 5181:	learn: 0.0660842	total: 59.2s	remaining: 55s
# 5182:	learn: 0.0660828	total: 59.2s	remaining: 55s
# 5183:	learn: 0.0660813	total: 59.2s	remaining: 55s
# 5184:	learn: 0.0660806	total: 59.2s	remaining: 55s
# 5185:	learn: 0.0660778	total: 59.2s	remaining: 55s
# 5186:	learn: 0.0660737	total: 59.2s	remaining: 55s
# 5187:	learn: 0.0660710	total: 59.2s	remaining: 55s
# 5188:	learn: 0.0660698	total: 59.3s	remaining: 54.9s
# 5189:	learn: 0.0660671	total: 59.3s	remaining: 54.9s
# 5190:	learn: 0.0660637	total: 59.3s	remaining: 54.9s
# 5191:	learn: 0.0660634	total: 59.3s	remaining: 54.9s
# 5192:	learn: 0.0660619	total: 59.3s	remaining: 54.9s
# 5193:	learn: 0.0660613	total: 59.3s	remaining: 54.9s
# 5194:	learn: 0.0660587	total: 59.3s	remaining: 54.9s
# 5195:	learn: 0.0660564	total: 59.3s	remaining: 54.8s
# 5196:	learn: 0.0660546	total: 59.3s	remaining: 54.8s
# 5197:	learn: 0.0660536	total: 59.3s	remaining: 54.8s
# 5198:	learn: 0.0660503	total: 59.4s	remaining: 54.8s
# 5199:	learn: 0.0660492	total: 59.4s	remaining: 54.8s
# 5200:	learn: 0.0660488	total: 59.4s	remaining: 54.8s
# 5201:	learn: 0.0660465	total: 59.4s	remaining: 54.8s
# 5202:	learn: 0.0660443	total: 59.4s	remaining: 54.8s
# 5203:	learn: 0.0660410	total: 59.4s	remaining: 54.7s
# 5204:	learn: 0.0660389	total: 59.4s	remaining: 54.7s
# 5205:	learn: 0.0660362	total: 59.4s	remaining: 54.7s
# 5206:	learn: 0.0660353	total: 59.4s	remaining: 54.7s
# 5207:	learn: 0.0660306	total: 59.4s	remaining: 54.7s
# 5208:	learn: 0.0660281	total: 59.4s	remaining: 54.7s
# 5209:	learn: 0.0660269	total: 59.4s	remaining: 54.7s
# 5210:	learn: 0.0660253	total: 59.5s	remaining: 54.6s
# 5211:	learn: 0.0660250	total: 59.5s	remaining: 54.6s
# 5212:	learn: 0.0660232	total: 59.5s	remaining: 54.6s
# 5213:	learn: 0.0660208	total: 59.5s	remaining: 54.6s
# 5214:	learn: 0.0660194	total: 59.5s	remaining: 54.6s
# 5215:	learn: 0.0660160	total: 59.5s	remaining: 54.6s
# 5216:	learn: 0.0660142	total: 59.5s	remaining: 54.6s
# 5217:	learn: 0.0660135	total: 59.5s	remaining: 54.5s
# 5218:	learn: 0.0660109	total: 59.5s	remaining: 54.5s
# 5219:	learn: 0.0660091	total: 59.5s	remaining: 54.5s
# 5220:	learn: 0.0660066	total: 59.5s	remaining: 54.5s
# 5221:	learn: 0.0660029	total: 59.6s	remaining: 54.5s
# 5222:	learn: 0.0660014	total: 59.6s	remaining: 54.5s
# 5223:	learn: 0.0659992	total: 59.6s	remaining: 54.5s
# 5224:	learn: 0.0659935	total: 59.6s	remaining: 54.5s
# 5225:	learn: 0.0659885	total: 59.6s	remaining: 54.4s
# 5226:	learn: 0.0659847	total: 59.6s	remaining: 54.4s
# 5227:	learn: 0.0659830	total: 59.6s	remaining: 54.4s
# 5228:	learn: 0.0659816	total: 59.6s	remaining: 54.4s
# 5229:	learn: 0.0659786	total: 59.6s	remaining: 54.4s
# 5230:	learn: 0.0659760	total: 59.6s	remaining: 54.4s
# 5231:	learn: 0.0659732	total: 59.6s	remaining: 54.4s
# 5232:	learn: 0.0659715	total: 59.7s	remaining: 54.4s
# 5233:	learn: 0.0659708	total: 59.7s	remaining: 54.3s
# 5234:	learn: 0.0659679	total: 59.7s	remaining: 54.3s
# 5235:	learn: 0.0659668	total: 59.7s	remaining: 54.3s
# 5236:	learn: 0.0659664	total: 59.7s	remaining: 54.3s
# 5237:	learn: 0.0659639	total: 59.7s	remaining: 54.3s
# 5238:	learn: 0.0659612	total: 59.7s	remaining: 54.3s
# 5239:	learn: 0.0659581	total: 59.7s	remaining: 54.3s
# 5240:	learn: 0.0659578	total: 59.7s	remaining: 54.3s
# 5241:	learn: 0.0659554	total: 59.8s	remaining: 54.2s
# 5242:	learn: 0.0659541	total: 59.8s	remaining: 54.2s
# 5243:	learn: 0.0659534	total: 59.8s	remaining: 54.2s
# 5244:	learn: 0.0659513	total: 59.8s	remaining: 54.2s
# 5245:	learn: 0.0659494	total: 59.8s	remaining: 54.2s
# 5246:	learn: 0.0659477	total: 59.8s	remaining: 54.2s
# 5247:	learn: 0.0659452	total: 59.8s	remaining: 54.2s
# 5248:	learn: 0.0659440	total: 59.8s	remaining: 54.1s
# 5249:	learn: 0.0659428	total: 59.8s	remaining: 54.1s
# 5250:	learn: 0.0659403	total: 59.8s	remaining: 54.1s
# 5251:	learn: 0.0659386	total: 59.8s	remaining: 54.1s
# 5252:	learn: 0.0659369	total: 59.9s	remaining: 54.1s
# 5253:	learn: 0.0659343	total: 59.9s	remaining: 54.1s
# 5254:	learn: 0.0659305	total: 59.9s	remaining: 54.1s
# 5255:	learn: 0.0659299	total: 59.9s	remaining: 54s
# 5256:	learn: 0.0659255	total: 59.9s	remaining: 54s
# 5257:	learn: 0.0659218	total: 59.9s	remaining: 54s
# 5258:	learn: 0.0659215	total: 59.9s	remaining: 54s
# 5259:	learn: 0.0659195	total: 59.9s	remaining: 54s
# 5260:	learn: 0.0659192	total: 59.9s	remaining: 54s
# 5261:	learn: 0.0659164	total: 59.9s	remaining: 54s
# 5262:	learn: 0.0659112	total: 59.9s	remaining: 54s
# 5263:	learn: 0.0659081	total: 60s	remaining: 53.9s
# 5264:	learn: 0.0659067	total: 60s	remaining: 53.9s
# 5265:	learn: 0.0659061	total: 60s	remaining: 53.9s
# 5266:	learn: 0.0659056	total: 60s	remaining: 53.9s
# 5267:	learn: 0.0659033	total: 60s	remaining: 53.9s
# 5268:	learn: 0.0659012	total: 60s	remaining: 53.9s
# 5269:	learn: 0.0659005	total: 1m	remaining: 53.9s
# 5270:	learn: 0.0658980	total: 1m	remaining: 53.8s
# 5271:	learn: 0.0658934	total: 1m	remaining: 53.8s
# 5272:	learn: 0.0658913	total: 1m	remaining: 53.8s
# 5273:	learn: 0.0658899	total: 1m	remaining: 53.8s
# 5274:	learn: 0.0658881	total: 1m	remaining: 53.8s
# 5275:	learn: 0.0658873	total: 1m	remaining: 53.8s
# 5276:	learn: 0.0658855	total: 1m	remaining: 53.8s
# 5277:	learn: 0.0658822	total: 1m	remaining: 53.8s
# 5278:	learn: 0.0658813	total: 1m	remaining: 53.7s
# 5279:	learn: 0.0658791	total: 1m	remaining: 53.7s
# 5280:	learn: 0.0658765	total: 1m	remaining: 53.7s
# 5281:	learn: 0.0658759	total: 1m	remaining: 53.7s
# 5282:	learn: 0.0658742	total: 1m	remaining: 53.7s
# 5283:	learn: 0.0658717	total: 1m	remaining: 53.7s
# 5284:	learn: 0.0658686	total: 1m	remaining: 53.7s
# 5285:	learn: 0.0658674	total: 1m	remaining: 53.7s
# 5286:	learn: 0.0658649	total: 1m	remaining: 53.6s
# 5287:	learn: 0.0658620	total: 1m	remaining: 53.6s
# 5288:	learn: 0.0658590	total: 1m	remaining: 53.6s
# 5289:	learn: 0.0658533	total: 1m	remaining: 53.6s
# 5290:	learn: 0.0658504	total: 1m	remaining: 53.6s
# 5291:	learn: 0.0658473	total: 1m	remaining: 53.6s
# 5292:	learn: 0.0658441	total: 1m	remaining: 53.6s
# 5293:	learn: 0.0658435	total: 1m	remaining: 53.6s
# 5294:	learn: 0.0658404	total: 1m	remaining: 53.5s
# 5295:	learn: 0.0658382	total: 1m	remaining: 53.5s
# 5296:	learn: 0.0658360	total: 1m	remaining: 53.5s
# 5297:	learn: 0.0658325	total: 1m	remaining: 53.5s
# 5298:	learn: 0.0658305	total: 1m	remaining: 53.5s
# 5299:	learn: 0.0658270	total: 1m	remaining: 53.5s
# 5300:	learn: 0.0658251	total: 1m	remaining: 53.5s
# 5301:	learn: 0.0658238	total: 1m	remaining: 53.5s
# 5302:	learn: 0.0658219	total: 1m	remaining: 53.4s
# 5303:	learn: 0.0658180	total: 1m	remaining: 53.4s
# 5304:	learn: 0.0658122	total: 1m	remaining: 53.4s
# 5305:	learn: 0.0658079	total: 1m	remaining: 53.4s
# 5306:	learn: 0.0658012	total: 1m	remaining: 53.4s
# 5307:	learn: 0.0657990	total: 1m	remaining: 53.4s
# 5308:	learn: 0.0657963	total: 1m	remaining: 53.4s
# 5309:	learn: 0.0657952	total: 1m	remaining: 53.4s
# 5310:	learn: 0.0657908	total: 1m	remaining: 53.4s
# 5311:	learn: 0.0657873	total: 1m	remaining: 53.3s
# 5312:	learn: 0.0657860	total: 1m	remaining: 53.3s
# 5313:	learn: 0.0657831	total: 1m	remaining: 53.3s
# 5314:	learn: 0.0657825	total: 1m	remaining: 53.3s
# 5315:	learn: 0.0657814	total: 1m	remaining: 53.3s
# 5316:	learn: 0.0657788	total: 1m	remaining: 53.3s
# 5317:	learn: 0.0657762	total: 1m	remaining: 53.3s
# 5318:	learn: 0.0657718	total: 1m	remaining: 53.3s
# 5319:	learn: 0.0657712	total: 1m	remaining: 53.2s
# 5320:	learn: 0.0657693	total: 1m	remaining: 53.2s
# 5321:	learn: 0.0657644	total: 1m	remaining: 53.2s
# 5322:	learn: 0.0657622	total: 1m	remaining: 53.2s
# 5323:	learn: 0.0657593	total: 1m	remaining: 53.2s
# 5324:	learn: 0.0657589	total: 1m	remaining: 53.2s
# 5325:	learn: 0.0657562	total: 1m	remaining: 53.2s
# 5326:	learn: 0.0657543	total: 1m	remaining: 53.2s
# 5327:	learn: 0.0657489	total: 1m	remaining: 53.1s
# 5328:	learn: 0.0657474	total: 1m	remaining: 53.1s
# 5329:	learn: 0.0657415	total: 1m	remaining: 53.1s
# 5330:	learn: 0.0657381	total: 1m	remaining: 53.1s
# 5331:	learn: 0.0657374	total: 1m	remaining: 53.1s
# 5332:	learn: 0.0657352	total: 1m	remaining: 53.1s
# 5333:	learn: 0.0657323	total: 1m	remaining: 53.1s
# 5334:	learn: 0.0657305	total: 1m	remaining: 53s
# 5335:	learn: 0.0657279	total: 1m	remaining: 53s
# 5336:	learn: 0.0657247	total: 1m	remaining: 53s
# 5337:	learn: 0.0657244	total: 1m	remaining: 53s
# 5338:	learn: 0.0657208	total: 1m	remaining: 53s
# 5339:	learn: 0.0657170	total: 1m	remaining: 53s
# 5340:	learn: 0.0657162	total: 1m	remaining: 53s
# 5341:	learn: 0.0657130	total: 1m	remaining: 53s
# 5342:	learn: 0.0657115	total: 1m	remaining: 52.9s
# 5343:	learn: 0.0657104	total: 1m	remaining: 52.9s
# 5344:	learn: 0.0657073	total: 1m	remaining: 52.9s
# 5345:	learn: 0.0657059	total: 1m	remaining: 52.9s
# 5346:	learn: 0.0657051	total: 1m	remaining: 52.9s
# 5347:	learn: 0.0657041	total: 1m	remaining: 52.9s
# 5348:	learn: 0.0657037	total: 1m	remaining: 52.9s
# 5349:	learn: 0.0657030	total: 1m	remaining: 52.8s
# 5350:	learn: 0.0657003	total: 1m	remaining: 52.8s
# 5351:	learn: 0.0656986	total: 1m	remaining: 52.8s
# 5352:	learn: 0.0656957	total: 1m	remaining: 52.8s
# 5353:	learn: 0.0656940	total: 1m	remaining: 52.8s
# 5354:	learn: 0.0656911	total: 1m	remaining: 52.8s
# 5355:	learn: 0.0656904	total: 1m	remaining: 52.8s
# 5356:	learn: 0.0656890	total: 1m	remaining: 52.7s
# 5357:	learn: 0.0656877	total: 1m	remaining: 52.7s
# 5358:	learn: 0.0656856	total: 1m	remaining: 52.7s
# 5359:	learn: 0.0656831	total: 1m	remaining: 52.7s
# 5360:	learn: 0.0656825	total: 1m	remaining: 52.7s
# 5361:	learn: 0.0656818	total: 1m	remaining: 52.7s
# 5362:	learn: 0.0656785	total: 1m	remaining: 52.7s
# 5363:	learn: 0.0656760	total: 1m	remaining: 52.7s
# 5364:	learn: 0.0656725	total: 1m	remaining: 52.6s
# 5365:	learn: 0.0656697	total: 1m	remaining: 52.6s
# 5366:	learn: 0.0656652	total: 1m	remaining: 52.6s
# 5367:	learn: 0.0656647	total: 1m	remaining: 52.6s
# 5368:	learn: 0.0656607	total: 1m	remaining: 52.6s
# 5369:	learn: 0.0656571	total: 1m	remaining: 52.6s
# 5370:	learn: 0.0656547	total: 1m	remaining: 52.6s
# 5371:	learn: 0.0656528	total: 1m 1s	remaining: 52.6s
# 5372:	learn: 0.0656509	total: 1m 1s	remaining: 52.5s
# 5373:	learn: 0.0656479	total: 1m 1s	remaining: 52.5s
# 5374:	learn: 0.0656465	total: 1m 1s	remaining: 52.5s
# 5375:	learn: 0.0656457	total: 1m 1s	remaining: 52.5s
# 5376:	learn: 0.0656450	total: 1m 1s	remaining: 52.5s
# 5377:	learn: 0.0656428	total: 1m 1s	remaining: 52.5s
# 5378:	learn: 0.0656406	total: 1m 1s	remaining: 52.5s
# 5379:	learn: 0.0656380	total: 1m 1s	remaining: 52.4s
# 5380:	learn: 0.0656359	total: 1m 1s	remaining: 52.4s
# 5381:	learn: 0.0656328	total: 1m 1s	remaining: 52.4s
# 5382:	learn: 0.0656302	total: 1m 1s	remaining: 52.4s
# 5383:	learn: 0.0656276	total: 1m 1s	remaining: 52.4s
# 5384:	learn: 0.0656250	total: 1m 1s	remaining: 52.4s
# 5385:	learn: 0.0656216	total: 1m 1s	remaining: 52.4s
# 5386:	learn: 0.0656200	total: 1m 1s	remaining: 52.4s
# 5387:	learn: 0.0656144	total: 1m 1s	remaining: 52.3s
# 5388:	learn: 0.0656100	total: 1m 1s	remaining: 52.3s
# 5389:	learn: 0.0656080	total: 1m 1s	remaining: 52.3s
# 5390:	learn: 0.0656075	total: 1m 1s	remaining: 52.3s
# 5391:	learn: 0.0656062	total: 1m 1s	remaining: 52.3s
# 5392:	learn: 0.0656035	total: 1m 1s	remaining: 52.3s
# 5393:	learn: 0.0656007	total: 1m 1s	remaining: 52.3s
# 5394:	learn: 0.0655967	total: 1m 1s	remaining: 52.3s
# 5395:	learn: 0.0655943	total: 1m 1s	remaining: 52.2s
# 5396:	learn: 0.0655928	total: 1m 1s	remaining: 52.2s
# 5397:	learn: 0.0655920	total: 1m 1s	remaining: 52.2s
# 5398:	learn: 0.0655914	total: 1m 1s	remaining: 52.2s
# 5399:	learn: 0.0655909	total: 1m 1s	remaining: 52.2s
# 5400:	learn: 0.0655878	total: 1m 1s	remaining: 52.2s
# 5401:	learn: 0.0655855	total: 1m 1s	remaining: 52.2s
# 5402:	learn: 0.0655848	total: 1m 1s	remaining: 52.1s
# 5403:	learn: 0.0655841	total: 1m 1s	remaining: 52.1s
# 5404:	learn: 0.0655801	total: 1m 1s	remaining: 52.1s
# 5405:	learn: 0.0655768	total: 1m 1s	remaining: 52.1s
# 5406:	learn: 0.0655754	total: 1m 1s	remaining: 52.1s
# 5407:	learn: 0.0655724	total: 1m 1s	remaining: 52.1s
# 5408:	learn: 0.0655721	total: 1m 1s	remaining: 52.1s
# 5409:	learn: 0.0655702	total: 1m 1s	remaining: 52.1s
# 5410:	learn: 0.0655679	total: 1m 1s	remaining: 52.1s
# 5411:	learn: 0.0655625	total: 1m 1s	remaining: 52s
# 5412:	learn: 0.0655563	total: 1m 1s	remaining: 52s
# 5413:	learn: 0.0655552	total: 1m 1s	remaining: 52s
# 5414:	learn: 0.0655543	total: 1m 1s	remaining: 52s
# 5415:	learn: 0.0655523	total: 1m 1s	remaining: 52s
# 5416:	learn: 0.0655518	total: 1m 1s	remaining: 52s
# 5417:	learn: 0.0655490	total: 1m 1s	remaining: 52s
# 5418:	learn: 0.0655487	total: 1m 1s	remaining: 52s
# 5419:	learn: 0.0655472	total: 1m 1s	remaining: 51.9s
# 5420:	learn: 0.0655434	total: 1m 1s	remaining: 51.9s
# 5421:	learn: 0.0655427	total: 1m 1s	remaining: 51.9s
# 5422:	learn: 0.0655404	total: 1m 1s	remaining: 51.9s
# 5423:	learn: 0.0655386	total: 1m 1s	remaining: 51.9s
# 5424:	learn: 0.0655377	total: 1m 1s	remaining: 51.9s
# 5425:	learn: 0.0655356	total: 1m 1s	remaining: 51.9s
# 5426:	learn: 0.0655331	total: 1m 1s	remaining: 51.8s
# 5427:	learn: 0.0655306	total: 1m 1s	remaining: 51.8s
# 5428:	learn: 0.0655298	total: 1m 1s	remaining: 51.8s
# 5429:	learn: 0.0655291	total: 1m 1s	remaining: 51.8s
# 5430:	learn: 0.0655267	total: 1m 1s	remaining: 51.8s
# 5431:	learn: 0.0655261	total: 1m 1s	remaining: 51.8s
# 5432:	learn: 0.0655225	total: 1m 1s	remaining: 51.8s
# 5433:	learn: 0.0655187	total: 1m 1s	remaining: 51.8s
# 5434:	learn: 0.0655163	total: 1m 1s	remaining: 51.7s
# 5435:	learn: 0.0655157	total: 1m 1s	remaining: 51.7s
# 5436:	learn: 0.0655144	total: 1m 1s	remaining: 51.7s
# 5437:	learn: 0.0655097	total: 1m 1s	remaining: 51.7s
# 5438:	learn: 0.0655030	total: 1m 1s	remaining: 51.7s
# 5439:	learn: 0.0655013	total: 1m 1s	remaining: 51.7s
# 5440:	learn: 0.0655004	total: 1m 1s	remaining: 51.7s
# 5441:	learn: 0.0654984	total: 1m 1s	remaining: 51.6s
# 5442:	learn: 0.0654971	total: 1m 1s	remaining: 51.6s
# 5443:	learn: 0.0654950	total: 1m 1s	remaining: 51.6s
# 5444:	learn: 0.0654941	total: 1m 1s	remaining: 51.6s
# 5445:	learn: 0.0654939	total: 1m 1s	remaining: 51.6s
# 5446:	learn: 0.0654924	total: 1m 1s	remaining: 51.6s
# 5447:	learn: 0.0654892	total: 1m 1s	remaining: 51.6s
# 5448:	learn: 0.0654861	total: 1m 1s	remaining: 51.6s
# 5449:	learn: 0.0654820	total: 1m 1s	remaining: 51.5s
# 5450:	learn: 0.0654815	total: 1m 1s	remaining: 51.5s
# 5451:	learn: 0.0654794	total: 1m 1s	remaining: 51.5s
# 5452:	learn: 0.0654776	total: 1m 1s	remaining: 51.5s
# 5453:	learn: 0.0654764	total: 1m 1s	remaining: 51.5s
# 5454:	learn: 0.0654725	total: 1m 1s	remaining: 51.5s
# 5455:	learn: 0.0654714	total: 1m 1s	remaining: 51.5s
# 5456:	learn: 0.0654671	total: 1m 1s	remaining: 51.5s
# 5457:	learn: 0.0654613	total: 1m 1s	remaining: 51.4s
# 5458:	learn: 0.0654567	total: 1m 1s	remaining: 51.4s
# 5459:	learn: 0.0654562	total: 1m 1s	remaining: 51.4s
# 5460:	learn: 0.0654533	total: 1m 1s	remaining: 51.4s
# 5461:	learn: 0.0654509	total: 1m 1s	remaining: 51.4s
# 5462:	learn: 0.0654498	total: 1m 1s	remaining: 51.4s
# 5463:	learn: 0.0654492	total: 1m 1s	remaining: 51.4s
# 5464:	learn: 0.0654457	total: 1m 1s	remaining: 51.3s
# 5465:	learn: 0.0654418	total: 1m 1s	remaining: 51.3s
# 5466:	learn: 0.0654389	total: 1m 1s	remaining: 51.3s
# 5467:	learn: 0.0654342	total: 1m 1s	remaining: 51.3s
# 5468:	learn: 0.0654325	total: 1m 1s	remaining: 51.3s
# 5469:	learn: 0.0654291	total: 1m 1s	remaining: 51.3s
# 5470:	learn: 0.0654262	total: 1m 1s	remaining: 51.3s
# 5471:	learn: 0.0654231	total: 1m 1s	remaining: 51.3s
# 5472:	learn: 0.0654225	total: 1m 1s	remaining: 51.3s
# 5473:	learn: 0.0654187	total: 1m 1s	remaining: 51.2s
# 5474:	learn: 0.0654161	total: 1m 1s	remaining: 51.2s
# 5475:	learn: 0.0654156	total: 1m 1s	remaining: 51.2s
# 5476:	learn: 0.0654135	total: 1m 1s	remaining: 51.2s
# 5477:	learn: 0.0654103	total: 1m 2s	remaining: 51.2s
# 5478:	learn: 0.0654078	total: 1m 2s	remaining: 51.2s
# 5479:	learn: 0.0654061	total: 1m 2s	remaining: 51.2s
# 5480:	learn: 0.0654032	total: 1m 2s	remaining: 51.2s
# 5481:	learn: 0.0654003	total: 1m 2s	remaining: 51.1s
# 5482:	learn: 0.0653981	total: 1m 2s	remaining: 51.1s
# 5483:	learn: 0.0653962	total: 1m 2s	remaining: 51.1s
# 5484:	learn: 0.0653942	total: 1m 2s	remaining: 51.1s
# 5485:	learn: 0.0653910	total: 1m 2s	remaining: 51.1s
# 5486:	learn: 0.0653902	total: 1m 2s	remaining: 51.1s
# 5487:	learn: 0.0653900	total: 1m 2s	remaining: 51.1s
# 5488:	learn: 0.0653889	total: 1m 2s	remaining: 51s
# 5489:	learn: 0.0653846	total: 1m 2s	remaining: 51s
# 5490:	learn: 0.0653827	total: 1m 2s	remaining: 51s
# 5491:	learn: 0.0653821	total: 1m 2s	remaining: 51s
# 5492:	learn: 0.0653799	total: 1m 2s	remaining: 51s
# 5493:	learn: 0.0653789	total: 1m 2s	remaining: 51s
# 5494:	learn: 0.0653747	total: 1m 2s	remaining: 51s
# 5495:	learn: 0.0653739	total: 1m 2s	remaining: 51s
# 5496:	learn: 0.0653731	total: 1m 2s	remaining: 51s
# 5497:	learn: 0.0653728	total: 1m 2s	remaining: 50.9s
# 5498:	learn: 0.0653708	total: 1m 2s	remaining: 50.9s
# 5499:	learn: 0.0653702	total: 1m 2s	remaining: 50.9s
# 5500:	learn: 0.0653691	total: 1m 2s	remaining: 50.9s
# 5501:	learn: 0.0653669	total: 1m 2s	remaining: 50.9s
# 5502:	learn: 0.0653645	total: 1m 2s	remaining: 50.9s
# 5503:	learn: 0.0653626	total: 1m 2s	remaining: 50.9s
# 5504:	learn: 0.0653579	total: 1m 2s	remaining: 50.8s
# 5505:	learn: 0.0653544	total: 1m 2s	remaining: 50.8s
# 5506:	learn: 0.0653533	total: 1m 2s	remaining: 50.8s
# 5507:	learn: 0.0653507	total: 1m 2s	remaining: 50.8s
# 5508:	learn: 0.0653471	total: 1m 2s	remaining: 50.8s
# 5509:	learn: 0.0653468	total: 1m 2s	remaining: 50.8s
# 5510:	learn: 0.0653437	total: 1m 2s	remaining: 50.8s
# 5511:	learn: 0.0653430	total: 1m 2s	remaining: 50.8s
# 5512:	learn: 0.0653406	total: 1m 2s	remaining: 50.8s
# 5513:	learn: 0.0653376	total: 1m 2s	remaining: 50.7s
# 5514:	learn: 0.0653335	total: 1m 2s	remaining: 50.7s
# 5515:	learn: 0.0653323	total: 1m 2s	remaining: 50.7s
# 5516:	learn: 0.0653296	total: 1m 2s	remaining: 50.7s
# 5517:	learn: 0.0653260	total: 1m 2s	remaining: 50.7s
# 5518:	learn: 0.0653255	total: 1m 2s	remaining: 50.7s
# 5519:	learn: 0.0653221	total: 1m 2s	remaining: 50.7s
# 5520:	learn: 0.0653216	total: 1m 2s	remaining: 50.6s
# 5521:	learn: 0.0653171	total: 1m 2s	remaining: 50.6s
# 5522:	learn: 0.0653163	total: 1m 2s	remaining: 50.6s
# 5523:	learn: 0.0653144	total: 1m 2s	remaining: 50.6s
# 5524:	learn: 0.0653118	total: 1m 2s	remaining: 50.6s
# 5525:	learn: 0.0653107	total: 1m 2s	remaining: 50.6s
# 5526:	learn: 0.0653073	total: 1m 2s	remaining: 50.6s
# 5527:	learn: 0.0653068	total: 1m 2s	remaining: 50.5s
# 5528:	learn: 0.0653065	total: 1m 2s	remaining: 50.5s
# 5529:	learn: 0.0653024	total: 1m 2s	remaining: 50.5s
# 5530:	learn: 0.0652990	total: 1m 2s	remaining: 50.5s
# 5531:	learn: 0.0652962	total: 1m 2s	remaining: 50.5s
# 5532:	learn: 0.0652958	total: 1m 2s	remaining: 50.5s
# 5533:	learn: 0.0652908	total: 1m 2s	remaining: 50.5s
# 5534:	learn: 0.0652886	total: 1m 2s	remaining: 50.5s
# 5535:	learn: 0.0652872	total: 1m 2s	remaining: 50.5s
# 5536:	learn: 0.0652842	total: 1m 2s	remaining: 50.4s
# 5537:	learn: 0.0652832	total: 1m 2s	remaining: 50.4s
# 5538:	learn: 0.0652807	total: 1m 2s	remaining: 50.4s
# 5539:	learn: 0.0652782	total: 1m 2s	remaining: 50.4s
# 5540:	learn: 0.0652768	total: 1m 2s	remaining: 50.4s
# 5541:	learn: 0.0652740	total: 1m 2s	remaining: 50.4s
# 5542:	learn: 0.0652732	total: 1m 2s	remaining: 50.4s
# 5543:	learn: 0.0652703	total: 1m 2s	remaining: 50.3s
# 5544:	learn: 0.0652674	total: 1m 2s	remaining: 50.3s
# 5545:	learn: 0.0652663	total: 1m 2s	remaining: 50.3s
# 5546:	learn: 0.0652615	total: 1m 2s	remaining: 50.3s
# 5547:	learn: 0.0652578	total: 1m 2s	remaining: 50.3s
# 5548:	learn: 0.0652571	total: 1m 2s	remaining: 50.3s
# 5549:	learn: 0.0652513	total: 1m 2s	remaining: 50.3s
# 5550:	learn: 0.0652494	total: 1m 2s	remaining: 50.3s
# 5551:	learn: 0.0652466	total: 1m 2s	remaining: 50.2s
# 5552:	learn: 0.0652441	total: 1m 2s	remaining: 50.2s
# 5553:	learn: 0.0652415	total: 1m 2s	remaining: 50.2s
# 5554:	learn: 0.0652409	total: 1m 2s	remaining: 50.2s
# 5555:	learn: 0.0652388	total: 1m 2s	remaining: 50.2s
# 5556:	learn: 0.0652377	total: 1m 2s	remaining: 50.2s
# 5557:	learn: 0.0652371	total: 1m 2s	remaining: 50.2s
# 5558:	learn: 0.0652360	total: 1m 2s	remaining: 50.2s
# 5559:	learn: 0.0652345	total: 1m 2s	remaining: 50.1s
# 5560:	learn: 0.0652338	total: 1m 2s	remaining: 50.1s
# 5561:	learn: 0.0652320	total: 1m 2s	remaining: 50.1s
# 5562:	learn: 0.0652304	total: 1m 2s	remaining: 50.1s
# 5563:	learn: 0.0652272	total: 1m 2s	remaining: 50.1s
# 5564:	learn: 0.0652252	total: 1m 2s	remaining: 50.1s
# 5565:	learn: 0.0652229	total: 1m 2s	remaining: 50.1s
# 5566:	learn: 0.0652221	total: 1m 2s	remaining: 50s
# 5567:	learn: 0.0652194	total: 1m 2s	remaining: 50s
# 5568:	learn: 0.0652142	total: 1m 2s	remaining: 50s
# 5569:	learn: 0.0652132	total: 1m 2s	remaining: 50s
# 5570:	learn: 0.0652097	total: 1m 2s	remaining: 50s
# 5571:	learn: 0.0652079	total: 1m 2s	remaining: 50s
# 5572:	learn: 0.0652035	total: 1m 2s	remaining: 50s
# 5573:	learn: 0.0652015	total: 1m 2s	remaining: 50s
# 5574:	learn: 0.0651988	total: 1m 2s	remaining: 49.9s
# 5575:	learn: 0.0651979	total: 1m 2s	remaining: 49.9s
# 5576:	learn: 0.0651961	total: 1m 2s	remaining: 49.9s
# 5577:	learn: 0.0651942	total: 1m 2s	remaining: 49.9s
# 5578:	learn: 0.0651924	total: 1m 2s	remaining: 49.9s
# 5579:	learn: 0.0651904	total: 1m 2s	remaining: 49.9s
# 5580:	learn: 0.0651875	total: 1m 2s	remaining: 49.9s
# 5581:	learn: 0.0651867	total: 1m 2s	remaining: 49.9s
# 5582:	learn: 0.0651810	total: 1m 3s	remaining: 49.8s
# 5583:	learn: 0.0651790	total: 1m 3s	remaining: 49.8s
# 5584:	learn: 0.0651773	total: 1m 3s	remaining: 49.8s
# 5585:	learn: 0.0651740	total: 1m 3s	remaining: 49.8s
# 5586:	learn: 0.0651711	total: 1m 3s	remaining: 49.8s
# 5587:	learn: 0.0651701	total: 1m 3s	remaining: 49.8s
# 5588:	learn: 0.0651689	total: 1m 3s	remaining: 49.8s
# 5589:	learn: 0.0651682	total: 1m 3s	remaining: 49.8s
# 5590:	learn: 0.0651659	total: 1m 3s	remaining: 49.7s
# 5591:	learn: 0.0651632	total: 1m 3s	remaining: 49.7s
# 5592:	learn: 0.0651627	total: 1m 3s	remaining: 49.7s
# 5593:	learn: 0.0651617	total: 1m 3s	remaining: 49.7s
# 5594:	learn: 0.0651609	total: 1m 3s	remaining: 49.7s
# 5595:	learn: 0.0651579	total: 1m 3s	remaining: 49.7s
# 5596:	learn: 0.0651573	total: 1m 3s	remaining: 49.7s
# 5597:	learn: 0.0651569	total: 1m 3s	remaining: 49.6s
# 5598:	learn: 0.0651556	total: 1m 3s	remaining: 49.6s
# 5599:	learn: 0.0651524	total: 1m 3s	remaining: 49.6s
# 5600:	learn: 0.0651517	total: 1m 3s	remaining: 49.6s
# 5601:	learn: 0.0651509	total: 1m 3s	remaining: 49.6s
# 5602:	learn: 0.0651500	total: 1m 3s	remaining: 49.6s
# 5603:	learn: 0.0651468	total: 1m 3s	remaining: 49.6s
# 5604:	learn: 0.0651461	total: 1m 3s	remaining: 49.6s
# 5605:	learn: 0.0651423	total: 1m 3s	remaining: 49.6s
# 5606:	learn: 0.0651395	total: 1m 3s	remaining: 49.5s
# 5607:	learn: 0.0651388	total: 1m 3s	remaining: 49.5s
# 5608:	learn: 0.0651376	total: 1m 3s	remaining: 49.5s
# 5609:	learn: 0.0651372	total: 1m 3s	remaining: 49.5s
# 5610:	learn: 0.0651365	total: 1m 3s	remaining: 49.5s
# 5611:	learn: 0.0651358	total: 1m 3s	remaining: 49.5s
# 5612:	learn: 0.0651349	total: 1m 3s	remaining: 49.5s
# 5613:	learn: 0.0651322	total: 1m 3s	remaining: 49.5s
# 5614:	learn: 0.0651297	total: 1m 3s	remaining: 49.4s
# 5615:	learn: 0.0651265	total: 1m 3s	remaining: 49.4s
# 5616:	learn: 0.0651237	total: 1m 3s	remaining: 49.4s
# 5617:	learn: 0.0651214	total: 1m 3s	remaining: 49.4s
# 5618:	learn: 0.0651206	total: 1m 3s	remaining: 49.4s
# 5619:	learn: 0.0651164	total: 1m 3s	remaining: 49.4s
# 5620:	learn: 0.0651121	total: 1m 3s	remaining: 49.4s
# 5621:	learn: 0.0651116	total: 1m 3s	remaining: 49.3s
# 5622:	learn: 0.0651085	total: 1m 3s	remaining: 49.3s
# 5623:	learn: 0.0651080	total: 1m 3s	remaining: 49.3s
# 5624:	learn: 0.0651053	total: 1m 3s	remaining: 49.3s
# 5625:	learn: 0.0651020	total: 1m 3s	remaining: 49.3s
# 5626:	learn: 0.0650989	total: 1m 3s	remaining: 49.3s
# 5627:	learn: 0.0650985	total: 1m 3s	remaining: 49.3s
# 5628:	learn: 0.0650936	total: 1m 3s	remaining: 49.3s
# 5629:	learn: 0.0650919	total: 1m 3s	remaining: 49.2s
# 5630:	learn: 0.0650900	total: 1m 3s	remaining: 49.2s
# 5631:	learn: 0.0650891	total: 1m 3s	remaining: 49.2s
# 5632:	learn: 0.0650870	total: 1m 3s	remaining: 49.2s
# 5633:	learn: 0.0650834	total: 1m 3s	remaining: 49.2s
# 5634:	learn: 0.0650804	total: 1m 3s	remaining: 49.2s
# 5635:	learn: 0.0650799	total: 1m 3s	remaining: 49.2s
# 5636:	learn: 0.0650745	total: 1m 3s	remaining: 49.2s
# 5637:	learn: 0.0650736	total: 1m 3s	remaining: 49.1s
# 5638:	learn: 0.0650727	total: 1m 3s	remaining: 49.1s
# 5639:	learn: 0.0650700	total: 1m 3s	remaining: 49.1s
# 5640:	learn: 0.0650667	total: 1m 3s	remaining: 49.1s
# 5641:	learn: 0.0650657	total: 1m 3s	remaining: 49.1s
# 5642:	learn: 0.0650643	total: 1m 3s	remaining: 49.1s
# 5643:	learn: 0.0650638	total: 1m 3s	remaining: 49.1s
# 5644:	learn: 0.0650630	total: 1m 3s	remaining: 49.1s
# 5645:	learn: 0.0650624	total: 1m 3s	remaining: 49s
# 5646:	learn: 0.0650606	total: 1m 3s	remaining: 49s
# 5647:	learn: 0.0650572	total: 1m 3s	remaining: 49s
# 5648:	learn: 0.0650523	total: 1m 3s	remaining: 49s
# 5649:	learn: 0.0650504	total: 1m 3s	remaining: 49s
# 5650:	learn: 0.0650478	total: 1m 3s	remaining: 49s
# 5651:	learn: 0.0650448	total: 1m 3s	remaining: 49s
# 5652:	learn: 0.0650434	total: 1m 3s	remaining: 49s
# 5653:	learn: 0.0650427	total: 1m 3s	remaining: 48.9s
# 5654:	learn: 0.0650422	total: 1m 3s	remaining: 48.9s
# 5655:	learn: 0.0650419	total: 1m 3s	remaining: 48.9s
# 5656:	learn: 0.0650414	total: 1m 3s	remaining: 48.9s
# 5657:	learn: 0.0650405	total: 1m 3s	remaining: 48.9s
# 5658:	learn: 0.0650373	total: 1m 3s	remaining: 48.9s
# 5659:	learn: 0.0650347	total: 1m 3s	remaining: 48.9s
# 5660:	learn: 0.0650342	total: 1m 3s	remaining: 48.8s
# 5661:	learn: 0.0650309	total: 1m 3s	remaining: 48.8s
# 5662:	learn: 0.0650300	total: 1m 3s	remaining: 48.8s
# 5663:	learn: 0.0650291	total: 1m 3s	remaining: 48.8s
# 5664:	learn: 0.0650259	total: 1m 3s	remaining: 48.8s
# 5665:	learn: 0.0650204	total: 1m 3s	remaining: 48.8s
# 5666:	learn: 0.0650173	total: 1m 3s	remaining: 48.8s
# 5667:	learn: 0.0650122	total: 1m 3s	remaining: 48.8s
# 5668:	learn: 0.0650098	total: 1m 3s	remaining: 48.8s
# 5669:	learn: 0.0650095	total: 1m 3s	remaining: 48.7s
# 5670:	learn: 0.0650058	total: 1m 3s	remaining: 48.7s
# 5671:	learn: 0.0650038	total: 1m 3s	remaining: 48.7s
# 5672:	learn: 0.0650005	total: 1m 3s	remaining: 48.7s
# 5673:	learn: 0.0649975	total: 1m 3s	remaining: 48.7s
# 5674:	learn: 0.0649949	total: 1m 3s	remaining: 48.7s
# 5675:	learn: 0.0649925	total: 1m 3s	remaining: 48.7s
# 5676:	learn: 0.0649922	total: 1m 3s	remaining: 48.7s
# 5677:	learn: 0.0649893	total: 1m 3s	remaining: 48.6s
# 5678:	learn: 0.0649872	total: 1m 3s	remaining: 48.6s
# 5679:	learn: 0.0649854	total: 1m 3s	remaining: 48.6s
# 5680:	learn: 0.0649809	total: 1m 3s	remaining: 48.6s
# 5681:	learn: 0.0649802	total: 1m 3s	remaining: 48.6s
# 5682:	learn: 0.0649789	total: 1m 3s	remaining: 48.6s
# 5683:	learn: 0.0649785	total: 1m 3s	remaining: 48.6s
# 5684:	learn: 0.0649761	total: 1m 3s	remaining: 48.6s
# 5685:	learn: 0.0649727	total: 1m 3s	remaining: 48.5s
# 5686:	learn: 0.0649690	total: 1m 3s	remaining: 48.5s
# 5687:	learn: 0.0649668	total: 1m 4s	remaining: 48.5s
# 5688:	learn: 0.0649663	total: 1m 4s	remaining: 48.5s
# 5689:	learn: 0.0649638	total: 1m 4s	remaining: 48.5s
# 5690:	learn: 0.0649603	total: 1m 4s	remaining: 48.5s
# 5691:	learn: 0.0649574	total: 1m 4s	remaining: 48.5s
# 5692:	learn: 0.0649535	total: 1m 4s	remaining: 48.5s
# 5693:	learn: 0.0649529	total: 1m 4s	remaining: 48.4s
# 5694:	learn: 0.0649518	total: 1m 4s	remaining: 48.4s
# 5695:	learn: 0.0649488	total: 1m 4s	remaining: 48.4s
# 5696:	learn: 0.0649475	total: 1m 4s	remaining: 48.4s
# 5697:	learn: 0.0649456	total: 1m 4s	remaining: 48.4s
# 5698:	learn: 0.0649428	total: 1m 4s	remaining: 48.4s
# 5699:	learn: 0.0649379	total: 1m 4s	remaining: 48.4s
# 5700:	learn: 0.0649348	total: 1m 4s	remaining: 48.3s
# 5701:	learn: 0.0649337	total: 1m 4s	remaining: 48.3s
# 5702:	learn: 0.0649315	total: 1m 4s	remaining: 48.3s
# 5703:	learn: 0.0649282	total: 1m 4s	remaining: 48.3s
# 5704:	learn: 0.0649267	total: 1m 4s	remaining: 48.3s
# 5705:	learn: 0.0649241	total: 1m 4s	remaining: 48.3s
# 5706:	learn: 0.0649237	total: 1m 4s	remaining: 48.3s
# 5707:	learn: 0.0649221	total: 1m 4s	remaining: 48.3s
# 5708:	learn: 0.0649175	total: 1m 4s	remaining: 48.3s
# 5709:	learn: 0.0649168	total: 1m 4s	remaining: 48.3s
# 5710:	learn: 0.0649124	total: 1m 4s	remaining: 48.2s
# 5711:	learn: 0.0649112	total: 1m 4s	remaining: 48.2s
# 5712:	learn: 0.0649105	total: 1m 4s	remaining: 48.2s
# 5713:	learn: 0.0649096	total: 1m 4s	remaining: 48.2s
# 5714:	learn: 0.0649067	total: 1m 4s	remaining: 48.2s
# 5715:	learn: 0.0649057	total: 1m 4s	remaining: 48.2s
# 5716:	learn: 0.0649022	total: 1m 4s	remaining: 48.2s
# 5717:	learn: 0.0649006	total: 1m 4s	remaining: 48.2s
# 5718:	learn: 0.0648972	total: 1m 4s	remaining: 48.1s
# 5719:	learn: 0.0648910	total: 1m 4s	remaining: 48.1s
# 5720:	learn: 0.0648881	total: 1m 4s	remaining: 48.1s
# 5721:	learn: 0.0648856	total: 1m 4s	remaining: 48.1s
# 5722:	learn: 0.0648823	total: 1m 4s	remaining: 48.1s
# 5723:	learn: 0.0648782	total: 1m 4s	remaining: 48.1s
# 5724:	learn: 0.0648746	total: 1m 4s	remaining: 48.1s
# 5725:	learn: 0.0648732	total: 1m 4s	remaining: 48s
# 5726:	learn: 0.0648713	total: 1m 4s	remaining: 48s
# 5727:	learn: 0.0648693	total: 1m 4s	remaining: 48s
# 5728:	learn: 0.0648667	total: 1m 4s	remaining: 48s
# 5729:	learn: 0.0648654	total: 1m 4s	remaining: 48s
# 5730:	learn: 0.0648612	total: 1m 4s	remaining: 48s
# 5731:	learn: 0.0648594	total: 1m 4s	remaining: 48s
# 5732:	learn: 0.0648573	total: 1m 4s	remaining: 48s
# 5733:	learn: 0.0648532	total: 1m 4s	remaining: 48s
# 5734:	learn: 0.0648512	total: 1m 4s	remaining: 47.9s
# 5735:	learn: 0.0648461	total: 1m 4s	remaining: 47.9s
# 5736:	learn: 0.0648432	total: 1m 4s	remaining: 47.9s
# 5737:	learn: 0.0648410	total: 1m 4s	remaining: 47.9s
# 5738:	learn: 0.0648381	total: 1m 4s	remaining: 47.9s
# 5739:	learn: 0.0648338	total: 1m 4s	remaining: 47.9s
# 5740:	learn: 0.0648314	total: 1m 4s	remaining: 47.9s
# 5741:	learn: 0.0648268	total: 1m 4s	remaining: 47.9s
# 5742:	learn: 0.0648251	total: 1m 4s	remaining: 47.8s
# 5743:	learn: 0.0648245	total: 1m 4s	remaining: 47.8s
# 5744:	learn: 0.0648211	total: 1m 4s	remaining: 47.8s
# 5745:	learn: 0.0648204	total: 1m 4s	remaining: 47.8s
# 5746:	learn: 0.0648200	total: 1m 4s	remaining: 47.8s
# 5747:	learn: 0.0648181	total: 1m 4s	remaining: 47.8s
# 5748:	learn: 0.0648176	total: 1m 4s	remaining: 47.8s
# 5749:	learn: 0.0648159	total: 1m 4s	remaining: 47.8s
# 5750:	learn: 0.0648144	total: 1m 4s	remaining: 47.7s
# 5751:	learn: 0.0648124	total: 1m 4s	remaining: 47.7s
# 5752:	learn: 0.0648110	total: 1m 4s	remaining: 47.7s
# 5753:	learn: 0.0648082	total: 1m 4s	remaining: 47.7s
# 5754:	learn: 0.0648073	total: 1m 4s	remaining: 47.7s
# 5755:	learn: 0.0648049	total: 1m 4s	remaining: 47.7s
# 5756:	learn: 0.0648038	total: 1m 4s	remaining: 47.7s
# 5757:	learn: 0.0648030	total: 1m 4s	remaining: 47.7s
# 5758:	learn: 0.0647991	total: 1m 4s	remaining: 47.6s
# 5759:	learn: 0.0647964	total: 1m 4s	remaining: 47.6s
# 5760:	learn: 0.0647958	total: 1m 4s	remaining: 47.6s
# 5761:	learn: 0.0647948	total: 1m 4s	remaining: 47.6s
# 5762:	learn: 0.0647906	total: 1m 4s	remaining: 47.6s
# 5763:	learn: 0.0647881	total: 1m 4s	remaining: 47.6s
# 5764:	learn: 0.0647835	total: 1m 4s	remaining: 47.6s
# 5765:	learn: 0.0647807	total: 1m 4s	remaining: 47.6s
# 5766:	learn: 0.0647786	total: 1m 4s	remaining: 47.5s
# 5767:	learn: 0.0647735	total: 1m 4s	remaining: 47.5s
# 5768:	learn: 0.0647694	total: 1m 4s	remaining: 47.5s
# 5769:	learn: 0.0647676	total: 1m 4s	remaining: 47.5s
# 5770:	learn: 0.0647657	total: 1m 4s	remaining: 47.5s
# 5771:	learn: 0.0647633	total: 1m 4s	remaining: 47.5s
# 5772:	learn: 0.0647619	total: 1m 4s	remaining: 47.5s
# 5773:	learn: 0.0647594	total: 1m 4s	remaining: 47.5s
# 5774:	learn: 0.0647572	total: 1m 4s	remaining: 47.4s
# 5775:	learn: 0.0647536	total: 1m 4s	remaining: 47.4s
# 5776:	learn: 0.0647508	total: 1m 4s	remaining: 47.4s
# 5777:	learn: 0.0647487	total: 1m 4s	remaining: 47.4s
# 5778:	learn: 0.0647477	total: 1m 4s	remaining: 47.4s
# 5779:	learn: 0.0647448	total: 1m 4s	remaining: 47.4s
# 5780:	learn: 0.0647435	total: 1m 4s	remaining: 47.4s
# 5781:	learn: 0.0647429	total: 1m 4s	remaining: 47.3s
# 5782:	learn: 0.0647409	total: 1m 4s	remaining: 47.3s
# 5783:	learn: 0.0647390	total: 1m 4s	remaining: 47.3s
# 5784:	learn: 0.0647381	total: 1m 4s	remaining: 47.3s
# 5785:	learn: 0.0647374	total: 1m 4s	remaining: 47.3s
# 5786:	learn: 0.0647346	total: 1m 4s	remaining: 47.3s
# 5787:	learn: 0.0647320	total: 1m 4s	remaining: 47.3s
# 5788:	learn: 0.0647295	total: 1m 4s	remaining: 47.3s
# 5789:	learn: 0.0647263	total: 1m 4s	remaining: 47.3s
# 5790:	learn: 0.0647227	total: 1m 5s	remaining: 47.3s
# 5791:	learn: 0.0647215	total: 1m 5s	remaining: 47.3s
# 5792:	learn: 0.0647197	total: 1m 5s	remaining: 47.3s
# 5793:	learn: 0.0647155	total: 1m 5s	remaining: 47.3s
# 5794:	learn: 0.0647129	total: 1m 5s	remaining: 47.3s
# 5795:	learn: 0.0647077	total: 1m 5s	remaining: 47.3s
# 5796:	learn: 0.0647042	total: 1m 5s	remaining: 47.3s
# 5797:	learn: 0.0647037	total: 1m 5s	remaining: 47.3s
# 5798:	learn: 0.0647010	total: 1m 5s	remaining: 47.3s
# 5799:	learn: 0.0647001	total: 1m 5s	remaining: 47.3s
# 5800:	learn: 0.0646979	total: 1m 5s	remaining: 47.3s
# 5801:	learn: 0.0646942	total: 1m 5s	remaining: 47.3s
# 5802:	learn: 0.0646918	total: 1m 5s	remaining: 47.3s
# 5803:	learn: 0.0646909	total: 1m 5s	remaining: 47.3s
# 5804:	learn: 0.0646883	total: 1m 5s	remaining: 47.3s
# 5805:	learn: 0.0646862	total: 1m 5s	remaining: 47.3s
# 5806:	learn: 0.0646858	total: 1m 5s	remaining: 47.2s
# 5807:	learn: 0.0646825	total: 1m 5s	remaining: 47.3s
# 5808:	learn: 0.0646789	total: 1m 5s	remaining: 47.3s
# 5809:	learn: 0.0646784	total: 1m 5s	remaining: 47.3s
# 5810:	learn: 0.0646771	total: 1m 5s	remaining: 47.3s
# 5811:	learn: 0.0646765	total: 1m 5s	remaining: 47.2s
# 5812:	learn: 0.0646756	total: 1m 5s	remaining: 47.2s
# 5813:	learn: 0.0646747	total: 1m 5s	remaining: 47.2s
# 5814:	learn: 0.0646714	total: 1m 5s	remaining: 47.2s
# 5815:	learn: 0.0646686	total: 1m 5s	remaining: 47.2s
# 5816:	learn: 0.0646662	total: 1m 5s	remaining: 47.2s
# 5817:	learn: 0.0646632	total: 1m 5s	remaining: 47.3s
# 5818:	learn: 0.0646617	total: 1m 5s	remaining: 47.2s
# 5819:	learn: 0.0646573	total: 1m 5s	remaining: 47.3s
# 5820:	learn: 0.0646549	total: 1m 5s	remaining: 47.3s
# 5821:	learn: 0.0646504	total: 1m 5s	remaining: 47.3s
# 5822:	learn: 0.0646499	total: 1m 5s	remaining: 47.2s
# 5823:	learn: 0.0646490	total: 1m 5s	remaining: 47.3s
# 5824:	learn: 0.0646474	total: 1m 5s	remaining: 47.3s
# 5825:	learn: 0.0646470	total: 1m 5s	remaining: 47.2s
# 5826:	learn: 0.0646469	total: 1m 5s	remaining: 47.2s
# 5827:	learn: 0.0646448	total: 1m 5s	remaining: 47.2s
# 5828:	learn: 0.0646430	total: 1m 5s	remaining: 47.2s
# 5829:	learn: 0.0646414	total: 1m 6s	remaining: 47.2s
# 5830:	learn: 0.0646392	total: 1m 6s	remaining: 47.2s
# 5831:	learn: 0.0646356	total: 1m 6s	remaining: 47.2s
# 5832:	learn: 0.0646336	total: 1m 6s	remaining: 47.2s
# 5833:	learn: 0.0646326	total: 1m 6s	remaining: 47.2s
# 5834:	learn: 0.0646294	total: 1m 6s	remaining: 47.2s
# 5835:	learn: 0.0646279	total: 1m 6s	remaining: 47.2s
# 5836:	learn: 0.0646240	total: 1m 6s	remaining: 47.2s
# 5837:	learn: 0.0646222	total: 1m 6s	remaining: 47.2s
# 5838:	learn: 0.0646200	total: 1m 6s	remaining: 47.2s
# 5839:	learn: 0.0646189	total: 1m 6s	remaining: 47.2s
# 5840:	learn: 0.0646165	total: 1m 6s	remaining: 47.2s
# 5841:	learn: 0.0646152	total: 1m 6s	remaining: 47.2s
# 5842:	learn: 0.0646141	total: 1m 6s	remaining: 47.2s
# 5843:	learn: 0.0646118	total: 1m 6s	remaining: 47.2s
# 5844:	learn: 0.0646113	total: 1m 6s	remaining: 47.2s
# 5845:	learn: 0.0646097	total: 1m 6s	remaining: 47.2s
# 5846:	learn: 0.0646097	total: 1m 6s	remaining: 47.2s
# 5847:	learn: 0.0646082	total: 1m 6s	remaining: 47.1s
# 5848:	learn: 0.0646078	total: 1m 6s	remaining: 47.1s
# 5849:	learn: 0.0646066	total: 1m 6s	remaining: 47.1s
# 5850:	learn: 0.0646047	total: 1m 6s	remaining: 47.1s
# 5851:	learn: 0.0646034	total: 1m 6s	remaining: 47.1s
# 5852:	learn: 0.0646003	total: 1m 6s	remaining: 47.1s
# 5853:	learn: 0.0645956	total: 1m 6s	remaining: 47.1s
# 5854:	learn: 0.0645937	total: 1m 6s	remaining: 47.1s
# 5855:	learn: 0.0645917	total: 1m 6s	remaining: 47.1s
# 5856:	learn: 0.0645879	total: 1m 6s	remaining: 47.1s
# 5857:	learn: 0.0645833	total: 1m 6s	remaining: 47.1s
# 5858:	learn: 0.0645812	total: 1m 6s	remaining: 47.1s
# 5859:	learn: 0.0645787	total: 1m 6s	remaining: 47.1s
# 5860:	learn: 0.0645757	total: 1m 6s	remaining: 47.1s
# 5861:	learn: 0.0645720	total: 1m 6s	remaining: 47.1s
# 5862:	learn: 0.0645689	total: 1m 6s	remaining: 47.1s
# 5863:	learn: 0.0645680	total: 1m 6s	remaining: 47.1s
# 5864:	learn: 0.0645665	total: 1m 6s	remaining: 47.1s
# 5865:	learn: 0.0645622	total: 1m 6s	remaining: 47.1s
# 5866:	learn: 0.0645613	total: 1m 6s	remaining: 47.1s
# 5867:	learn: 0.0645601	total: 1m 6s	remaining: 47.1s
# 5868:	learn: 0.0645588	total: 1m 6s	remaining: 47.1s
# 5869:	learn: 0.0645581	total: 1m 6s	remaining: 47.1s
# 5870:	learn: 0.0645573	total: 1m 6s	remaining: 47.1s
# 5871:	learn: 0.0645555	total: 1m 6s	remaining: 47.1s
# 5872:	learn: 0.0645550	total: 1m 6s	remaining: 47.1s
# 5873:	learn: 0.0645546	total: 1m 7s	remaining: 47.1s
# 5874:	learn: 0.0645540	total: 1m 7s	remaining: 47.1s
# 5875:	learn: 0.0645533	total: 1m 7s	remaining: 47.1s
# 5876:	learn: 0.0645525	total: 1m 7s	remaining: 47s
# 5877:	learn: 0.0645497	total: 1m 7s	remaining: 47s
# 5878:	learn: 0.0645493	total: 1m 7s	remaining: 47s
# 5879:	learn: 0.0645469	total: 1m 7s	remaining: 47s
# 5880:	learn: 0.0645460	total: 1m 7s	remaining: 47s
# 5881:	learn: 0.0645443	total: 1m 7s	remaining: 47s
# 5882:	learn: 0.0645410	total: 1m 7s	remaining: 47s
# 5883:	learn: 0.0645387	total: 1m 7s	remaining: 47s
# 5884:	learn: 0.0645362	total: 1m 7s	remaining: 47s
# 5885:	learn: 0.0645349	total: 1m 7s	remaining: 47s
# 5886:	learn: 0.0645340	total: 1m 7s	remaining: 47s
# 5887:	learn: 0.0645308	total: 1m 7s	remaining: 47s
# 5888:	learn: 0.0645283	total: 1m 7s	remaining: 46.9s
# 5889:	learn: 0.0645234	total: 1m 7s	remaining: 46.9s
# 5890:	learn: 0.0645227	total: 1m 7s	remaining: 46.9s
# 5891:	learn: 0.0645210	total: 1m 7s	remaining: 46.9s
# 5892:	learn: 0.0645201	total: 1m 7s	remaining: 46.9s
# 5893:	learn: 0.0645180	total: 1m 7s	remaining: 46.9s
# 5894:	learn: 0.0645130	total: 1m 7s	remaining: 46.9s
# 5895:	learn: 0.0645121	total: 1m 7s	remaining: 46.9s
# 5896:	learn: 0.0645093	total: 1m 7s	remaining: 46.9s
# 5897:	learn: 0.0645074	total: 1m 7s	remaining: 46.9s
# 5898:	learn: 0.0645058	total: 1m 7s	remaining: 46.9s
# 5899:	learn: 0.0645040	total: 1m 7s	remaining: 46.9s
# 5900:	learn: 0.0645009	total: 1m 7s	remaining: 46.9s
# 5901:	learn: 0.0644987	total: 1m 7s	remaining: 46.9s
# 5902:	learn: 0.0644981	total: 1m 7s	remaining: 46.9s
# 5903:	learn: 0.0644947	total: 1m 7s	remaining: 46.9s
# 5904:	learn: 0.0644919	total: 1m 7s	remaining: 46.9s
# 5905:	learn: 0.0644885	total: 1m 7s	remaining: 46.9s
# 5906:	learn: 0.0644868	total: 1m 7s	remaining: 46.9s
# 5907:	learn: 0.0644855	total: 1m 7s	remaining: 46.9s
# 5908:	learn: 0.0644849	total: 1m 7s	remaining: 46.9s
# 5909:	learn: 0.0644815	total: 1m 7s	remaining: 46.9s
# 5910:	learn: 0.0644803	total: 1m 7s	remaining: 46.9s
# 5911:	learn: 0.0644789	total: 1m 7s	remaining: 46.9s
# 5912:	learn: 0.0644775	total: 1m 7s	remaining: 46.9s
# 5913:	learn: 0.0644748	total: 1m 7s	remaining: 46.9s
# 5914:	learn: 0.0644698	total: 1m 7s	remaining: 46.9s
# ...
# 9710:	learn: 0.0582501	total: 1m 52s	remaining: 3.35s
# 9711:	learn: 0.0582499	total: 1m 52s	remaining: 3.34s
# 9712:	learn: 0.0582485	total: 1m 52s	remaining: 3.33s
# 9713:	learn: 0.0582481	total: 1m 52s	remaining: 3.31s
# 9714:	learn: 0.0582473	total: 1m 52s	remaining: 3.3s
# 9715:	learn: 0.0582470	total: 1m 52s	remaining: 3.29s
# 9716:	learn: 0.0582425	total: 1m 52s	remaining: 3.28s
# 9717:	learn: 0.0582423	total: 1m 52s	remaining: 3.27s
# 9718:	learn: 0.0582417	total: 1m 52s	remaining: 3.25s
# 9719:	learn: 0.0582415	total: 1m 52s	remaining: 3.24s
# 9720:	learn: 0.0582405	total: 1m 52s	remaining: 3.23s
# 9721:	learn: 0.0582395	total: 1m 52s	remaining: 3.22s
# 9722:	learn: 0.0582389	total: 1m 52s	remaining: 3.21s
# 9723:	learn: 0.0582367	total: 1m 52s	remaining: 3.2s
# 9724:	learn: 0.0582343	total: 1m 52s	remaining: 3.19s
# 9725:	learn: 0.0582340	total: 1m 52s	remaining: 3.17s
# 9726:	learn: 0.0582338	total: 1m 52s	remaining: 3.16s
# 9727:	learn: 0.0582326	total: 1m 52s	remaining: 3.15s
# 9728:	learn: 0.0582323	total: 1m 52s	remaining: 3.14s
# 9729:	learn: 0.0582314	total: 1m 52s	remaining: 3.13s
# 9730:	learn: 0.0582300	total: 1m 52s	remaining: 3.12s
# 9731:	learn: 0.0582278	total: 1m 52s	remaining: 3.1s
# 9732:	learn: 0.0582261	total: 1m 52s	remaining: 3.09s
# 9733:	learn: 0.0582253	total: 1m 52s	remaining: 3.08s
# 9734:	learn: 0.0582227	total: 1m 52s	remaining: 3.07s
# 9735:	learn: 0.0582223	total: 1m 52s	remaining: 3.06s
# 9736:	learn: 0.0582208	total: 1m 52s	remaining: 3.05s
# 9737:	learn: 0.0582187	total: 1m 52s	remaining: 3.03s
# 9738:	learn: 0.0582172	total: 1m 52s	remaining: 3.02s
# 9739:	learn: 0.0582150	total: 1m 52s	remaining: 3.01s
# 9740:	learn: 0.0582134	total: 1m 52s	remaining: 3s
# 9741:	learn: 0.0582114	total: 1m 52s	remaining: 2.99s
# 9742:	learn: 0.0582100	total: 1m 52s	remaining: 2.98s
# 9743:	learn: 0.0582095	total: 1m 52s	remaining: 2.96s
# 9744:	learn: 0.0582092	total: 1m 52s	remaining: 2.95s
# 9745:	learn: 0.0582080	total: 1m 52s	remaining: 2.94s
# 9746:	learn: 0.0582070	total: 1m 52s	remaining: 2.93s
# 9747:	learn: 0.0582069	total: 1m 52s	remaining: 2.92s
# 9748:	learn: 0.0582060	total: 1m 52s	remaining: 2.91s
# 9749:	learn: 0.0582044	total: 1m 52s	remaining: 2.89s
# 9750:	learn: 0.0582030	total: 1m 52s	remaining: 2.88s
# 9751:	learn: 0.0582030	total: 1m 52s	remaining: 2.87s
# 9752:	learn: 0.0582023	total: 1m 52s	remaining: 2.86s
# 9753:	learn: 0.0582015	total: 1m 52s	remaining: 2.85s
# 9754:	learn: 0.0581975	total: 1m 52s	remaining: 2.84s
# 9755:	learn: 0.0581950	total: 1m 52s	remaining: 2.83s
# 9756:	learn: 0.0581947	total: 1m 52s	remaining: 2.81s
# 9757:	learn: 0.0581937	total: 1m 52s	remaining: 2.8s
# 9758:	learn: 0.0581929	total: 1m 52s	remaining: 2.79s
# 9759:	learn: 0.0581924	total: 1m 52s	remaining: 2.78s
# 9760:	learn: 0.0581906	total: 1m 52s	remaining: 2.77s
# 9761:	learn: 0.0581890	total: 1m 53s	remaining: 2.75s
# 9762:	learn: 0.0581881	total: 1m 53s	remaining: 2.74s
# 9763:	learn: 0.0581877	total: 1m 53s	remaining: 2.73s
# 9764:	learn: 0.0581874	total: 1m 53s	remaining: 2.72s
# 9765:	learn: 0.0581854	total: 1m 53s	remaining: 2.71s
# 9766:	learn: 0.0581835	total: 1m 53s	remaining: 2.7s
# 9767:	learn: 0.0581821	total: 1m 53s	remaining: 2.69s
# 9768:	learn: 0.0581802	total: 1m 53s	remaining: 2.67s
# 9769:	learn: 0.0581795	total: 1m 53s	remaining: 2.66s
# 9770:	learn: 0.0581790	total: 1m 53s	remaining: 2.65s
# 9771:	learn: 0.0581779	total: 1m 53s	remaining: 2.64s
# 9772:	learn: 0.0581777	total: 1m 53s	remaining: 2.63s
# 9773:	learn: 0.0581766	total: 1m 53s	remaining: 2.62s
# 9774:	learn: 0.0581746	total: 1m 53s	remaining: 2.6s
# 9775:	learn: 0.0581716	total: 1m 53s	remaining: 2.59s
# 9776:	learn: 0.0581714	total: 1m 53s	remaining: 2.58s
# 9777:	learn: 0.0581713	total: 1m 53s	remaining: 2.57s
# 9778:	learn: 0.0581692	total: 1m 53s	remaining: 2.56s
# 9779:	learn: 0.0581681	total: 1m 53s	remaining: 2.54s
# 9780:	learn: 0.0581678	total: 1m 53s	remaining: 2.53s
# 9781:	learn: 0.0581651	total: 1m 53s	remaining: 2.52s
# 9782:	learn: 0.0581647	total: 1m 53s	remaining: 2.51s
# 9783:	learn: 0.0581634	total: 1m 53s	remaining: 2.5s
# 9784:	learn: 0.0581621	total: 1m 53s	remaining: 2.49s
# 9785:	learn: 0.0581609	total: 1m 53s	remaining: 2.48s
# 9786:	learn: 0.0581588	total: 1m 53s	remaining: 2.46s
# 9787:	learn: 0.0581588	total: 1m 53s	remaining: 2.45s
# 9788:	learn: 0.0581583	total: 1m 53s	remaining: 2.44s
# 9789:	learn: 0.0581569	total: 1m 53s	remaining: 2.43s
# 9790:	learn: 0.0581559	total: 1m 53s	remaining: 2.42s
# 9791:	learn: 0.0581544	total: 1m 53s	remaining: 2.41s
# 9792:	learn: 0.0581535	total: 1m 53s	remaining: 2.39s
# 9793:	learn: 0.0581522	total: 1m 53s	remaining: 2.38s
# 9794:	learn: 0.0581519	total: 1m 53s	remaining: 2.37s
# 9795:	learn: 0.0581505	total: 1m 53s	remaining: 2.36s
# 9796:	learn: 0.0581487	total: 1m 53s	remaining: 2.35s
# 9797:	learn: 0.0581483	total: 1m 53s	remaining: 2.34s
# 9798:	learn: 0.0581468	total: 1m 53s	remaining: 2.33s
# 9799:	learn: 0.0581455	total: 1m 53s	remaining: 2.31s
# 9800:	learn: 0.0581444	total: 1m 53s	remaining: 2.3s
# 9801:	learn: 0.0581433	total: 1m 53s	remaining: 2.29s
# 9802:	learn: 0.0581427	total: 1m 53s	remaining: 2.28s
# 9803:	learn: 0.0581425	total: 1m 53s	remaining: 2.27s
# 9804:	learn: 0.0581417	total: 1m 53s	remaining: 2.25s
# 9805:	learn: 0.0581401	total: 1m 53s	remaining: 2.24s
# 9806:	learn: 0.0581391	total: 1m 53s	remaining: 2.23s
# 9807:	learn: 0.0581379	total: 1m 53s	remaining: 2.22s
# 9808:	learn: 0.0581362	total: 1m 53s	remaining: 2.21s
# 9809:	learn: 0.0581355	total: 1m 53s	remaining: 2.2s
# 9810:	learn: 0.0581348	total: 1m 53s	remaining: 2.19s
# 9811:	learn: 0.0581345	total: 1m 53s	remaining: 2.17s
# 9812:	learn: 0.0581320	total: 1m 53s	remaining: 2.16s
# 9813:	learn: 0.0581297	total: 1m 53s	remaining: 2.15s
# 9814:	learn: 0.0581287	total: 1m 53s	remaining: 2.14s
# 9815:	learn: 0.0581272	total: 1m 53s	remaining: 2.13s
# 9816:	learn: 0.0581260	total: 1m 53s	remaining: 2.12s
# 9817:	learn: 0.0581254	total: 1m 53s	remaining: 2.1s
# 9818:	learn: 0.0581239	total: 1m 53s	remaining: 2.09s
# 9819:	learn: 0.0581232	total: 1m 53s	remaining: 2.08s
# 9820:	learn: 0.0581228	total: 1m 53s	remaining: 2.07s
# 9821:	learn: 0.0581214	total: 1m 53s	remaining: 2.06s
# 9822:	learn: 0.0581212	total: 1m 53s	remaining: 2.05s
# 9823:	learn: 0.0581208	total: 1m 53s	remaining: 2.04s
# 9824:	learn: 0.0581179	total: 1m 53s	remaining: 2.02s
# 9825:	learn: 0.0581168	total: 1m 53s	remaining: 2.01s
# 9826:	learn: 0.0581154	total: 1m 53s	remaining: 2s
# 9827:	learn: 0.0581149	total: 1m 53s	remaining: 1.99s
# 9828:	learn: 0.0581137	total: 1m 53s	remaining: 1.98s
# 9829:	learn: 0.0581126	total: 1m 53s	remaining: 1.97s
# 9830:	learn: 0.0581125	total: 1m 53s	remaining: 1.95s
# 9831:	learn: 0.0581111	total: 1m 53s	remaining: 1.94s
# 9832:	learn: 0.0581108	total: 1m 53s	remaining: 1.93s
# 9833:	learn: 0.0581079	total: 1m 53s	remaining: 1.92s
# 9834:	learn: 0.0581071	total: 1m 53s	remaining: 1.91s
# 9835:	learn: 0.0581067	total: 1m 53s	remaining: 1.9s
# 9836:	learn: 0.0581044	total: 1m 53s	remaining: 1.88s
# 9837:	learn: 0.0581029	total: 1m 53s	remaining: 1.87s
# 9838:	learn: 0.0581027	total: 1m 53s	remaining: 1.86s
# 9839:	learn: 0.0581012	total: 1m 53s	remaining: 1.85s
# 9840:	learn: 0.0580996	total: 1m 53s	remaining: 1.84s
# 9841:	learn: 0.0580973	total: 1m 53s	remaining: 1.83s
# 9842:	learn: 0.0580946	total: 1m 53s	remaining: 1.81s
# 9843:	learn: 0.0580945	total: 1m 53s	remaining: 1.8s
# 9844:	learn: 0.0580942	total: 1m 53s	remaining: 1.79s
# 9845:	learn: 0.0580921	total: 1m 53s	remaining: 1.78s
# 9846:	learn: 0.0580916	total: 1m 53s	remaining: 1.77s
# 9847:	learn: 0.0580911	total: 1m 53s	remaining: 1.76s
# 9848:	learn: 0.0580906	total: 1m 53s	remaining: 1.75s
# 9849:	learn: 0.0580879	total: 1m 53s	remaining: 1.73s
# 9850:	learn: 0.0580876	total: 1m 53s	remaining: 1.72s
# 9851:	learn: 0.0580872	total: 1m 53s	remaining: 1.71s
# 9852:	learn: 0.0580855	total: 1m 53s	remaining: 1.7s
# 9853:	learn: 0.0580849	total: 1m 53s	remaining: 1.69s
# 9854:	learn: 0.0580833	total: 1m 53s	remaining: 1.68s
# 9855:	learn: 0.0580822	total: 1m 53s	remaining: 1.66s
# 9856:	learn: 0.0580813	total: 1m 53s	remaining: 1.65s
# 9857:	learn: 0.0580807	total: 1m 53s	remaining: 1.64s
# 9858:	learn: 0.0580803	total: 1m 53s	remaining: 1.63s
# 9859:	learn: 0.0580798	total: 1m 53s	remaining: 1.62s
# 9860:	learn: 0.0580796	total: 1m 53s	remaining: 1.61s
# 9861:	learn: 0.0580780	total: 1m 53s	remaining: 1.59s
# 9862:	learn: 0.0580777	total: 1m 53s	remaining: 1.58s
# 9863:	learn: 0.0580769	total: 1m 53s	remaining: 1.57s
# 9864:	learn: 0.0580766	total: 1m 53s	remaining: 1.56s
# 9865:	learn: 0.0580764	total: 1m 53s	remaining: 1.55s
# 9866:	learn: 0.0580761	total: 1m 54s	remaining: 1.54s
# 9867:	learn: 0.0580750	total: 1m 54s	remaining: 1.52s
# 9868:	learn: 0.0580743	total: 1m 54s	remaining: 1.51s
# 9869:	learn: 0.0580736	total: 1m 54s	remaining: 1.5s
# 9870:	learn: 0.0580735	total: 1m 54s	remaining: 1.49s
# 9871:	learn: 0.0580719	total: 1m 54s	remaining: 1.48s
# 9872:	learn: 0.0580698	total: 1m 54s	remaining: 1.47s
# 9873:	learn: 0.0580691	total: 1m 54s	remaining: 1.46s
# 9874:	learn: 0.0580676	total: 1m 54s	remaining: 1.44s
# 9875:	learn: 0.0580664	total: 1m 54s	remaining: 1.43s
# 9876:	learn: 0.0580633	total: 1m 54s	remaining: 1.42s
# 9877:	learn: 0.0580608	total: 1m 54s	remaining: 1.41s
# 9878:	learn: 0.0580600	total: 1m 54s	remaining: 1.4s
# 9879:	learn: 0.0580578	total: 1m 54s	remaining: 1.39s
# 9880:	learn: 0.0580563	total: 1m 54s	remaining: 1.37s
# 9881:	learn: 0.0580556	total: 1m 54s	remaining: 1.36s
# 9882:	learn: 0.0580516	total: 1m 54s	remaining: 1.35s
# 9883:	learn: 0.0580515	total: 1m 54s	remaining: 1.34s
# 9884:	learn: 0.0580513	total: 1m 54s	remaining: 1.33s
# 9885:	learn: 0.0580497	total: 1m 54s	remaining: 1.32s
# 9886:	learn: 0.0580454	total: 1m 54s	remaining: 1.3s
# 9887:	learn: 0.0580423	total: 1m 54s	remaining: 1.29s
# 9888:	learn: 0.0580411	total: 1m 54s	remaining: 1.28s
# 9889:	learn: 0.0580409	total: 1m 54s	remaining: 1.27s
# 9890:	learn: 0.0580376	total: 1m 54s	remaining: 1.26s
# 9891:	learn: 0.0580375	total: 1m 54s	remaining: 1.25s
# 9892:	learn: 0.0580363	total: 1m 54s	remaining: 1.24s
# 9893:	learn: 0.0580349	total: 1m 54s	remaining: 1.22s
# 9894:	learn: 0.0580347	total: 1m 54s	remaining: 1.21s
# 9895:	learn: 0.0580346	total: 1m 54s	remaining: 1.2s
# 9896:	learn: 0.0580335	total: 1m 54s	remaining: 1.19s
# 9897:	learn: 0.0580321	total: 1m 54s	remaining: 1.18s
# 9898:	learn: 0.0580319	total: 1m 54s	remaining: 1.17s
# 9899:	learn: 0.0580275	total: 1m 54s	remaining: 1.15s
# 9900:	learn: 0.0580274	total: 1m 54s	remaining: 1.14s
# 9901:	learn: 0.0580272	total: 1m 54s	remaining: 1.13s
# 9902:	learn: 0.0580268	total: 1m 54s	remaining: 1.12s
# 9903:	learn: 0.0580265	total: 1m 54s	remaining: 1.11s
# 9904:	learn: 0.0580263	total: 1m 54s	remaining: 1.1s
# 9905:	learn: 0.0580253	total: 1m 54s	remaining: 1.08s
# 9906:	learn: 0.0580235	total: 1m 54s	remaining: 1.07s
# 9907:	learn: 0.0580223	total: 1m 54s	remaining: 1.06s
# 9908:	learn: 0.0580217	total: 1m 54s	remaining: 1.05s
# 9909:	learn: 0.0580211	total: 1m 54s	remaining: 1.04s
# 9910:	learn: 0.0580191	total: 1m 54s	remaining: 1.03s
# 9911:	learn: 0.0580182	total: 1m 54s	remaining: 1.01s
# 9912:	learn: 0.0580179	total: 1m 54s	remaining: 1s
# 9913:	learn: 0.0580169	total: 1m 54s	remaining: 993ms
# 9914:	learn: 0.0580155	total: 1m 54s	remaining: 981ms
# 9915:	learn: 0.0580149	total: 1m 54s	remaining: 970ms
# 9916:	learn: 0.0580138	total: 1m 54s	remaining: 958ms
# 9917:	learn: 0.0580117	total: 1m 54s	remaining: 946ms
# 9918:	learn: 0.0580109	total: 1m 54s	remaining: 935ms
# 9919:	learn: 0.0580096	total: 1m 54s	remaining: 923ms
# 9920:	learn: 0.0580093	total: 1m 54s	remaining: 912ms
# 9921:	learn: 0.0580086	total: 1m 54s	remaining: 900ms
# 9922:	learn: 0.0580081	total: 1m 54s	remaining: 889ms
# 9923:	learn: 0.0580069	total: 1m 54s	remaining: 877ms
# 9924:	learn: 0.0580051	total: 1m 54s	remaining: 866ms
# 9925:	learn: 0.0580048	total: 1m 54s	remaining: 854ms
# 9926:	learn: 0.0580034	total: 1m 54s	remaining: 842ms
# 9927:	learn: 0.0580017	total: 1m 54s	remaining: 831ms
# 9928:	learn: 0.0580010	total: 1m 54s	remaining: 819ms
# 9929:	learn: 0.0580005	total: 1m 54s	remaining: 808ms
# 9930:	learn: 0.0580001	total: 1m 54s	remaining: 796ms
# 9931:	learn: 0.0579981	total: 1m 54s	remaining: 785ms
# 9932:	learn: 0.0579959	total: 1m 54s	remaining: 773ms
# 9933:	learn: 0.0579940	total: 1m 54s	remaining: 762ms
# 9934:	learn: 0.0579919	total: 1m 54s	remaining: 750ms
# 9935:	learn: 0.0579891	total: 1m 54s	remaining: 738ms
# 9936:	learn: 0.0579869	total: 1m 54s	remaining: 727ms
# 9937:	learn: 0.0579867	total: 1m 54s	remaining: 715ms
# 9938:	learn: 0.0579828	total: 1m 54s	remaining: 704ms
# 9939:	learn: 0.0579825	total: 1m 54s	remaining: 692ms
# 9940:	learn: 0.0579812	total: 1m 54s	remaining: 681ms
# 9941:	learn: 0.0579806	total: 1m 54s	remaining: 669ms
# 9942:	learn: 0.0579793	total: 1m 54s	remaining: 658ms
# 9943:	learn: 0.0579780	total: 1m 54s	remaining: 646ms
# 9944:	learn: 0.0579767	total: 1m 54s	remaining: 635ms
# 9945:	learn: 0.0579751	total: 1m 54s	remaining: 623ms
# 9946:	learn: 0.0579736	total: 1m 54s	remaining: 611ms
# 9947:	learn: 0.0579716	total: 1m 54s	remaining: 600ms
# 9948:	learn: 0.0579693	total: 1m 54s	remaining: 588ms
# 9949:	learn: 0.0579688	total: 1m 54s	remaining: 577ms
# 9950:	learn: 0.0579678	total: 1m 54s	remaining: 565ms
# 9951:	learn: 0.0579651	total: 1m 54s	remaining: 554ms
# 9952:	learn: 0.0579624	total: 1m 54s	remaining: 542ms
# 9953:	learn: 0.0579609	total: 1m 54s	remaining: 531ms
# 9954:	learn: 0.0579607	total: 1m 54s	remaining: 519ms
# 9955:	learn: 0.0579599	total: 1m 54s	remaining: 507ms
# 9956:	learn: 0.0579597	total: 1m 54s	remaining: 496ms
# 9957:	learn: 0.0579589	total: 1m 54s	remaining: 484ms
# 9958:	learn: 0.0579582	total: 1m 54s	remaining: 473ms
# 9959:	learn: 0.0579570	total: 1m 54s	remaining: 461ms
# 9960:	learn: 0.0579567	total: 1m 54s	remaining: 450ms
# 9961:	learn: 0.0579565	total: 1m 54s	remaining: 438ms
# 9962:	learn: 0.0579552	total: 1m 54s	remaining: 427ms
# 9963:	learn: 0.0579551	total: 1m 54s	remaining: 415ms
# 9964:	learn: 0.0579548	total: 1m 54s	remaining: 404ms
# 9965:	learn: 0.0579524	total: 1m 54s	remaining: 392ms
# 9966:	learn: 0.0579514	total: 1m 54s	remaining: 381ms
# 9967:	learn: 0.0579487	total: 1m 54s	remaining: 369ms
# 9968:	learn: 0.0579473	total: 1m 54s	remaining: 357ms
# 9969:	learn: 0.0579453	total: 1m 54s	remaining: 346ms
# 9970:	learn: 0.0579423	total: 1m 54s	remaining: 334ms
# 9971:	learn: 0.0579419	total: 1m 54s	remaining: 323ms
# 9972:	learn: 0.0579406	total: 1m 54s	remaining: 311ms
# 9973:	learn: 0.0579392	total: 1m 54s	remaining: 300ms
# 9974:	learn: 0.0579374	total: 1m 55s	remaining: 288ms
# 9975:	learn: 0.0579355	total: 1m 55s	remaining: 277ms
# 9976:	learn: 0.0579343	total: 1m 55s	remaining: 265ms
# 9977:	learn: 0.0579328	total: 1m 55s	remaining: 254ms
# 9978:	learn: 0.0579320	total: 1m 55s	remaining: 242ms
# 9979:	learn: 0.0579315	total: 1m 55s	remaining: 231ms
# 9980:	learn: 0.0579313	total: 1m 55s	remaining: 219ms
# 9981:	learn: 0.0579308	total: 1m 55s	remaining: 207ms
# 9982:	learn: 0.0579292	total: 1m 55s	remaining: 196ms
# 9983:	learn: 0.0579273	total: 1m 55s	remaining: 184ms
# 9984:	learn: 0.0579258	total: 1m 55s	remaining: 173ms
# 9985:	learn: 0.0579244	total: 1m 55s	remaining: 161ms
# 9986:	learn: 0.0579241	total: 1m 55s	remaining: 150ms
# 9987:	learn: 0.0579217	total: 1m 55s	remaining: 138ms
# 9988:	learn: 0.0579209	total: 1m 55s	remaining: 127ms
# 9989:	learn: 0.0579199	total: 1m 55s	remaining: 115ms
# 9990:	learn: 0.0579198	total: 1m 55s	remaining: 104ms
# 9991:	learn: 0.0579184	total: 1m 55s	remaining: 92.2ms
# 9992:	learn: 0.0579174	total: 1m 55s	remaining: 80.7ms
# 9993:	learn: 0.0579156	total: 1m 55s	remaining: 69.2ms
# 9994:	learn: 0.0579141	total: 1m 55s	remaining: 57.6ms
# 9995:	learn: 0.0579141	total: 1m 55s	remaining: 46.1ms
# 9996:	learn: 0.0579135	total: 1m 55s	remaining: 34.6ms
# 9997:	learn: 0.0579110	total: 1m 55s	remaining: 23ms
# 9998:	learn: 0.0579101	total: 1m 55s	remaining: 11.5ms
# 9999:	learn: 0.0579099	total: 1m 55s	remaining: 0us
# GridSearchCV(cv=2,
#              estimator=<catboost.core.CatBoostRegressor object at 0x7f4c6d2d65b0>,
#              n_jobs=1,
#              param_grid={'depth': [4, 6, 8], 'iterations': [10000],
#                          'l2_leaf_reg': [2, 3, 4], 'od_type': ['Iter']},
#              scoring='neg_root_mean_squared_error')

# %%
print(" Results from Grid Search " )
print("\n The best estimator across ALL searched params:\n",grid.best_estimator_)
print("\n The best score across ALL searched params:\n",grid.best_score_)
print("\n The best parameters across ALL searched params:\n",grid.best_params_)
# Out:
#  Results from Grid Search
#
#  The best estimator across ALL searched params:
#  <catboost.core.CatBoostRegressor object at 0x7f4c6d241c10>
#
#  The best score across ALL searched params:
#  -0.08478447903559613
#
#  The best parameters across ALL searched params:
#  {'depth': 8, 'iterations': 10000, 'l2_leaf_reg': 4, 'od_type': 'Iter'}

# %% [markdown]
# Konfigurasi terbaik CatBoostRegressor:
#
# - pake fitur kategorikal
# - l2_leaf_reg: 4
# - depth: 8

# %%
rmse_scores_train_tuned = cross_val_score(grid, X_train_log, y_train_log, cv=2, scoring='neg_root_mean_squared_error')
rmse_scores_test_tuned = cross_val_score(grid, X_test_log, y_test_log, cv=2, scoring='neg_root_mean_squared_error')
# Out:
# Streaming output truncated to the last 5000 lines.
# 5000:	learn: 0.0580524	total: 16.8s	remaining: 16.8s
# 5001:	learn: 0.0580513	total: 16.8s	remaining: 16.8s
# 5002:	learn: 0.0580440	total: 16.8s	remaining: 16.8s
# 5003:	learn: 0.0580424	total: 16.8s	remaining: 16.8s
# 5004:	learn: 0.0580382	total: 16.8s	remaining: 16.8s
# 5005:	learn: 0.0580353	total: 16.9s	remaining: 16.8s
# 5006:	learn: 0.0580323	total: 16.9s	remaining: 16.8s
# 5007:	learn: 0.0580310	total: 16.9s	remaining: 16.8s
# 5008:	learn: 0.0580298	total: 16.9s	remaining: 16.8s
# 5009:	learn: 0.0580275	total: 16.9s	remaining: 16.8s
# 5010:	learn: 0.0580258	total: 16.9s	remaining: 16.8s
# 5011:	learn: 0.0580246	total: 16.9s	remaining: 16.8s
# 5012:	learn: 0.0580221	total: 16.9s	remaining: 16.8s
# 5013:	learn: 0.0580190	total: 16.9s	remaining: 16.8s
# 5014:	learn: 0.0580163	total: 16.9s	remaining: 16.8s
# 5015:	learn: 0.0580141	total: 16.9s	remaining: 16.8s
# 5016:	learn: 0.0580080	total: 16.9s	remaining: 16.8s
# 5017:	learn: 0.0580048	total: 16.9s	remaining: 16.8s
# 5018:	learn: 0.0579980	total: 16.9s	remaining: 16.8s
# 5019:	learn: 0.0579882	total: 16.9s	remaining: 16.8s
# 5020:	learn: 0.0579875	total: 16.9s	remaining: 16.8s
# 5021:	learn: 0.0579860	total: 16.9s	remaining: 16.8s
# 5022:	learn: 0.0579841	total: 16.9s	remaining: 16.8s
# 5023:	learn: 0.0579817	total: 16.9s	remaining: 16.7s
# 5024:	learn: 0.0579798	total: 16.9s	remaining: 16.7s
# 5025:	learn: 0.0579791	total: 16.9s	remaining: 16.7s
# 5026:	learn: 0.0579731	total: 16.9s	remaining: 16.7s
# 5027:	learn: 0.0579728	total: 16.9s	remaining: 16.7s
# 5028:	learn: 0.0579694	total: 16.9s	remaining: 16.7s
# 5029:	learn: 0.0579646	total: 16.9s	remaining: 16.7s
# 5030:	learn: 0.0579603	total: 16.9s	remaining: 16.7s
# 5031:	learn: 0.0579559	total: 16.9s	remaining: 16.7s
# 5032:	learn: 0.0579512	total: 16.9s	remaining: 16.7s
# 5033:	learn: 0.0579500	total: 16.9s	remaining: 16.7s
# 5034:	learn: 0.0579487	total: 16.9s	remaining: 16.7s
# 5035:	learn: 0.0579429	total: 16.9s	remaining: 16.7s
# 5036:	learn: 0.0579382	total: 16.9s	remaining: 16.7s
# 5037:	learn: 0.0579379	total: 16.9s	remaining: 16.7s
# 5038:	learn: 0.0579307	total: 17s	remaining: 16.7s
# 5039:	learn: 0.0579264	total: 17s	remaining: 16.7s
# 5040:	learn: 0.0579254	total: 17s	remaining: 16.7s
# 5041:	learn: 0.0579215	total: 17s	remaining: 16.7s
# 5042:	learn: 0.0579179	total: 17s	remaining: 16.7s
# 5043:	learn: 0.0579170	total: 17s	remaining: 16.7s
# 5044:	learn: 0.0579118	total: 17s	remaining: 16.7s
# 5045:	learn: 0.0579114	total: 17s	remaining: 16.7s
# 5046:	learn: 0.0579076	total: 17s	remaining: 16.7s
# 5047:	learn: 0.0579068	total: 17s	remaining: 16.7s
# 5048:	learn: 0.0579029	total: 17s	remaining: 16.6s
# 5049:	learn: 0.0578992	total: 17s	remaining: 16.6s
# 5050:	learn: 0.0578969	total: 17s	remaining: 16.6s
# 5051:	learn: 0.0578929	total: 17s	remaining: 16.6s
# 5052:	learn: 0.0578862	total: 17s	remaining: 16.6s
# 5053:	learn: 0.0578804	total: 17s	remaining: 16.6s
# 5054:	learn: 0.0578779	total: 17s	remaining: 16.6s
# 5055:	learn: 0.0578732	total: 17s	remaining: 16.6s
# 5056:	learn: 0.0578649	total: 17s	remaining: 16.6s
# 5057:	learn: 0.0578636	total: 17s	remaining: 16.6s
# 5058:	learn: 0.0578631	total: 17s	remaining: 16.6s
# 5059:	learn: 0.0578603	total: 17s	remaining: 16.6s
# 5060:	learn: 0.0578548	total: 17s	remaining: 16.6s
# 5061:	learn: 0.0578541	total: 17s	remaining: 16.6s
# 5062:	learn: 0.0578520	total: 17s	remaining: 16.6s
# 5063:	learn: 0.0578491	total: 17s	remaining: 16.6s
# 5064:	learn: 0.0578468	total: 17s	remaining: 16.6s
# 5065:	learn: 0.0578379	total: 17s	remaining: 16.6s
# 5066:	learn: 0.0578331	total: 17s	remaining: 16.6s
# 5067:	learn: 0.0578297	total: 17s	remaining: 16.6s
# 5068:	learn: 0.0578261	total: 17s	remaining: 16.6s
# 5069:	learn: 0.0578251	total: 17s	remaining: 16.6s
# 5070:	learn: 0.0578230	total: 17s	remaining: 16.6s
# 5071:	learn: 0.0578210	total: 17s	remaining: 16.6s
# 5072:	learn: 0.0578193	total: 17s	remaining: 16.6s
# 5073:	learn: 0.0578167	total: 17s	remaining: 16.5s
# 5074:	learn: 0.0578112	total: 17s	remaining: 16.5s
# 5075:	learn: 0.0578068	total: 17.1s	remaining: 16.5s
# 5076:	learn: 0.0578048	total: 17.1s	remaining: 16.5s
# 5077:	learn: 0.0577988	total: 17.1s	remaining: 16.5s
# 5078:	learn: 0.0577971	total: 17.1s	remaining: 16.5s
# 5079:	learn: 0.0577898	total: 17.1s	remaining: 16.5s
# 5080:	learn: 0.0577881	total: 17.1s	remaining: 16.5s
# 5081:	learn: 0.0577864	total: 17.1s	remaining: 16.5s
# 5082:	learn: 0.0577856	total: 17.1s	remaining: 16.5s
# 5083:	learn: 0.0577834	total: 17.1s	remaining: 16.5s
# 5084:	learn: 0.0577787	total: 17.1s	remaining: 16.5s
# 5085:	learn: 0.0577752	total: 17.1s	remaining: 16.5s
# 5086:	learn: 0.0577720	total: 17.1s	remaining: 16.5s
# 5087:	learn: 0.0577707	total: 17.1s	remaining: 16.5s
# 5088:	learn: 0.0577698	total: 17.1s	remaining: 16.5s
# 5089:	learn: 0.0577681	total: 17.1s	remaining: 16.5s
# 5090:	learn: 0.0577630	total: 17.1s	remaining: 16.5s
# 5091:	learn: 0.0577623	total: 17.1s	remaining: 16.5s
# 5092:	learn: 0.0577560	total: 17.1s	remaining: 16.5s
# 5093:	learn: 0.0577546	total: 17.1s	remaining: 16.5s
# 5094:	learn: 0.0577491	total: 17.1s	remaining: 16.5s
# 5095:	learn: 0.0577448	total: 17.1s	remaining: 16.5s
# 5096:	learn: 0.0577441	total: 17.1s	remaining: 16.5s
# 5097:	learn: 0.0577407	total: 17.1s	remaining: 16.5s
# 5098:	learn: 0.0577389	total: 17.1s	remaining: 16.5s
# 5099:	learn: 0.0577301	total: 17.1s	remaining: 16.5s
# 5100:	learn: 0.0577204	total: 17.1s	remaining: 16.5s
# 5101:	learn: 0.0577156	total: 17.1s	remaining: 16.4s
# 5102:	learn: 0.0577123	total: 17.1s	remaining: 16.4s
# 5103:	learn: 0.0577086	total: 17.1s	remaining: 16.4s
# 5104:	learn: 0.0577029	total: 17.1s	remaining: 16.4s
# 5105:	learn: 0.0577000	total: 17.1s	remaining: 16.4s
# 5106:	learn: 0.0576916	total: 17.1s	remaining: 16.4s
# 5107:	learn: 0.0576850	total: 17.1s	remaining: 16.4s
# 5108:	learn: 0.0576831	total: 17.1s	remaining: 16.4s
# 5109:	learn: 0.0576818	total: 17.2s	remaining: 16.4s
# 5110:	learn: 0.0576800	total: 17.2s	remaining: 16.4s
# 5111:	learn: 0.0576756	total: 17.2s	remaining: 16.4s
# 5112:	learn: 0.0576696	total: 17.2s	remaining: 16.4s
# 5113:	learn: 0.0576677	total: 17.2s	remaining: 16.4s
# 5114:	learn: 0.0576647	total: 17.2s	remaining: 16.4s
# 5115:	learn: 0.0576606	total: 17.2s	remaining: 16.4s
# 5116:	learn: 0.0576520	total: 17.2s	remaining: 16.4s
# 5117:	learn: 0.0576502	total: 17.2s	remaining: 16.4s
# 5118:	learn: 0.0576442	total: 17.2s	remaining: 16.4s
# 5119:	learn: 0.0576401	total: 17.2s	remaining: 16.4s
# 5120:	learn: 0.0576391	total: 17.2s	remaining: 16.4s
# 5121:	learn: 0.0576380	total: 17.2s	remaining: 16.4s
# 5122:	learn: 0.0576338	total: 17.2s	remaining: 16.4s
# 5123:	learn: 0.0576305	total: 17.2s	remaining: 16.4s
# 5124:	learn: 0.0576279	total: 17.2s	remaining: 16.4s
# 5125:	learn: 0.0576253	total: 17.2s	remaining: 16.4s
# 5126:	learn: 0.0576234	total: 17.2s	remaining: 16.3s
# 5127:	learn: 0.0576192	total: 17.2s	remaining: 16.3s
# 5128:	learn: 0.0576142	total: 17.2s	remaining: 16.3s
# 5129:	learn: 0.0576138	total: 17.2s	remaining: 16.3s
# 5130:	learn: 0.0576128	total: 17.2s	remaining: 16.3s
# 5131:	learn: 0.0576077	total: 17.2s	remaining: 16.3s
# 5132:	learn: 0.0576057	total: 17.2s	remaining: 16.3s
# 5133:	learn: 0.0576011	total: 17.2s	remaining: 16.3s
# 5134:	learn: 0.0575983	total: 17.2s	remaining: 16.3s
# 5135:	learn: 0.0575959	total: 17.2s	remaining: 16.3s
# 5136:	learn: 0.0575940	total: 17.2s	remaining: 16.3s
# 5137:	learn: 0.0575882	total: 17.2s	remaining: 16.3s
# 5138:	learn: 0.0575825	total: 17.2s	remaining: 16.3s
# 5139:	learn: 0.0575820	total: 17.2s	remaining: 16.3s
# 5140:	learn: 0.0575801	total: 17.2s	remaining: 16.3s
# 5141:	learn: 0.0575795	total: 17.2s	remaining: 16.3s
# 5142:	learn: 0.0575758	total: 17.2s	remaining: 16.3s
# 5143:	learn: 0.0575732	total: 17.2s	remaining: 16.3s
# 5144:	learn: 0.0575716	total: 17.2s	remaining: 16.3s
# 5145:	learn: 0.0575709	total: 17.3s	remaining: 16.3s
# 5146:	learn: 0.0575680	total: 17.3s	remaining: 16.3s
# 5147:	learn: 0.0575642	total: 17.3s	remaining: 16.3s
# 5148:	learn: 0.0575572	total: 17.3s	remaining: 16.3s
# 5149:	learn: 0.0575561	total: 17.3s	remaining: 16.3s
# 5150:	learn: 0.0575532	total: 17.3s	remaining: 16.3s
# 5151:	learn: 0.0575491	total: 17.3s	remaining: 16.3s
# 5152:	learn: 0.0575486	total: 17.3s	remaining: 16.3s
# 5153:	learn: 0.0575470	total: 17.3s	remaining: 16.2s
# 5154:	learn: 0.0575452	total: 17.3s	remaining: 16.2s
# 5155:	learn: 0.0575411	total: 17.3s	remaining: 16.2s
# 5156:	learn: 0.0575385	total: 17.3s	remaining: 16.2s
# 5157:	learn: 0.0575372	total: 17.3s	remaining: 16.2s
# 5158:	learn: 0.0575312	total: 17.3s	remaining: 16.2s
# 5159:	learn: 0.0575298	total: 17.3s	remaining: 16.2s
# 5160:	learn: 0.0575269	total: 17.3s	remaining: 16.2s
# 5161:	learn: 0.0575213	total: 17.3s	remaining: 16.2s
# 5162:	learn: 0.0575193	total: 17.3s	remaining: 16.2s
# 5163:	learn: 0.0575165	total: 17.3s	remaining: 16.2s
# 5164:	learn: 0.0575138	total: 17.3s	remaining: 16.2s
# 5165:	learn: 0.0575114	total: 17.3s	remaining: 16.2s
# 5166:	learn: 0.0575102	total: 17.3s	remaining: 16.2s
# 5167:	learn: 0.0575076	total: 17.3s	remaining: 16.2s
# 5168:	learn: 0.0575000	total: 17.3s	remaining: 16.2s
# 5169:	learn: 0.0574986	total: 17.3s	remaining: 16.2s
# 5170:	learn: 0.0574976	total: 17.3s	remaining: 16.2s
# 5171:	learn: 0.0574926	total: 17.3s	remaining: 16.2s
# 5172:	learn: 0.0574884	total: 17.3s	remaining: 16.2s
# 5173:	learn: 0.0574861	total: 17.3s	remaining: 16.2s
# 5174:	learn: 0.0574830	total: 17.3s	remaining: 16.2s
# 5175:	learn: 0.0574806	total: 17.3s	remaining: 16.2s
# 5176:	learn: 0.0574790	total: 17.3s	remaining: 16.2s
# 5177:	learn: 0.0574725	total: 17.3s	remaining: 16.1s
# 5178:	learn: 0.0574683	total: 17.3s	remaining: 16.1s
# 5179:	learn: 0.0574657	total: 17.3s	remaining: 16.1s
# 5180:	learn: 0.0574612	total: 17.4s	remaining: 16.1s
# 5181:	learn: 0.0574589	total: 17.4s	remaining: 16.1s
# 5182:	learn: 0.0574540	total: 17.4s	remaining: 16.1s
# 5183:	learn: 0.0574475	total: 17.4s	remaining: 16.1s
# 5184:	learn: 0.0574445	total: 17.4s	remaining: 16.1s
# 5185:	learn: 0.0574422	total: 17.4s	remaining: 16.1s
# 5186:	learn: 0.0574366	total: 17.4s	remaining: 16.1s
# 5187:	learn: 0.0574345	total: 17.4s	remaining: 16.1s
# 5188:	learn: 0.0574294	total: 17.4s	remaining: 16.1s
# 5189:	learn: 0.0574264	total: 17.4s	remaining: 16.1s
# 5190:	learn: 0.0574192	total: 17.4s	remaining: 16.1s
# 5191:	learn: 0.0574119	total: 17.4s	remaining: 16.1s
# 5192:	learn: 0.0574080	total: 17.4s	remaining: 16.1s
# 5193:	learn: 0.0574051	total: 17.4s	remaining: 16.1s
# 5194:	learn: 0.0574036	total: 17.4s	remaining: 16.1s
# 5195:	learn: 0.0573986	total: 17.4s	remaining: 16.1s
# 5196:	learn: 0.0573951	total: 17.4s	remaining: 16.1s
# 5197:	learn: 0.0573947	total: 17.4s	remaining: 16.1s
# 5198:	learn: 0.0573923	total: 17.4s	remaining: 16.1s
# 5199:	learn: 0.0573898	total: 17.4s	remaining: 16.1s
# 5200:	learn: 0.0573881	total: 17.4s	remaining: 16.1s
# 5201:	learn: 0.0573827	total: 17.4s	remaining: 16.1s
# 5202:	learn: 0.0573764	total: 17.4s	remaining: 16.1s
# 5203:	learn: 0.0573723	total: 17.4s	remaining: 16s
# 5204:	learn: 0.0573657	total: 17.4s	remaining: 16s
# 5205:	learn: 0.0573610	total: 17.4s	remaining: 16s
# 5206:	learn: 0.0573555	total: 17.4s	remaining: 16s
# 5207:	learn: 0.0573491	total: 17.4s	remaining: 16s
# 5208:	learn: 0.0573473	total: 17.4s	remaining: 16s
# 5209:	learn: 0.0573432	total: 17.4s	remaining: 16s
# 5210:	learn: 0.0573403	total: 17.4s	remaining: 16s
# 5211:	learn: 0.0573351	total: 17.4s	remaining: 16s
# 5212:	learn: 0.0573303	total: 17.4s	remaining: 16s
# 5213:	learn: 0.0573298	total: 17.4s	remaining: 16s
# 5214:	learn: 0.0573275	total: 17.4s	remaining: 16s
# 5215:	learn: 0.0573247	total: 17.4s	remaining: 16s
# 5216:	learn: 0.0573213	total: 17.4s	remaining: 16s
# 5217:	learn: 0.0573196	total: 17.4s	remaining: 16s
# 5218:	learn: 0.0573163	total: 17.5s	remaining: 16s
# 5219:	learn: 0.0573128	total: 17.5s	remaining: 16s
# 5220:	learn: 0.0573100	total: 17.5s	remaining: 16s
# 5221:	learn: 0.0573090	total: 17.5s	remaining: 16s
# 5222:	learn: 0.0573070	total: 17.5s	remaining: 16s
# 5223:	learn: 0.0573022	total: 17.5s	remaining: 16s
# 5224:	learn: 0.0573000	total: 17.5s	remaining: 16s
# 5225:	learn: 0.0572956	total: 17.5s	remaining: 16s
# 5226:	learn: 0.0572945	total: 17.5s	remaining: 16s
# 5227:	learn: 0.0572920	total: 17.5s	remaining: 16s
# 5228:	learn: 0.0572878	total: 17.5s	remaining: 16s
# 5229:	learn: 0.0572873	total: 17.5s	remaining: 15.9s
# 5230:	learn: 0.0572861	total: 17.5s	remaining: 15.9s
# 5231:	learn: 0.0572852	total: 17.5s	remaining: 15.9s
# 5232:	learn: 0.0572814	total: 17.5s	remaining: 15.9s
# 5233:	learn: 0.0572788	total: 17.5s	remaining: 15.9s
# 5234:	learn: 0.0572760	total: 17.5s	remaining: 15.9s
# 5235:	learn: 0.0572752	total: 17.5s	remaining: 15.9s
# 5236:	learn: 0.0572674	total: 17.5s	remaining: 15.9s
# 5237:	learn: 0.0572541	total: 17.5s	remaining: 15.9s
# 5238:	learn: 0.0572501	total: 17.5s	remaining: 15.9s
# 5239:	learn: 0.0572462	total: 17.5s	remaining: 15.9s
# 5240:	learn: 0.0572433	total: 17.5s	remaining: 15.9s
# 5241:	learn: 0.0572413	total: 17.5s	remaining: 15.9s
# 5242:	learn: 0.0572373	total: 17.5s	remaining: 15.9s
# 5243:	learn: 0.0572359	total: 17.5s	remaining: 15.9s
# 5244:	learn: 0.0572341	total: 17.5s	remaining: 15.9s
# 5245:	learn: 0.0572335	total: 17.5s	remaining: 15.9s
# 5246:	learn: 0.0572284	total: 17.5s	remaining: 15.9s
# 5247:	learn: 0.0572256	total: 17.5s	remaining: 15.9s
# 5248:	learn: 0.0572225	total: 17.5s	remaining: 15.9s
# 5249:	learn: 0.0572202	total: 17.5s	remaining: 15.9s
# 5250:	learn: 0.0572158	total: 17.5s	remaining: 15.9s
# 5251:	learn: 0.0572110	total: 17.5s	remaining: 15.9s
# 5252:	learn: 0.0572107	total: 17.5s	remaining: 15.9s
# 5253:	learn: 0.0572060	total: 17.6s	remaining: 15.9s
# 5254:	learn: 0.0572015	total: 17.6s	remaining: 15.8s
# 5255:	learn: 0.0571989	total: 17.6s	remaining: 15.8s
# 5256:	learn: 0.0571965	total: 17.6s	remaining: 15.8s
# 5257:	learn: 0.0571946	total: 17.6s	remaining: 15.8s
# 5258:	learn: 0.0571934	total: 17.6s	remaining: 15.8s
# 5259:	learn: 0.0571900	total: 17.6s	remaining: 15.8s
# 5260:	learn: 0.0571869	total: 17.6s	remaining: 15.8s
# 5261:	learn: 0.0571829	total: 17.6s	remaining: 15.8s
# 5262:	learn: 0.0571787	total: 17.6s	remaining: 15.8s
# 5263:	learn: 0.0571769	total: 17.6s	remaining: 15.8s
# 5264:	learn: 0.0571751	total: 17.6s	remaining: 15.8s
# 5265:	learn: 0.0571733	total: 17.6s	remaining: 15.8s
# 5266:	learn: 0.0571698	total: 17.6s	remaining: 15.8s
# 5267:	learn: 0.0571690	total: 17.6s	remaining: 15.8s
# 5268:	learn: 0.0571652	total: 17.6s	remaining: 15.8s
# 5269:	learn: 0.0571619	total: 17.6s	remaining: 15.8s
# 5270:	learn: 0.0571593	total: 17.6s	remaining: 15.8s
# 5271:	learn: 0.0571554	total: 17.6s	remaining: 15.8s
# 5272:	learn: 0.0571508	total: 17.6s	remaining: 15.8s
# 5273:	learn: 0.0571480	total: 17.6s	remaining: 15.8s
# 5274:	learn: 0.0571429	total: 17.6s	remaining: 15.8s
# 5275:	learn: 0.0571399	total: 17.6s	remaining: 15.8s
# 5276:	learn: 0.0571378	total: 17.6s	remaining: 15.8s
# 5277:	learn: 0.0571363	total: 17.6s	remaining: 15.8s
# 5278:	learn: 0.0571347	total: 17.6s	remaining: 15.8s
# 5279:	learn: 0.0571318	total: 17.6s	remaining: 15.8s
# 5280:	learn: 0.0571276	total: 17.6s	remaining: 15.7s
# 5281:	learn: 0.0571260	total: 17.6s	remaining: 15.7s
# 5282:	learn: 0.0571242	total: 17.6s	remaining: 15.7s
# 5283:	learn: 0.0571207	total: 17.6s	remaining: 15.7s
# 5284:	learn: 0.0571187	total: 17.6s	remaining: 15.7s
# 5285:	learn: 0.0571122	total: 17.6s	remaining: 15.7s
# 5286:	learn: 0.0571076	total: 17.6s	remaining: 15.7s
# 5287:	learn: 0.0571026	total: 17.6s	remaining: 15.7s
# 5288:	learn: 0.0570988	total: 17.6s	remaining: 15.7s
# 5289:	learn: 0.0570935	total: 17.6s	remaining: 15.7s
# 5290:	learn: 0.0570924	total: 17.7s	remaining: 15.7s
# 5291:	learn: 0.0570870	total: 17.7s	remaining: 15.7s
# 5292:	learn: 0.0570861	total: 17.7s	remaining: 15.7s
# 5293:	learn: 0.0570842	total: 17.7s	remaining: 15.7s
# 5294:	learn: 0.0570831	total: 17.7s	remaining: 15.7s
# 5295:	learn: 0.0570777	total: 17.7s	remaining: 15.7s
# 5296:	learn: 0.0570734	total: 17.7s	remaining: 15.7s
# 5297:	learn: 0.0570714	total: 17.7s	remaining: 15.7s
# 5298:	learn: 0.0570690	total: 17.7s	remaining: 15.7s
# 5299:	learn: 0.0570657	total: 17.7s	remaining: 15.7s
# 5300:	learn: 0.0570644	total: 17.7s	remaining: 15.7s
# 5301:	learn: 0.0570625	total: 17.7s	remaining: 15.7s
# 5302:	learn: 0.0570608	total: 17.7s	remaining: 15.7s
# 5303:	learn: 0.0570553	total: 17.7s	remaining: 15.7s
# 5304:	learn: 0.0570539	total: 17.7s	remaining: 15.7s
# 5305:	learn: 0.0570518	total: 17.7s	remaining: 15.7s
# 5306:	learn: 0.0570509	total: 17.7s	remaining: 15.7s
# 5307:	learn: 0.0570492	total: 17.7s	remaining: 15.7s
# 5308:	learn: 0.0570433	total: 17.7s	remaining: 15.7s
# 5309:	learn: 0.0570422	total: 17.7s	remaining: 15.7s
# 5310:	learn: 0.0570379	total: 17.7s	remaining: 15.6s
# 5311:	learn: 0.0570324	total: 17.7s	remaining: 15.6s
# 5312:	learn: 0.0570296	total: 17.7s	remaining: 15.6s
# 5313:	learn: 0.0570277	total: 17.7s	remaining: 15.6s
# 5314:	learn: 0.0570248	total: 17.7s	remaining: 15.6s
# 5315:	learn: 0.0570240	total: 17.7s	remaining: 15.6s
# 5316:	learn: 0.0570213	total: 17.7s	remaining: 15.6s
# 5317:	learn: 0.0570200	total: 17.7s	remaining: 15.6s
# 5318:	learn: 0.0570146	total: 17.7s	remaining: 15.6s
# 5319:	learn: 0.0570115	total: 17.7s	remaining: 15.6s
# 5320:	learn: 0.0570079	total: 17.8s	remaining: 15.6s
# 5321:	learn: 0.0570043	total: 17.8s	remaining: 15.6s
# 5322:	learn: 0.0570022	total: 17.8s	remaining: 15.6s
# 5323:	learn: 0.0569997	total: 17.8s	remaining: 15.6s
# 5324:	learn: 0.0569957	total: 17.8s	remaining: 15.6s
# 5325:	learn: 0.0569920	total: 17.8s	remaining: 15.6s
# 5326:	learn: 0.0569861	total: 17.8s	remaining: 15.6s
# 5327:	learn: 0.0569822	total: 17.8s	remaining: 15.6s
# 5328:	learn: 0.0569767	total: 17.8s	remaining: 15.6s
# 5329:	learn: 0.0569742	total: 17.8s	remaining: 15.6s
# 5330:	learn: 0.0569692	total: 17.8s	remaining: 15.6s
# 5331:	learn: 0.0569670	total: 17.8s	remaining: 15.6s
# 5332:	learn: 0.0569652	total: 17.8s	remaining: 15.6s
# 5333:	learn: 0.0569638	total: 17.8s	remaining: 15.6s
# 5334:	learn: 0.0569606	total: 17.8s	remaining: 15.6s
# 5335:	learn: 0.0569556	total: 17.8s	remaining: 15.6s
# 5336:	learn: 0.0569520	total: 17.8s	remaining: 15.5s
# 5337:	learn: 0.0569502	total: 17.8s	remaining: 15.5s
# 5338:	learn: 0.0569471	total: 17.8s	remaining: 15.5s
# 5339:	learn: 0.0569465	total: 17.8s	remaining: 15.5s
# 5340:	learn: 0.0569446	total: 17.8s	remaining: 15.5s
# 5341:	learn: 0.0569431	total: 17.8s	remaining: 15.5s
# 5342:	learn: 0.0569416	total: 17.8s	remaining: 15.5s
# 5343:	learn: 0.0569402	total: 17.8s	remaining: 15.5s
# 5344:	learn: 0.0569341	total: 17.8s	remaining: 15.5s
# 5345:	learn: 0.0569291	total: 17.8s	remaining: 15.5s
# 5346:	learn: 0.0569252	total: 17.8s	remaining: 15.5s
# 5347:	learn: 0.0569223	total: 17.8s	remaining: 15.5s
# 5348:	learn: 0.0569178	total: 17.8s	remaining: 15.5s
# 5349:	learn: 0.0569167	total: 17.8s	remaining: 15.5s
# 5350:	learn: 0.0569135	total: 17.8s	remaining: 15.5s
# 5351:	learn: 0.0569125	total: 17.8s	remaining: 15.5s
# 5352:	learn: 0.0569114	total: 17.8s	remaining: 15.5s
# 5353:	learn: 0.0569091	total: 17.8s	remaining: 15.5s
# 5354:	learn: 0.0569042	total: 17.8s	remaining: 15.5s
# 5355:	learn: 0.0568970	total: 17.8s	remaining: 15.5s
# 5356:	learn: 0.0568927	total: 17.9s	remaining: 15.5s
# 5357:	learn: 0.0568863	total: 17.9s	remaining: 15.5s
# 5358:	learn: 0.0568790	total: 17.9s	remaining: 15.5s
# 5359:	learn: 0.0568732	total: 17.9s	remaining: 15.5s
# 5360:	learn: 0.0568722	total: 17.9s	remaining: 15.5s
# 5361:	learn: 0.0568714	total: 17.9s	remaining: 15.5s
# 5362:	learn: 0.0568693	total: 17.9s	remaining: 15.5s
# 5363:	learn: 0.0568678	total: 17.9s	remaining: 15.5s
# 5364:	learn: 0.0568663	total: 17.9s	remaining: 15.5s
# 5365:	learn: 0.0568611	total: 17.9s	remaining: 15.4s
# 5366:	learn: 0.0568591	total: 17.9s	remaining: 15.4s
# 5367:	learn: 0.0568563	total: 17.9s	remaining: 15.4s
# 5368:	learn: 0.0568508	total: 17.9s	remaining: 15.4s
# 5369:	learn: 0.0568487	total: 17.9s	remaining: 15.4s
# 5370:	learn: 0.0568461	total: 17.9s	remaining: 15.4s
# 5371:	learn: 0.0568453	total: 17.9s	remaining: 15.4s
# 5372:	learn: 0.0568431	total: 17.9s	remaining: 15.4s
# 5373:	learn: 0.0568382	total: 17.9s	remaining: 15.4s
# 5374:	learn: 0.0568336	total: 17.9s	remaining: 15.4s
# 5375:	learn: 0.0568315	total: 17.9s	remaining: 15.4s
# 5376:	learn: 0.0568245	total: 17.9s	remaining: 15.4s
# 5377:	learn: 0.0568234	total: 17.9s	remaining: 15.4s
# 5378:	learn: 0.0568162	total: 17.9s	remaining: 15.4s
# 5379:	learn: 0.0568116	total: 17.9s	remaining: 15.4s
# 5380:	learn: 0.0568107	total: 17.9s	remaining: 15.4s
# 5381:	learn: 0.0568101	total: 17.9s	remaining: 15.4s
# 5382:	learn: 0.0568046	total: 17.9s	remaining: 15.4s
# 5383:	learn: 0.0568041	total: 17.9s	remaining: 15.4s
# 5384:	learn: 0.0567989	total: 17.9s	remaining: 15.4s
# 5385:	learn: 0.0567936	total: 17.9s	remaining: 15.4s
# 5386:	learn: 0.0567925	total: 17.9s	remaining: 15.4s
# 5387:	learn: 0.0567881	total: 17.9s	remaining: 15.4s
# 5388:	learn: 0.0567867	total: 18s	remaining: 15.4s
# 5389:	learn: 0.0567846	total: 18s	remaining: 15.4s
# 5390:	learn: 0.0567833	total: 18s	remaining: 15.4s
# 5391:	learn: 0.0567814	total: 18s	remaining: 15.3s
# 5392:	learn: 0.0567785	total: 18s	remaining: 15.3s
# 5393:	learn: 0.0567772	total: 18s	remaining: 15.3s
# 5394:	learn: 0.0567728	total: 18s	remaining: 15.3s
# 5395:	learn: 0.0567717	total: 18s	remaining: 15.3s
# 5396:	learn: 0.0567697	total: 18s	remaining: 15.3s
# 5397:	learn: 0.0567695	total: 18s	remaining: 15.3s
# 5398:	learn: 0.0567677	total: 18s	remaining: 15.3s
# 5399:	learn: 0.0567661	total: 18s	remaining: 15.3s
# 5400:	learn: 0.0567631	total: 18s	remaining: 15.3s
# 5401:	learn: 0.0567613	total: 18s	remaining: 15.3s
# 5402:	learn: 0.0567560	total: 18s	remaining: 15.3s
# 5403:	learn: 0.0567549	total: 18s	remaining: 15.3s
# 5404:	learn: 0.0567513	total: 18s	remaining: 15.3s
# 5405:	learn: 0.0567493	total: 18s	remaining: 15.3s
# 5406:	learn: 0.0567447	total: 18s	remaining: 15.3s
# 5407:	learn: 0.0567361	total: 18s	remaining: 15.3s
# 5408:	learn: 0.0567346	total: 18s	remaining: 15.3s
# 5409:	learn: 0.0567334	total: 18s	remaining: 15.3s
# 5410:	learn: 0.0567324	total: 18s	remaining: 15.3s
# 5411:	learn: 0.0567281	total: 18s	remaining: 15.3s
# 5412:	learn: 0.0567237	total: 18s	remaining: 15.3s
# 5413:	learn: 0.0567227	total: 18s	remaining: 15.3s
# 5414:	learn: 0.0567206	total: 18s	remaining: 15.3s
# 5415:	learn: 0.0567180	total: 18s	remaining: 15.3s
# 5416:	learn: 0.0567155	total: 18s	remaining: 15.3s
# 5417:	learn: 0.0567124	total: 18s	remaining: 15.2s
# 5418:	learn: 0.0567055	total: 18s	remaining: 15.2s
# 5419:	learn: 0.0567039	total: 18s	remaining: 15.2s
# 5420:	learn: 0.0566984	total: 18s	remaining: 15.2s
# 5421:	learn: 0.0566964	total: 18s	remaining: 15.2s
# 5422:	learn: 0.0566907	total: 18s	remaining: 15.2s
# 5423:	learn: 0.0566879	total: 18s	remaining: 15.2s
# 5424:	learn: 0.0566777	total: 18s	remaining: 15.2s
# 5425:	learn: 0.0566738	total: 18.1s	remaining: 15.2s
# 5426:	learn: 0.0566698	total: 18.1s	remaining: 15.2s
# 5427:	learn: 0.0566686	total: 18.1s	remaining: 15.2s
# 5428:	learn: 0.0566658	total: 18.1s	remaining: 15.2s
# 5429:	learn: 0.0566654	total: 18.1s	remaining: 15.2s
# 5430:	learn: 0.0566636	total: 18.1s	remaining: 15.2s
# 5431:	learn: 0.0566602	total: 18.1s	remaining: 15.2s
# 5432:	learn: 0.0566521	total: 18.1s	remaining: 15.2s
# 5433:	learn: 0.0566500	total: 18.1s	remaining: 15.2s
# 5434:	learn: 0.0566487	total: 18.1s	remaining: 15.2s
# 5435:	learn: 0.0566459	total: 18.1s	remaining: 15.2s
# 5436:	learn: 0.0566455	total: 18.1s	remaining: 15.2s
# 5437:	learn: 0.0566417	total: 18.1s	remaining: 15.2s
# 5438:	learn: 0.0566344	total: 18.1s	remaining: 15.2s
# 5439:	learn: 0.0566329	total: 18.1s	remaining: 15.2s
# 5440:	learn: 0.0566311	total: 18.1s	remaining: 15.2s
# 5441:	learn: 0.0566287	total: 18.1s	remaining: 15.2s
# 5442:	learn: 0.0566282	total: 18.1s	remaining: 15.2s
# 5443:	learn: 0.0566214	total: 18.1s	remaining: 15.2s
# 5444:	learn: 0.0566124	total: 18.1s	remaining: 15.1s
# 5445:	learn: 0.0566095	total: 18.1s	remaining: 15.1s
# 5446:	learn: 0.0566064	total: 18.1s	remaining: 15.1s
# 5447:	learn: 0.0566030	total: 18.1s	remaining: 15.1s
# 5448:	learn: 0.0566007	total: 18.1s	remaining: 15.1s
# 5449:	learn: 0.0565980	total: 18.1s	remaining: 15.1s
# 5450:	learn: 0.0565973	total: 18.1s	remaining: 15.1s
# 5451:	learn: 0.0565953	total: 18.1s	remaining: 15.1s
# 5452:	learn: 0.0565950	total: 18.1s	remaining: 15.1s
# 5453:	learn: 0.0565898	total: 18.1s	remaining: 15.1s
# 5454:	learn: 0.0565880	total: 18.1s	remaining: 15.1s
# 5455:	learn: 0.0565831	total: 18.1s	remaining: 15.1s
# 5456:	learn: 0.0565810	total: 18.1s	remaining: 15.1s
# 5457:	learn: 0.0565756	total: 18.1s	remaining: 15.1s
# 5458:	learn: 0.0565697	total: 18.1s	remaining: 15.1s
# 5459:	learn: 0.0565653	total: 18.1s	remaining: 15.1s
# 5460:	learn: 0.0565633	total: 18.1s	remaining: 15.1s
# 5461:	learn: 0.0565616	total: 18.2s	remaining: 15.1s
# 5462:	learn: 0.0565558	total: 18.2s	remaining: 15.1s
# 5463:	learn: 0.0565551	total: 18.2s	remaining: 15.1s
# 5464:	learn: 0.0565484	total: 18.2s	remaining: 15.1s
# 5465:	learn: 0.0565418	total: 18.2s	remaining: 15.1s
# 5466:	learn: 0.0565387	total: 18.2s	remaining: 15.1s
# 5467:	learn: 0.0565344	total: 18.2s	remaining: 15.1s
# 5468:	learn: 0.0565316	total: 18.2s	remaining: 15.1s
# 5469:	learn: 0.0565288	total: 18.2s	remaining: 15.1s
# 5470:	learn: 0.0565255	total: 18.2s	remaining: 15s
# 5471:	learn: 0.0565206	total: 18.2s	remaining: 15s
# 5472:	learn: 0.0565200	total: 18.2s	remaining: 15s
# 5473:	learn: 0.0565151	total: 18.2s	remaining: 15s
# 5474:	learn: 0.0565133	total: 18.2s	remaining: 15s
# 5475:	learn: 0.0565094	total: 18.2s	remaining: 15s
# 5476:	learn: 0.0565027	total: 18.2s	remaining: 15s
# 5477:	learn: 0.0564988	total: 18.2s	remaining: 15s
# 5478:	learn: 0.0564942	total: 18.2s	remaining: 15s
# 5479:	learn: 0.0564896	total: 18.2s	remaining: 15s
# 5480:	learn: 0.0564853	total: 18.2s	remaining: 15s
# 5481:	learn: 0.0564836	total: 18.2s	remaining: 15s
# 5482:	learn: 0.0564829	total: 18.2s	remaining: 15s
# 5483:	learn: 0.0564825	total: 18.2s	remaining: 15s
# 5484:	learn: 0.0564774	total: 18.2s	remaining: 15s
# 5485:	learn: 0.0564757	total: 18.2s	remaining: 15s
# 5486:	learn: 0.0564739	total: 18.2s	remaining: 15s
# 5487:	learn: 0.0564713	total: 18.2s	remaining: 15s
# 5488:	learn: 0.0564680	total: 18.2s	remaining: 15s
# 5489:	learn: 0.0564636	total: 18.2s	remaining: 15s
# 5490:	learn: 0.0564595	total: 18.2s	remaining: 15s
# 5491:	learn: 0.0564584	total: 18.2s	remaining: 15s
# 5492:	learn: 0.0564546	total: 18.2s	remaining: 15s
# 5493:	learn: 0.0564523	total: 18.2s	remaining: 15s
# 5494:	learn: 0.0564505	total: 18.2s	remaining: 15s
# 5495:	learn: 0.0564477	total: 18.2s	remaining: 15s
# 5496:	learn: 0.0564446	total: 18.2s	remaining: 14.9s
# 5497:	learn: 0.0564416	total: 18.3s	remaining: 14.9s
# 5498:	learn: 0.0564408	total: 18.3s	remaining: 14.9s
# 5499:	learn: 0.0564386	total: 18.3s	remaining: 14.9s
# 5500:	learn: 0.0564300	total: 18.3s	remaining: 14.9s
# 5501:	learn: 0.0564291	total: 18.3s	remaining: 14.9s
# 5502:	learn: 0.0564282	total: 18.3s	remaining: 14.9s
# 5503:	learn: 0.0564228	total: 18.3s	remaining: 14.9s
# 5504:	learn: 0.0564195	total: 18.3s	remaining: 14.9s
# 5505:	learn: 0.0564143	total: 18.3s	remaining: 14.9s
# 5506:	learn: 0.0564105	total: 18.3s	remaining: 14.9s
# 5507:	learn: 0.0564076	total: 18.3s	remaining: 14.9s
# 5508:	learn: 0.0564070	total: 18.3s	remaining: 14.9s
# 5509:	learn: 0.0564036	total: 18.3s	remaining: 14.9s
# 5510:	learn: 0.0563960	total: 18.3s	remaining: 14.9s
# 5511:	learn: 0.0563956	total: 18.3s	remaining: 14.9s
# 5512:	learn: 0.0563850	total: 18.3s	remaining: 14.9s
# 5513:	learn: 0.0563814	total: 18.3s	remaining: 14.9s
# 5514:	learn: 0.0563774	total: 18.3s	remaining: 14.9s
# 5515:	learn: 0.0563744	total: 18.3s	remaining: 14.9s
# 5516:	learn: 0.0563672	total: 18.3s	remaining: 14.9s
# 5517:	learn: 0.0563668	total: 18.3s	remaining: 14.9s
# 5518:	learn: 0.0563643	total: 18.3s	remaining: 14.9s
# 5519:	learn: 0.0563628	total: 18.3s	remaining: 14.9s
# 5520:	learn: 0.0563604	total: 18.3s	remaining: 14.9s
# 5521:	learn: 0.0563598	total: 18.3s	remaining: 14.9s
# 5522:	learn: 0.0563589	total: 18.3s	remaining: 14.9s
# 5523:	learn: 0.0563555	total: 18.3s	remaining: 14.9s
# 5524:	learn: 0.0563542	total: 18.3s	remaining: 14.8s
# 5525:	learn: 0.0563497	total: 18.3s	remaining: 14.8s
# 5526:	learn: 0.0563449	total: 18.3s	remaining: 14.8s
# 5527:	learn: 0.0563442	total: 18.3s	remaining: 14.8s
# 5528:	learn: 0.0563392	total: 18.3s	remaining: 14.8s
# 5529:	learn: 0.0563358	total: 18.3s	remaining: 14.8s
# 5530:	learn: 0.0563316	total: 18.3s	remaining: 14.8s
# 5531:	learn: 0.0563243	total: 18.3s	remaining: 14.8s
# 5532:	learn: 0.0563221	total: 18.4s	remaining: 14.8s
# 5533:	learn: 0.0563171	total: 18.4s	remaining: 14.8s
# 5534:	learn: 0.0563120	total: 18.4s	remaining: 14.8s
# 5535:	learn: 0.0563109	total: 18.4s	remaining: 14.8s
# 5536:	learn: 0.0563064	total: 18.4s	remaining: 14.8s
# 5537:	learn: 0.0563051	total: 18.4s	remaining: 14.8s
# 5538:	learn: 0.0563035	total: 18.4s	remaining: 14.8s
# 5539:	learn: 0.0562991	total: 18.4s	remaining: 14.8s
# 5540:	learn: 0.0562977	total: 18.4s	remaining: 14.8s
# 5541:	learn: 0.0562973	total: 18.4s	remaining: 14.8s
# 5542:	learn: 0.0562962	total: 18.4s	remaining: 14.8s
# 5543:	learn: 0.0562932	total: 18.4s	remaining: 14.8s
# 5544:	learn: 0.0562862	total: 18.4s	remaining: 14.8s
# 5545:	learn: 0.0562854	total: 18.4s	remaining: 14.8s
# 5546:	learn: 0.0562819	total: 18.4s	remaining: 14.8s
# 5547:	learn: 0.0562806	total: 18.4s	remaining: 14.8s
# 5548:	learn: 0.0562746	total: 18.4s	remaining: 14.8s
# 5549:	learn: 0.0562734	total: 18.4s	remaining: 14.8s
# 5550:	learn: 0.0562707	total: 18.4s	remaining: 14.7s
# 5551:	learn: 0.0562646	total: 18.4s	remaining: 14.7s
# 5552:	learn: 0.0562536	total: 18.4s	remaining: 14.7s
# 5553:	learn: 0.0562452	total: 18.4s	remaining: 14.7s
# 5554:	learn: 0.0562413	total: 18.4s	remaining: 14.7s
# 5555:	learn: 0.0562394	total: 18.4s	remaining: 14.7s
# 5556:	learn: 0.0562353	total: 18.4s	remaining: 14.7s
# 5557:	learn: 0.0562341	total: 18.4s	remaining: 14.7s
# 5558:	learn: 0.0562267	total: 18.4s	remaining: 14.7s
# 5559:	learn: 0.0562241	total: 18.4s	remaining: 14.7s
# 5560:	learn: 0.0562227	total: 18.4s	remaining: 14.7s
# 5561:	learn: 0.0562160	total: 18.4s	remaining: 14.7s
# 5562:	learn: 0.0562158	total: 18.4s	remaining: 14.7s
# 5563:	learn: 0.0562089	total: 18.4s	remaining: 14.7s
# 5564:	learn: 0.0562069	total: 18.4s	remaining: 14.7s
# 5565:	learn: 0.0562056	total: 18.4s	remaining: 14.7s
# 5566:	learn: 0.0562028	total: 18.4s	remaining: 14.7s
# 5567:	learn: 0.0562020	total: 18.4s	remaining: 14.7s
# 5568:	learn: 0.0561995	total: 18.5s	remaining: 14.7s
# 5569:	learn: 0.0561959	total: 18.5s	remaining: 14.7s
# 5570:	learn: 0.0561940	total: 18.5s	remaining: 14.7s
# 5571:	learn: 0.0561895	total: 18.5s	remaining: 14.7s
# 5572:	learn: 0.0561868	total: 18.5s	remaining: 14.7s
# 5573:	learn: 0.0561831	total: 18.5s	remaining: 14.7s
# 5574:	learn: 0.0561782	total: 18.5s	remaining: 14.7s
# 5575:	learn: 0.0561755	total: 18.5s	remaining: 14.7s
# 5576:	learn: 0.0561746	total: 18.5s	remaining: 14.7s
# 5577:	learn: 0.0561694	total: 18.5s	remaining: 14.7s
# 5578:	learn: 0.0561672	total: 18.5s	remaining: 14.6s
# 5579:	learn: 0.0561606	total: 18.5s	remaining: 14.6s
# 5580:	learn: 0.0561545	total: 18.5s	remaining: 14.6s
# 5581:	learn: 0.0561540	total: 18.5s	remaining: 14.6s
# 5582:	learn: 0.0561526	total: 18.5s	remaining: 14.6s
# 5583:	learn: 0.0561509	total: 18.5s	remaining: 14.6s
# 5584:	learn: 0.0561498	total: 18.5s	remaining: 14.6s
# 5585:	learn: 0.0561483	total: 18.5s	remaining: 14.6s
# 5586:	learn: 0.0561473	total: 18.5s	remaining: 14.6s
# 5587:	learn: 0.0561439	total: 18.5s	remaining: 14.6s
# 5588:	learn: 0.0561377	total: 18.5s	remaining: 14.6s
# 5589:	learn: 0.0561363	total: 18.5s	remaining: 14.6s
# 5590:	learn: 0.0561337	total: 18.5s	remaining: 14.6s
# 5591:	learn: 0.0561293	total: 18.5s	remaining: 14.6s
# 5592:	learn: 0.0561266	total: 18.5s	remaining: 14.6s
# 5593:	learn: 0.0561230	total: 18.5s	remaining: 14.6s
# 5594:	learn: 0.0561193	total: 18.5s	remaining: 14.6s
# 5595:	learn: 0.0561180	total: 18.5s	remaining: 14.6s
# 5596:	learn: 0.0561162	total: 18.5s	remaining: 14.6s
# 5597:	learn: 0.0561116	total: 18.5s	remaining: 14.6s
# 5598:	learn: 0.0561093	total: 18.5s	remaining: 14.6s
# 5599:	learn: 0.0561080	total: 18.5s	remaining: 14.6s
# 5600:	learn: 0.0561057	total: 18.5s	remaining: 14.6s
# 5601:	learn: 0.0561038	total: 18.5s	remaining: 14.6s
# 5602:	learn: 0.0560989	total: 18.5s	remaining: 14.6s
# 5603:	learn: 0.0560900	total: 18.6s	remaining: 14.6s
# 5604:	learn: 0.0560891	total: 18.6s	remaining: 14.5s
# 5605:	learn: 0.0560881	total: 18.6s	remaining: 14.5s
# 5606:	learn: 0.0560871	total: 18.6s	remaining: 14.5s
# 5607:	learn: 0.0560855	total: 18.6s	remaining: 14.5s
# 5608:	learn: 0.0560829	total: 18.6s	remaining: 14.5s
# 5609:	learn: 0.0560765	total: 18.6s	remaining: 14.5s
# 5610:	learn: 0.0560727	total: 18.6s	remaining: 14.5s
# 5611:	learn: 0.0560719	total: 18.6s	remaining: 14.5s
# 5612:	learn: 0.0560639	total: 18.6s	remaining: 14.5s
# 5613:	learn: 0.0560622	total: 18.6s	remaining: 14.5s
# 5614:	learn: 0.0560557	total: 18.6s	remaining: 14.5s
# 5615:	learn: 0.0560548	total: 18.6s	remaining: 14.5s
# 5616:	learn: 0.0560536	total: 18.6s	remaining: 14.5s
# 5617:	learn: 0.0560495	total: 18.6s	remaining: 14.5s
# 5618:	learn: 0.0560441	total: 18.6s	remaining: 14.5s
# 5619:	learn: 0.0560419	total: 18.6s	remaining: 14.5s
# 5620:	learn: 0.0560366	total: 18.6s	remaining: 14.5s
# 5621:	learn: 0.0560340	total: 18.6s	remaining: 14.5s
# 5622:	learn: 0.0560294	total: 18.6s	remaining: 14.5s
# 5623:	learn: 0.0560280	total: 18.6s	remaining: 14.5s
# 5624:	learn: 0.0560259	total: 18.6s	remaining: 14.5s
# 5625:	learn: 0.0560232	total: 18.6s	remaining: 14.5s
# 5626:	learn: 0.0560217	total: 18.6s	remaining: 14.5s
# 5627:	learn: 0.0560185	total: 18.6s	remaining: 14.5s
# 5628:	learn: 0.0560134	total: 18.6s	remaining: 14.5s
# 5629:	learn: 0.0560111	total: 18.6s	remaining: 14.5s
# 5630:	learn: 0.0560098	total: 18.6s	remaining: 14.4s
# 5631:	learn: 0.0560069	total: 18.6s	remaining: 14.4s
# 5632:	learn: 0.0560013	total: 18.6s	remaining: 14.4s
# 5633:	learn: 0.0559998	total: 18.6s	remaining: 14.4s
# 5634:	learn: 0.0559960	total: 18.6s	remaining: 14.4s
# 5635:	learn: 0.0559956	total: 18.6s	remaining: 14.4s
# 5636:	learn: 0.0559890	total: 18.6s	remaining: 14.4s
# 5637:	learn: 0.0559867	total: 18.6s	remaining: 14.4s
# 5638:	learn: 0.0559850	total: 18.6s	remaining: 14.4s
# 5639:	learn: 0.0559803	total: 18.7s	remaining: 14.4s
# 5640:	learn: 0.0559798	total: 18.7s	remaining: 14.4s
# 5641:	learn: 0.0559769	total: 18.7s	remaining: 14.4s
# 5642:	learn: 0.0559746	total: 18.7s	remaining: 14.4s
# 5643:	learn: 0.0559724	total: 18.7s	remaining: 14.4s
# 5644:	learn: 0.0559695	total: 18.7s	remaining: 14.4s
# 5645:	learn: 0.0559687	total: 18.7s	remaining: 14.4s
# 5646:	learn: 0.0559638	total: 18.7s	remaining: 14.4s
# 5647:	learn: 0.0559584	total: 18.7s	remaining: 14.4s
# 5648:	learn: 0.0559571	total: 18.7s	remaining: 14.4s
# 5649:	learn: 0.0559543	total: 18.7s	remaining: 14.4s
# 5650:	learn: 0.0559523	total: 18.7s	remaining: 14.4s
# 5651:	learn: 0.0559479	total: 18.7s	remaining: 14.4s
# 5652:	learn: 0.0559420	total: 18.7s	remaining: 14.4s
# 5653:	learn: 0.0559343	total: 18.7s	remaining: 14.4s
# 5654:	learn: 0.0559327	total: 18.7s	remaining: 14.4s
# 5655:	learn: 0.0559279	total: 18.7s	remaining: 14.4s
# 5656:	learn: 0.0559270	total: 18.7s	remaining: 14.4s
# 5657:	learn: 0.0559255	total: 18.7s	remaining: 14.4s
# 5658:	learn: 0.0559188	total: 18.7s	remaining: 14.4s
# 5659:	learn: 0.0559149	total: 18.7s	remaining: 14.4s
# 5660:	learn: 0.0559106	total: 18.7s	remaining: 14.4s
# 5661:	learn: 0.0559059	total: 18.7s	remaining: 14.3s
# 5662:	learn: 0.0559004	total: 18.7s	remaining: 14.3s
# 5663:	learn: 0.0558978	total: 18.7s	remaining: 14.3s
# 5664:	learn: 0.0558911	total: 18.7s	remaining: 14.3s
# 5665:	learn: 0.0558900	total: 18.7s	remaining: 14.3s
# 5666:	learn: 0.0558860	total: 18.7s	remaining: 14.3s
# 5667:	learn: 0.0558828	total: 18.7s	remaining: 14.3s
# 5668:	learn: 0.0558805	total: 18.8s	remaining: 14.3s
# 5669:	learn: 0.0558797	total: 18.8s	remaining: 14.3s
# 5670:	learn: 0.0558751	total: 18.8s	remaining: 14.3s
# 5671:	learn: 0.0558725	total: 18.8s	remaining: 14.3s
# 5672:	learn: 0.0558706	total: 18.8s	remaining: 14.3s
# 5673:	learn: 0.0558703	total: 18.8s	remaining: 14.3s
# 5674:	learn: 0.0558666	total: 18.8s	remaining: 14.3s
# 5675:	learn: 0.0558640	total: 18.8s	remaining: 14.3s
# 5676:	learn: 0.0558638	total: 18.8s	remaining: 14.3s
# 5677:	learn: 0.0558618	total: 18.8s	remaining: 14.3s
# 5678:	learn: 0.0558526	total: 18.8s	remaining: 14.3s
# 5679:	learn: 0.0558473	total: 18.8s	remaining: 14.3s
# 5680:	learn: 0.0558453	total: 18.8s	remaining: 14.3s
# 5681:	learn: 0.0558453	total: 18.8s	remaining: 14.3s
# 5682:	learn: 0.0558412	total: 18.8s	remaining: 14.3s
# 5683:	learn: 0.0558392	total: 18.8s	remaining: 14.3s
# 5684:	learn: 0.0558348	total: 18.8s	remaining: 14.3s
# 5685:	learn: 0.0558313	total: 18.8s	remaining: 14.3s
# 5686:	learn: 0.0558305	total: 18.8s	remaining: 14.3s
# 5687:	learn: 0.0558273	total: 18.8s	remaining: 14.3s
# 5688:	learn: 0.0558241	total: 18.8s	remaining: 14.2s
# 5689:	learn: 0.0558184	total: 18.8s	remaining: 14.2s
# 5690:	learn: 0.0558177	total: 18.8s	remaining: 14.2s
# 5691:	learn: 0.0558072	total: 18.8s	remaining: 14.2s
# 5692:	learn: 0.0558056	total: 18.8s	remaining: 14.2s
# 5693:	learn: 0.0558027	total: 18.8s	remaining: 14.2s
# 5694:	learn: 0.0558021	total: 18.8s	remaining: 14.2s
# 5695:	learn: 0.0557989	total: 18.8s	remaining: 14.2s
# 5696:	learn: 0.0557935	total: 18.8s	remaining: 14.2s
# 5697:	learn: 0.0557928	total: 18.8s	remaining: 14.2s
# 5698:	learn: 0.0557920	total: 18.8s	remaining: 14.2s
# 5699:	learn: 0.0557870	total: 18.8s	remaining: 14.2s
# 5700:	learn: 0.0557855	total: 18.8s	remaining: 14.2s
# 5701:	learn: 0.0557829	total: 18.8s	remaining: 14.2s
# 5702:	learn: 0.0557772	total: 18.8s	remaining: 14.2s
# 5703:	learn: 0.0557734	total: 18.9s	remaining: 14.2s
# 5704:	learn: 0.0557679	total: 18.9s	remaining: 14.2s
# 5705:	learn: 0.0557675	total: 18.9s	remaining: 14.2s
# 5706:	learn: 0.0557607	total: 18.9s	remaining: 14.2s
# 5707:	learn: 0.0557570	total: 18.9s	remaining: 14.2s
# 5708:	learn: 0.0557562	total: 18.9s	remaining: 14.2s
# 5709:	learn: 0.0557493	total: 18.9s	remaining: 14.2s
# 5710:	learn: 0.0557480	total: 18.9s	remaining: 14.2s
# 5711:	learn: 0.0557474	total: 18.9s	remaining: 14.2s
# 5712:	learn: 0.0557425	total: 18.9s	remaining: 14.2s
# 5713:	learn: 0.0557392	total: 18.9s	remaining: 14.2s
# 5714:	learn: 0.0557386	total: 18.9s	remaining: 14.2s
# 5715:	learn: 0.0557356	total: 18.9s	remaining: 14.2s
# 5716:	learn: 0.0557289	total: 18.9s	remaining: 14.2s
# 5717:	learn: 0.0557237	total: 18.9s	remaining: 14.1s
# 5718:	learn: 0.0557186	total: 18.9s	remaining: 14.1s
# 5719:	learn: 0.0557164	total: 18.9s	remaining: 14.1s
# 5720:	learn: 0.0557140	total: 18.9s	remaining: 14.1s
# 5721:	learn: 0.0557115	total: 18.9s	remaining: 14.1s
# 5722:	learn: 0.0557026	total: 18.9s	remaining: 14.1s
# 5723:	learn: 0.0557003	total: 18.9s	remaining: 14.1s
# 5724:	learn: 0.0556998	total: 18.9s	remaining: 14.1s
# 5725:	learn: 0.0556968	total: 18.9s	remaining: 14.1s
# 5726:	learn: 0.0556931	total: 18.9s	remaining: 14.1s
# 5727:	learn: 0.0556926	total: 18.9s	remaining: 14.1s
# 5728:	learn: 0.0556871	total: 18.9s	remaining: 14.1s
# 5729:	learn: 0.0556855	total: 18.9s	remaining: 14.1s
# 5730:	learn: 0.0556831	total: 18.9s	remaining: 14.1s
# 5731:	learn: 0.0556790	total: 18.9s	remaining: 14.1s
# 5732:	learn: 0.0556774	total: 18.9s	remaining: 14.1s
# 5733:	learn: 0.0556750	total: 18.9s	remaining: 14.1s
# 5734:	learn: 0.0556724	total: 18.9s	remaining: 14.1s
# 5735:	learn: 0.0556710	total: 18.9s	remaining: 14.1s
# 5736:	learn: 0.0556664	total: 18.9s	remaining: 14.1s
# 5737:	learn: 0.0556630	total: 18.9s	remaining: 14.1s
# 5738:	learn: 0.0556613	total: 18.9s	remaining: 14.1s
# 5739:	learn: 0.0556577	total: 19s	remaining: 14.1s
# 5740:	learn: 0.0556565	total: 19s	remaining: 14.1s
# 5741:	learn: 0.0556559	total: 19s	remaining: 14.1s
# 5742:	learn: 0.0556528	total: 19s	remaining: 14.1s
# 5743:	learn: 0.0556520	total: 19s	remaining: 14.1s
# 5744:	learn: 0.0556495	total: 19s	remaining: 14s
# 5745:	learn: 0.0556451	total: 19s	remaining: 14s
# 5746:	learn: 0.0556445	total: 19s	remaining: 14s
# 5747:	learn: 0.0556411	total: 19s	remaining: 14s
# 5748:	learn: 0.0556366	total: 19s	remaining: 14s
# 5749:	learn: 0.0556323	total: 19s	remaining: 14s
# 5750:	learn: 0.0556291	total: 19s	remaining: 14s
# 5751:	learn: 0.0556264	total: 19s	remaining: 14s
# 5752:	learn: 0.0556254	total: 19s	remaining: 14s
# 5753:	learn: 0.0556198	total: 19s	remaining: 14s
# 5754:	learn: 0.0556144	total: 19s	remaining: 14s
# 5755:	learn: 0.0556112	total: 19s	remaining: 14s
# 5756:	learn: 0.0556102	total: 19s	remaining: 14s
# 5757:	learn: 0.0556084	total: 19s	remaining: 14s
# 5758:	learn: 0.0556071	total: 19s	remaining: 14s
# 5759:	learn: 0.0556022	total: 19s	remaining: 14s
# 5760:	learn: 0.0555979	total: 19s	remaining: 14s
# 5761:	learn: 0.0555945	total: 19s	remaining: 14s
# 5762:	learn: 0.0555920	total: 19s	remaining: 14s
# 5763:	learn: 0.0555909	total: 19s	remaining: 14s
# 5764:	learn: 0.0555877	total: 19s	remaining: 14s
# 5765:	learn: 0.0555873	total: 19s	remaining: 14s
# 5766:	learn: 0.0555861	total: 19s	remaining: 14s
# 5767:	learn: 0.0555832	total: 19s	remaining: 14s
# 5768:	learn: 0.0555818	total: 19s	remaining: 14s
# 5769:	learn: 0.0555750	total: 19s	remaining: 14s
# 5770:	learn: 0.0555741	total: 19s	remaining: 13.9s
# 5771:	learn: 0.0555723	total: 19s	remaining: 13.9s
# 5772:	learn: 0.0555695	total: 19s	remaining: 13.9s
# 5773:	learn: 0.0555685	total: 19s	remaining: 13.9s
# 5774:	learn: 0.0555667	total: 19.1s	remaining: 13.9s
# 5775:	learn: 0.0555653	total: 19.1s	remaining: 13.9s
# 5776:	learn: 0.0555629	total: 19.1s	remaining: 13.9s
# 5777:	learn: 0.0555612	total: 19.1s	remaining: 13.9s
# 5778:	learn: 0.0555574	total: 19.1s	remaining: 13.9s
# 5779:	learn: 0.0555541	total: 19.1s	remaining: 13.9s
# 5780:	learn: 0.0555510	total: 19.1s	remaining: 13.9s
# 5781:	learn: 0.0555478	total: 19.1s	remaining: 13.9s
# 5782:	learn: 0.0555439	total: 19.1s	remaining: 13.9s
# 5783:	learn: 0.0555423	total: 19.1s	remaining: 13.9s
# 5784:	learn: 0.0555403	total: 19.1s	remaining: 13.9s
# 5785:	learn: 0.0555400	total: 19.1s	remaining: 13.9s
# 5786:	learn: 0.0555378	total: 19.1s	remaining: 13.9s
# 5787:	learn: 0.0555353	total: 19.1s	remaining: 13.9s
# 5788:	learn: 0.0555326	total: 19.1s	remaining: 13.9s
# 5789:	learn: 0.0555322	total: 19.1s	remaining: 13.9s
# 5790:	learn: 0.0555318	total: 19.1s	remaining: 13.9s
# 5791:	learn: 0.0555289	total: 19.1s	remaining: 13.9s
# 5792:	learn: 0.0555283	total: 19.1s	remaining: 13.9s
# 5793:	learn: 0.0555258	total: 19.1s	remaining: 13.9s
# 5794:	learn: 0.0555221	total: 19.1s	remaining: 13.9s
# 5795:	learn: 0.0555160	total: 19.1s	remaining: 13.9s
# 5796:	learn: 0.0555120	total: 19.1s	remaining: 13.9s
# 5797:	learn: 0.0555106	total: 19.1s	remaining: 13.9s
# 5798:	learn: 0.0555083	total: 19.1s	remaining: 13.8s
# 5799:	learn: 0.0555073	total: 19.1s	remaining: 13.8s
# 5800:	learn: 0.0555051	total: 19.1s	remaining: 13.8s
# 5801:	learn: 0.0555031	total: 19.1s	remaining: 13.8s
# 5802:	learn: 0.0554998	total: 19.1s	remaining: 13.8s
# 5803:	learn: 0.0554996	total: 19.1s	remaining: 13.8s
# 5804:	learn: 0.0554976	total: 19.1s	remaining: 13.8s
# 5805:	learn: 0.0554947	total: 19.1s	remaining: 13.8s
# 5806:	learn: 0.0554899	total: 19.1s	remaining: 13.8s
# 5807:	learn: 0.0554841	total: 19.1s	remaining: 13.8s
# 5808:	learn: 0.0554770	total: 19.1s	remaining: 13.8s
# 5809:	learn: 0.0554755	total: 19.1s	remaining: 13.8s
# 5810:	learn: 0.0554741	total: 19.1s	remaining: 13.8s
# 5811:	learn: 0.0554712	total: 19.2s	remaining: 13.8s
# 5812:	learn: 0.0554700	total: 19.2s	remaining: 13.8s
# 5813:	learn: 0.0554647	total: 19.2s	remaining: 13.8s
# 5814:	learn: 0.0554631	total: 19.2s	remaining: 13.8s
# 5815:	learn: 0.0554602	total: 19.2s	remaining: 13.8s
# 5816:	learn: 0.0554552	total: 19.2s	remaining: 13.8s
# 5817:	learn: 0.0554523	total: 19.2s	remaining: 13.8s
# 5818:	learn: 0.0554488	total: 19.2s	remaining: 13.8s
# 5819:	learn: 0.0554431	total: 19.2s	remaining: 13.8s
# 5820:	learn: 0.0554381	total: 19.2s	remaining: 13.8s
# 5821:	learn: 0.0554364	total: 19.2s	remaining: 13.8s
# 5822:	learn: 0.0554331	total: 19.2s	remaining: 13.8s
# 5823:	learn: 0.0554308	total: 19.2s	remaining: 13.8s
# 5824:	learn: 0.0554273	total: 19.2s	remaining: 13.8s
# 5825:	learn: 0.0554251	total: 19.2s	remaining: 13.7s
# 5826:	learn: 0.0554214	total: 19.2s	remaining: 13.7s
# 5827:	learn: 0.0554177	total: 19.2s	remaining: 13.7s
# 5828:	learn: 0.0554108	total: 19.2s	remaining: 13.7s
# 5829:	learn: 0.0554104	total: 19.2s	remaining: 13.7s
# 5830:	learn: 0.0554048	total: 19.2s	remaining: 13.7s
# 5831:	learn: 0.0554018	total: 19.2s	remaining: 13.7s
# 5832:	learn: 0.0554004	total: 19.2s	remaining: 13.7s
# 5833:	learn: 0.0553941	total: 19.2s	remaining: 13.7s
# 5834:	learn: 0.0553900	total: 19.2s	remaining: 13.7s
# 5835:	learn: 0.0553868	total: 19.2s	remaining: 13.7s
# 5836:	learn: 0.0553817	total: 19.2s	remaining: 13.7s
# 5837:	learn: 0.0553795	total: 19.2s	remaining: 13.7s
# 5838:	learn: 0.0553787	total: 19.2s	remaining: 13.7s
# 5839:	learn: 0.0553775	total: 19.2s	remaining: 13.7s
# 5840:	learn: 0.0553739	total: 19.2s	remaining: 13.7s
# 5841:	learn: 0.0553729	total: 19.2s	remaining: 13.7s
# 5842:	learn: 0.0553698	total: 19.2s	remaining: 13.7s
# 5843:	learn: 0.0553647	total: 19.2s	remaining: 13.7s
# 5844:	learn: 0.0553621	total: 19.3s	remaining: 13.7s
# 5845:	learn: 0.0553608	total: 19.3s	remaining: 13.7s
# 5846:	learn: 0.0553592	total: 19.3s	remaining: 13.7s
# 5847:	learn: 0.0553578	total: 19.3s	remaining: 13.7s
# 5848:	learn: 0.0553523	total: 19.3s	remaining: 13.7s
# 5849:	learn: 0.0553517	total: 19.3s	remaining: 13.7s
# 5850:	learn: 0.0553512	total: 19.3s	remaining: 13.7s
# 5851:	learn: 0.0553470	total: 19.3s	remaining: 13.7s
# 5852:	learn: 0.0553464	total: 19.3s	remaining: 13.7s
# 5853:	learn: 0.0553429	total: 19.3s	remaining: 13.7s
# 5854:	learn: 0.0553402	total: 19.3s	remaining: 13.6s
# 5855:	learn: 0.0553352	total: 19.3s	remaining: 13.6s
# 5856:	learn: 0.0553297	total: 19.3s	remaining: 13.6s
# 5857:	learn: 0.0553283	total: 19.3s	remaining: 13.6s
# 5858:	learn: 0.0553248	total: 19.3s	remaining: 13.6s
# 5859:	learn: 0.0553245	total: 19.3s	remaining: 13.6s
# 5860:	learn: 0.0553226	total: 19.3s	remaining: 13.6s
# 5861:	learn: 0.0553181	total: 19.3s	remaining: 13.6s
# 5862:	learn: 0.0553158	total: 19.3s	remaining: 13.6s
# 5863:	learn: 0.0553115	total: 19.3s	remaining: 13.6s
# 5864:	learn: 0.0553106	total: 19.3s	remaining: 13.6s
# 5865:	learn: 0.0553082	total: 19.3s	remaining: 13.6s
# 5866:	learn: 0.0553072	total: 19.3s	remaining: 13.6s
# 5867:	learn: 0.0553000	total: 19.3s	remaining: 13.6s
# 5868:	learn: 0.0552931	total: 19.3s	remaining: 13.6s
# 5869:	learn: 0.0552924	total: 19.3s	remaining: 13.6s
# 5870:	learn: 0.0552916	total: 19.3s	remaining: 13.6s
# 5871:	learn: 0.0552892	total: 19.3s	remaining: 13.6s
# 5872:	learn: 0.0552857	total: 19.3s	remaining: 13.6s
# 5873:	learn: 0.0552829	total: 19.3s	remaining: 13.6s
# 5874:	learn: 0.0552795	total: 19.3s	remaining: 13.6s
# 5875:	learn: 0.0552757	total: 19.3s	remaining: 13.6s
# 5876:	learn: 0.0552726	total: 19.3s	remaining: 13.6s
# 5877:	learn: 0.0552698	total: 19.3s	remaining: 13.6s
# 5878:	learn: 0.0552679	total: 19.3s	remaining: 13.6s
# 5879:	learn: 0.0552630	total: 19.3s	remaining: 13.6s
# 5880:	learn: 0.0552620	total: 19.4s	remaining: 13.6s
# 5881:	learn: 0.0552580	total: 19.4s	remaining: 13.5s
# 5882:	learn: 0.0552556	total: 19.4s	remaining: 13.5s
# 5883:	learn: 0.0552545	total: 19.4s	remaining: 13.5s
# 5884:	learn: 0.0552527	total: 19.4s	remaining: 13.5s
# 5885:	learn: 0.0552469	total: 19.4s	remaining: 13.5s
# 5886:	learn: 0.0552419	total: 19.4s	remaining: 13.5s
# 5887:	learn: 0.0552382	total: 19.4s	remaining: 13.5s
# 5888:	learn: 0.0552363	total: 19.4s	remaining: 13.5s
# 5889:	learn: 0.0552335	total: 19.4s	remaining: 13.5s
# 5890:	learn: 0.0552324	total: 19.4s	remaining: 13.5s
# 5891:	learn: 0.0552290	total: 19.4s	remaining: 13.5s
# 5892:	learn: 0.0552266	total: 19.4s	remaining: 13.5s
# 5893:	learn: 0.0552190	total: 19.4s	remaining: 13.5s
# 5894:	learn: 0.0552161	total: 19.4s	remaining: 13.5s
# 5895:	learn: 0.0552141	total: 19.4s	remaining: 13.5s
# 5896:	learn: 0.0552120	total: 19.4s	remaining: 13.5s
# 5897:	learn: 0.0552058	total: 19.4s	remaining: 13.5s
# 5898:	learn: 0.0552020	total: 19.4s	remaining: 13.5s
# 5899:	learn: 0.0551962	total: 19.4s	remaining: 13.5s
# 5900:	learn: 0.0551953	total: 19.4s	remaining: 13.5s
# 5901:	learn: 0.0551909	total: 19.4s	remaining: 13.5s
# 5902:	learn: 0.0551848	total: 19.4s	remaining: 13.5s
# 5903:	learn: 0.0551771	total: 19.4s	remaining: 13.5s
# 5904:	learn: 0.0551731	total: 19.4s	remaining: 13.5s
# 5905:	learn: 0.0551709	total: 19.4s	remaining: 13.5s
# 5906:	learn: 0.0551643	total: 19.4s	remaining: 13.5s
# 5907:	learn: 0.0551568	total: 19.4s	remaining: 13.5s
# 5908:	learn: 0.0551548	total: 19.4s	remaining: 13.4s
# 5909:	learn: 0.0551536	total: 19.4s	remaining: 13.4s
# 5910:	learn: 0.0551509	total: 19.4s	remaining: 13.4s
# ...
# 9699:	learn: 0.0461614	total: 32.1s	remaining: 993ms
# 9700:	learn: 0.0461591	total: 32.1s	remaining: 990ms
# 9701:	learn: 0.0461567	total: 32.1s	remaining: 986ms
# 9702:	learn: 0.0461553	total: 32.1s	remaining: 983ms
# 9703:	learn: 0.0461521	total: 32.1s	remaining: 980ms
# 9704:	learn: 0.0461493	total: 32.1s	remaining: 976ms
# 9705:	learn: 0.0461487	total: 32.1s	remaining: 973ms
# 9706:	learn: 0.0461467	total: 32.1s	remaining: 970ms
# 9707:	learn: 0.0461449	total: 32.1s	remaining: 966ms
# 9708:	learn: 0.0461423	total: 32.1s	remaining: 963ms
# 9709:	learn: 0.0461420	total: 32.1s	remaining: 960ms
# 9710:	learn: 0.0461406	total: 32.1s	remaining: 956ms
# 9711:	learn: 0.0461396	total: 32.1s	remaining: 953ms
# 9712:	learn: 0.0461363	total: 32.1s	remaining: 950ms
# 9713:	learn: 0.0461321	total: 32.1s	remaining: 946ms
# 9714:	learn: 0.0461297	total: 32.1s	remaining: 943ms
# 9715:	learn: 0.0461275	total: 32.1s	remaining: 940ms
# 9716:	learn: 0.0461258	total: 32.2s	remaining: 936ms
# 9717:	learn: 0.0461237	total: 32.2s	remaining: 933ms
# 9718:	learn: 0.0461209	total: 32.2s	remaining: 930ms
# 9719:	learn: 0.0461184	total: 32.2s	remaining: 926ms
# 9720:	learn: 0.0461183	total: 32.2s	remaining: 923ms
# 9721:	learn: 0.0461181	total: 32.2s	remaining: 920ms
# 9722:	learn: 0.0461167	total: 32.2s	remaining: 916ms
# 9723:	learn: 0.0461151	total: 32.2s	remaining: 913ms
# 9724:	learn: 0.0461139	total: 32.2s	remaining: 910ms
# 9725:	learn: 0.0461107	total: 32.2s	remaining: 907ms
# 9726:	learn: 0.0461106	total: 32.2s	remaining: 903ms
# 9727:	learn: 0.0461066	total: 32.2s	remaining: 900ms
# 9728:	learn: 0.0461049	total: 32.2s	remaining: 897ms
# 9729:	learn: 0.0461043	total: 32.2s	remaining: 893ms
# 9730:	learn: 0.0461039	total: 32.2s	remaining: 890ms
# 9731:	learn: 0.0461030	total: 32.2s	remaining: 887ms
# 9732:	learn: 0.0460976	total: 32.2s	remaining: 883ms
# 9733:	learn: 0.0460945	total: 32.2s	remaining: 880ms
# 9734:	learn: 0.0460911	total: 32.2s	remaining: 877ms
# 9735:	learn: 0.0460908	total: 32.2s	remaining: 873ms
# 9736:	learn: 0.0460907	total: 32.2s	remaining: 870ms
# 9737:	learn: 0.0460905	total: 32.2s	remaining: 867ms
# 9738:	learn: 0.0460891	total: 32.2s	remaining: 863ms
# 9739:	learn: 0.0460866	total: 32.2s	remaining: 860ms
# 9740:	learn: 0.0460845	total: 32.2s	remaining: 857ms
# 9741:	learn: 0.0460820	total: 32.2s	remaining: 853ms
# 9742:	learn: 0.0460787	total: 32.2s	remaining: 850ms
# 9743:	learn: 0.0460780	total: 32.2s	remaining: 847ms
# 9744:	learn: 0.0460767	total: 32.2s	remaining: 843ms
# 9745:	learn: 0.0460726	total: 32.2s	remaining: 840ms
# 9746:	learn: 0.0460704	total: 32.2s	remaining: 837ms
# 9747:	learn: 0.0460698	total: 32.2s	remaining: 833ms
# 9748:	learn: 0.0460687	total: 32.2s	remaining: 830ms
# 9749:	learn: 0.0460652	total: 32.2s	remaining: 827ms
# 9750:	learn: 0.0460614	total: 32.2s	remaining: 823ms
# 9751:	learn: 0.0460610	total: 32.2s	remaining: 820ms
# 9752:	learn: 0.0460590	total: 32.3s	remaining: 817ms
# 9753:	learn: 0.0460546	total: 32.3s	remaining: 814ms
# 9754:	learn: 0.0460514	total: 32.3s	remaining: 811ms
# 9755:	learn: 0.0460497	total: 32.3s	remaining: 807ms
# 9756:	learn: 0.0460482	total: 32.3s	remaining: 804ms
# 9757:	learn: 0.0460462	total: 32.3s	remaining: 801ms
# 9758:	learn: 0.0460461	total: 32.3s	remaining: 797ms
# 9759:	learn: 0.0460448	total: 32.3s	remaining: 794ms
# 9760:	learn: 0.0460447	total: 32.3s	remaining: 791ms
# 9761:	learn: 0.0460388	total: 32.3s	remaining: 787ms
# 9762:	learn: 0.0460388	total: 32.3s	remaining: 784ms
# 9763:	learn: 0.0460382	total: 32.3s	remaining: 781ms
# 9764:	learn: 0.0460347	total: 32.3s	remaining: 777ms
# 9765:	learn: 0.0460343	total: 32.3s	remaining: 774ms
# 9766:	learn: 0.0460330	total: 32.3s	remaining: 771ms
# 9767:	learn: 0.0460319	total: 32.3s	remaining: 768ms
# 9768:	learn: 0.0460297	total: 32.3s	remaining: 764ms
# 9769:	learn: 0.0460268	total: 32.3s	remaining: 761ms
# 9770:	learn: 0.0460256	total: 32.3s	remaining: 758ms
# 9771:	learn: 0.0460225	total: 32.3s	remaining: 754ms
# 9772:	learn: 0.0460201	total: 32.3s	remaining: 751ms
# 9773:	learn: 0.0460195	total: 32.3s	remaining: 748ms
# 9774:	learn: 0.0460186	total: 32.3s	remaining: 744ms
# 9775:	learn: 0.0460162	total: 32.3s	remaining: 741ms
# 9776:	learn: 0.0460146	total: 32.3s	remaining: 738ms
# 9777:	learn: 0.0460143	total: 32.3s	remaining: 734ms
# 9778:	learn: 0.0460131	total: 32.3s	remaining: 731ms
# 9779:	learn: 0.0460102	total: 32.3s	remaining: 728ms
# 9780:	learn: 0.0460085	total: 32.3s	remaining: 724ms
# 9781:	learn: 0.0460049	total: 32.4s	remaining: 721ms
# 9782:	learn: 0.0460042	total: 32.4s	remaining: 718ms
# 9783:	learn: 0.0460038	total: 32.4s	remaining: 714ms
# 9784:	learn: 0.0460026	total: 32.4s	remaining: 711ms
# 9785:	learn: 0.0460002	total: 32.4s	remaining: 708ms
# 9786:	learn: 0.0459979	total: 32.4s	remaining: 704ms
# 9787:	learn: 0.0459961	total: 32.4s	remaining: 701ms
# 9788:	learn: 0.0459934	total: 32.4s	remaining: 698ms
# 9789:	learn: 0.0459909	total: 32.4s	remaining: 694ms
# 9790:	learn: 0.0459908	total: 32.4s	remaining: 691ms
# 9791:	learn: 0.0459892	total: 32.4s	remaining: 688ms
# 9792:	learn: 0.0459874	total: 32.4s	remaining: 684ms
# 9793:	learn: 0.0459840	total: 32.4s	remaining: 681ms
# 9794:	learn: 0.0459807	total: 32.4s	remaining: 678ms
# 9795:	learn: 0.0459798	total: 32.4s	remaining: 675ms
# 9796:	learn: 0.0459755	total: 32.4s	remaining: 671ms
# 9797:	learn: 0.0459751	total: 32.4s	remaining: 668ms
# 9798:	learn: 0.0459744	total: 32.4s	remaining: 665ms
# 9799:	learn: 0.0459736	total: 32.4s	remaining: 661ms
# 9800:	learn: 0.0459699	total: 32.4s	remaining: 658ms
# 9801:	learn: 0.0459692	total: 32.4s	remaining: 655ms
# 9802:	learn: 0.0459668	total: 32.4s	remaining: 651ms
# 9803:	learn: 0.0459663	total: 32.4s	remaining: 648ms
# 9804:	learn: 0.0459643	total: 32.4s	remaining: 645ms
# 9805:	learn: 0.0459637	total: 32.4s	remaining: 641ms
# 9806:	learn: 0.0459620	total: 32.4s	remaining: 638ms
# 9807:	learn: 0.0459619	total: 32.4s	remaining: 635ms
# 9808:	learn: 0.0459611	total: 32.4s	remaining: 631ms
# 9809:	learn: 0.0459604	total: 32.4s	remaining: 628ms
# 9810:	learn: 0.0459585	total: 32.4s	remaining: 625ms
# 9811:	learn: 0.0459567	total: 32.4s	remaining: 621ms
# 9812:	learn: 0.0459556	total: 32.4s	remaining: 618ms
# 9813:	learn: 0.0459540	total: 32.4s	remaining: 615ms
# 9814:	learn: 0.0459491	total: 32.4s	remaining: 611ms
# 9815:	learn: 0.0459484	total: 32.4s	remaining: 608ms
# 9816:	learn: 0.0459474	total: 32.5s	remaining: 605ms
# 9817:	learn: 0.0459464	total: 32.5s	remaining: 602ms
# 9818:	learn: 0.0459452	total: 32.5s	remaining: 598ms
# 9819:	learn: 0.0459432	total: 32.5s	remaining: 595ms
# 9820:	learn: 0.0459432	total: 32.5s	remaining: 592ms
# 9821:	learn: 0.0459420	total: 32.5s	remaining: 588ms
# 9822:	learn: 0.0459405	total: 32.5s	remaining: 585ms
# 9823:	learn: 0.0459403	total: 32.5s	remaining: 582ms
# 9824:	learn: 0.0459385	total: 32.5s	remaining: 579ms
# 9825:	learn: 0.0459383	total: 32.5s	remaining: 575ms
# 9826:	learn: 0.0459352	total: 32.5s	remaining: 572ms
# 9827:	learn: 0.0459328	total: 32.5s	remaining: 569ms
# 9828:	learn: 0.0459317	total: 32.5s	remaining: 565ms
# 9829:	learn: 0.0459294	total: 32.5s	remaining: 562ms
# 9830:	learn: 0.0459292	total: 32.5s	remaining: 559ms
# 9831:	learn: 0.0459289	total: 32.5s	remaining: 555ms
# 9832:	learn: 0.0459271	total: 32.5s	remaining: 552ms
# 9833:	learn: 0.0459236	total: 32.5s	remaining: 549ms
# 9834:	learn: 0.0459203	total: 32.5s	remaining: 545ms
# 9835:	learn: 0.0459164	total: 32.5s	remaining: 542ms
# 9836:	learn: 0.0459099	total: 32.5s	remaining: 539ms
# 9837:	learn: 0.0459068	total: 32.5s	remaining: 535ms
# 9838:	learn: 0.0459038	total: 32.5s	remaining: 532ms
# 9839:	learn: 0.0459003	total: 32.5s	remaining: 529ms
# 9840:	learn: 0.0458990	total: 32.5s	remaining: 525ms
# 9841:	learn: 0.0458970	total: 32.5s	remaining: 522ms
# 9842:	learn: 0.0458957	total: 32.5s	remaining: 519ms
# 9843:	learn: 0.0458940	total: 32.5s	remaining: 516ms
# 9844:	learn: 0.0458937	total: 32.5s	remaining: 512ms
# 9845:	learn: 0.0458922	total: 32.5s	remaining: 509ms
# 9846:	learn: 0.0458893	total: 32.5s	remaining: 506ms
# 9847:	learn: 0.0458866	total: 32.5s	remaining: 502ms
# 9848:	learn: 0.0458824	total: 32.5s	remaining: 499ms
# 9849:	learn: 0.0458814	total: 32.5s	remaining: 496ms
# 9850:	learn: 0.0458774	total: 32.5s	remaining: 492ms
# 9851:	learn: 0.0458771	total: 32.6s	remaining: 489ms
# 9852:	learn: 0.0458730	total: 32.6s	remaining: 486ms
# 9853:	learn: 0.0458709	total: 32.6s	remaining: 482ms
# 9854:	learn: 0.0458685	total: 32.6s	remaining: 479ms
# 9855:	learn: 0.0458652	total: 32.6s	remaining: 476ms
# 9856:	learn: 0.0458635	total: 32.6s	remaining: 472ms
# 9857:	learn: 0.0458621	total: 32.6s	remaining: 469ms
# 9858:	learn: 0.0458610	total: 32.6s	remaining: 466ms
# 9859:	learn: 0.0458601	total: 32.6s	remaining: 463ms
# 9860:	learn: 0.0458576	total: 32.6s	remaining: 459ms
# 9861:	learn: 0.0458546	total: 32.6s	remaining: 456ms
# 9862:	learn: 0.0458541	total: 32.6s	remaining: 453ms
# 9863:	learn: 0.0458516	total: 32.6s	remaining: 449ms
# 9864:	learn: 0.0458499	total: 32.6s	remaining: 446ms
# 9865:	learn: 0.0458473	total: 32.6s	remaining: 443ms
# 9866:	learn: 0.0458444	total: 32.6s	remaining: 439ms
# 9867:	learn: 0.0458435	total: 32.6s	remaining: 436ms
# 9868:	learn: 0.0458432	total: 32.6s	remaining: 433ms
# 9869:	learn: 0.0458431	total: 32.6s	remaining: 429ms
# 9870:	learn: 0.0458414	total: 32.6s	remaining: 426ms
# 9871:	learn: 0.0458406	total: 32.6s	remaining: 423ms
# 9872:	learn: 0.0458376	total: 32.6s	remaining: 419ms
# 9873:	learn: 0.0458364	total: 32.6s	remaining: 416ms
# 9874:	learn: 0.0458313	total: 32.6s	remaining: 413ms
# 9875:	learn: 0.0458286	total: 32.6s	remaining: 410ms
# 9876:	learn: 0.0458272	total: 32.6s	remaining: 406ms
# 9877:	learn: 0.0458270	total: 32.6s	remaining: 403ms
# 9878:	learn: 0.0458246	total: 32.6s	remaining: 400ms
# 9879:	learn: 0.0458232	total: 32.6s	remaining: 396ms
# 9880:	learn: 0.0458231	total: 32.6s	remaining: 393ms
# 9881:	learn: 0.0458212	total: 32.6s	remaining: 390ms
# 9882:	learn: 0.0458182	total: 32.6s	remaining: 386ms
# 9883:	learn: 0.0458179	total: 32.6s	remaining: 383ms
# 9884:	learn: 0.0458166	total: 32.6s	remaining: 380ms
# 9885:	learn: 0.0458160	total: 32.7s	remaining: 377ms
# 9886:	learn: 0.0458150	total: 32.7s	remaining: 373ms
# 9887:	learn: 0.0458116	total: 32.7s	remaining: 370ms
# 9888:	learn: 0.0458096	total: 32.7s	remaining: 367ms
# 9889:	learn: 0.0458065	total: 32.7s	remaining: 363ms
# 9890:	learn: 0.0458051	total: 32.7s	remaining: 360ms
# 9891:	learn: 0.0458028	total: 32.7s	remaining: 357ms
# 9892:	learn: 0.0458025	total: 32.7s	remaining: 353ms
# 9893:	learn: 0.0458000	total: 32.7s	remaining: 350ms
# 9894:	learn: 0.0457984	total: 32.7s	remaining: 347ms
# 9895:	learn: 0.0457973	total: 32.7s	remaining: 343ms
# 9896:	learn: 0.0457957	total: 32.7s	remaining: 340ms
# 9897:	learn: 0.0457956	total: 32.7s	remaining: 337ms
# 9898:	learn: 0.0457932	total: 32.7s	remaining: 334ms
# 9899:	learn: 0.0457927	total: 32.7s	remaining: 330ms
# 9900:	learn: 0.0457893	total: 32.7s	remaining: 327ms
# 9901:	learn: 0.0457884	total: 32.7s	remaining: 324ms
# 9902:	learn: 0.0457881	total: 32.7s	remaining: 320ms
# 9903:	learn: 0.0457852	total: 32.7s	remaining: 317ms
# 9904:	learn: 0.0457842	total: 32.7s	remaining: 314ms
# 9905:	learn: 0.0457816	total: 32.7s	remaining: 310ms
# 9906:	learn: 0.0457781	total: 32.7s	remaining: 307ms
# 9907:	learn: 0.0457759	total: 32.7s	remaining: 304ms
# 9908:	learn: 0.0457752	total: 32.7s	remaining: 300ms
# 9909:	learn: 0.0457747	total: 32.7s	remaining: 297ms
# 9910:	learn: 0.0457724	total: 32.7s	remaining: 294ms
# 9911:	learn: 0.0457719	total: 32.7s	remaining: 291ms
# 9912:	learn: 0.0457714	total: 32.7s	remaining: 287ms
# 9913:	learn: 0.0457691	total: 32.7s	remaining: 284ms
# 9914:	learn: 0.0457673	total: 32.7s	remaining: 281ms
# 9915:	learn: 0.0457668	total: 32.7s	remaining: 277ms
# 9916:	learn: 0.0457645	total: 32.7s	remaining: 274ms
# 9917:	learn: 0.0457639	total: 32.7s	remaining: 271ms
# 9918:	learn: 0.0457637	total: 32.7s	remaining: 267ms
# 9919:	learn: 0.0457624	total: 32.7s	remaining: 264ms
# 9920:	learn: 0.0457604	total: 32.8s	remaining: 261ms
# 9921:	learn: 0.0457569	total: 32.8s	remaining: 257ms
# 9922:	learn: 0.0457542	total: 32.8s	remaining: 254ms
# 9923:	learn: 0.0457524	total: 32.8s	remaining: 251ms
# 9924:	learn: 0.0457496	total: 32.8s	remaining: 248ms
# 9925:	learn: 0.0457493	total: 32.8s	remaining: 244ms
# 9926:	learn: 0.0457487	total: 32.8s	remaining: 241ms
# 9927:	learn: 0.0457456	total: 32.8s	remaining: 238ms
# 9928:	learn: 0.0457441	total: 32.8s	remaining: 234ms
# 9929:	learn: 0.0457420	total: 32.8s	remaining: 231ms
# 9930:	learn: 0.0457416	total: 32.8s	remaining: 228ms
# 9931:	learn: 0.0457404	total: 32.8s	remaining: 224ms
# 9932:	learn: 0.0457341	total: 32.8s	remaining: 221ms
# 9933:	learn: 0.0457308	total: 32.8s	remaining: 218ms
# 9934:	learn: 0.0457289	total: 32.8s	remaining: 215ms
# 9935:	learn: 0.0457285	total: 32.8s	remaining: 211ms
# 9936:	learn: 0.0457280	total: 32.8s	remaining: 208ms
# 9937:	learn: 0.0457279	total: 32.8s	remaining: 205ms
# 9938:	learn: 0.0457277	total: 32.8s	remaining: 201ms
# 9939:	learn: 0.0457268	total: 32.8s	remaining: 198ms
# 9940:	learn: 0.0457262	total: 32.8s	remaining: 195ms
# 9941:	learn: 0.0457257	total: 32.8s	remaining: 191ms
# 9942:	learn: 0.0457236	total: 32.8s	remaining: 188ms
# 9943:	learn: 0.0457229	total: 32.8s	remaining: 185ms
# 9944:	learn: 0.0457227	total: 32.8s	remaining: 181ms
# 9945:	learn: 0.0457210	total: 32.8s	remaining: 178ms
# 9946:	learn: 0.0457184	total: 32.8s	remaining: 175ms
# 9947:	learn: 0.0457179	total: 32.8s	remaining: 172ms
# 9948:	learn: 0.0457164	total: 32.8s	remaining: 168ms
# 9949:	learn: 0.0457138	total: 32.8s	remaining: 165ms
# 9950:	learn: 0.0457091	total: 32.8s	remaining: 162ms
# 9951:	learn: 0.0457072	total: 32.8s	remaining: 158ms
# 9952:	learn: 0.0457067	total: 32.8s	remaining: 155ms
# 9953:	learn: 0.0457027	total: 32.8s	remaining: 152ms
# 9954:	learn: 0.0457000	total: 32.9s	remaining: 148ms
# 9955:	learn: 0.0456978	total: 32.9s	remaining: 145ms
# 9956:	learn: 0.0456969	total: 32.9s	remaining: 142ms
# 9957:	learn: 0.0456944	total: 32.9s	remaining: 139ms
# 9958:	learn: 0.0456926	total: 32.9s	remaining: 135ms
# 9959:	learn: 0.0456903	total: 32.9s	remaining: 132ms
# 9960:	learn: 0.0456876	total: 32.9s	remaining: 129ms
# 9961:	learn: 0.0456873	total: 32.9s	remaining: 125ms
# 9962:	learn: 0.0456862	total: 32.9s	remaining: 122ms
# 9963:	learn: 0.0456839	total: 32.9s	remaining: 119ms
# 9964:	learn: 0.0456807	total: 32.9s	remaining: 115ms
# 9965:	learn: 0.0456793	total: 32.9s	remaining: 112ms
# 9966:	learn: 0.0456772	total: 32.9s	remaining: 109ms
# 9967:	learn: 0.0456755	total: 32.9s	remaining: 106ms
# 9968:	learn: 0.0456733	total: 32.9s	remaining: 102ms
# 9969:	learn: 0.0456716	total: 32.9s	remaining: 99ms
# 9970:	learn: 0.0456704	total: 32.9s	remaining: 95.7ms
# 9971:	learn: 0.0456690	total: 32.9s	remaining: 92.4ms
# 9972:	learn: 0.0456684	total: 32.9s	remaining: 89.1ms
# 9973:	learn: 0.0456657	total: 32.9s	remaining: 85.8ms
# 9974:	learn: 0.0456639	total: 32.9s	remaining: 82.5ms
# 9975:	learn: 0.0456605	total: 32.9s	remaining: 79.2ms
# 9976:	learn: 0.0456584	total: 32.9s	remaining: 75.9ms
# 9977:	learn: 0.0456553	total: 32.9s	remaining: 72.6ms
# 9978:	learn: 0.0456523	total: 32.9s	remaining: 69.3ms
# 9979:	learn: 0.0456504	total: 32.9s	remaining: 66ms
# 9980:	learn: 0.0456490	total: 32.9s	remaining: 62.7ms
# 9981:	learn: 0.0456472	total: 32.9s	remaining: 59.4ms
# 9982:	learn: 0.0456449	total: 32.9s	remaining: 56.1ms
# 9983:	learn: 0.0456440	total: 32.9s	remaining: 52.8ms
# 9984:	learn: 0.0456429	total: 32.9s	remaining: 49.5ms
# 9985:	learn: 0.0456404	total: 32.9s	remaining: 46.2ms
# 9986:	learn: 0.0456378	total: 32.9s	remaining: 42.9ms
# 9987:	learn: 0.0456366	total: 32.9s	remaining: 39.6ms
# 9988:	learn: 0.0456339	total: 33s	remaining: 36.3ms
# 9989:	learn: 0.0456297	total: 33s	remaining: 33ms
# 9990:	learn: 0.0456272	total: 33s	remaining: 29.7ms
# 9991:	learn: 0.0456265	total: 33s	remaining: 26.4ms
# 9992:	learn: 0.0456258	total: 33s	remaining: 23.1ms
# 9993:	learn: 0.0456251	total: 33s	remaining: 19.8ms
# 9994:	learn: 0.0456246	total: 33s	remaining: 16.5ms
# 9995:	learn: 0.0456226	total: 33s	remaining: 13.2ms
# 9996:	learn: 0.0456174	total: 33s	remaining: 9.89ms
# 9997:	learn: 0.0456129	total: 33s	remaining: 6.6ms
# 9998:	learn: 0.0456100	total: 33s	remaining: 3.3ms
# 9999:	learn: 0.0456067	total: 33s	remaining: 0us

# %%
print("Hasil Cross-Validation RMSE (train data)")
print(f"CatBoost label encoder: {rmse_scores_train_tuned.mean()}")

print("Hasil Cross-Validation RMSE (test data)")
print(f"CatBoost label encoder: {rmse_scores_test_tuned.mean()}")
# Out:
# Hasil Cross-Validation RMSE (train data)
# CatBoost label encoder: -0.083898909162469
# Hasil Cross-Validation RMSE (test data)
# CatBoost label encoder: -0.08764459217763534

# %%
models = pd.DataFrame({'Model': ['Auto Categorical', 'Manual Label Encoding', 'Manual Label Encoding & Tuned'],
                       'RMSE Score (test data)': [rmse_scores_test_cat.mean(), rmse_scores_test_nocat.mean(), rmse_scores_test_tuned.mean()]})

models.sort_values(by = 'RMSE Score (test data)', ascending = False, ignore_index = True)
# Out:
#                            Model  RMSE Score (test data)
# 0          Manual Label Encoding               -0.084703
# 1               Auto Categorical               -0.086192
# 2  Manual Label Encoding & Tuned               -0.087645

# %% [markdown]
# ## <p style="background-color:#25316D;font-family:newtimeroman;color:#FEF5AC;font-size:80%;text-align:center;border-radius:10px 10px;">Final Model Comparison</p>

# %%
# Final model
# XGBoost : xgb_reg
# CatBoost : grid

# Model Linear Regression prediction on test data
start_lr = timer()
pred_lr = lr.predict(X_test_log)
end_lr = timer()
pred_time_lr = end_lr - start_lr
r2_lr = r2_score(y_test_log, pred_lr)
rmse_lr = np.sqrt(mean_squared_error(y_test_log, pred_lr))

# Model XGB prediction on test data
start_xgb = timer()
pred_xgb = xgb_reg.predict(X_test_log)
end_xgb = timer()
pred_time_xgb = end_xgb - start_xgb

r2_xgb = r2_score(y_test_log, pred_xgb)
rmse_xgb = np.sqrt(mean_squared_error(y_test_log, pred_xgb))

# Model Cat prediction on test data
start_cat = timer()
pred_cat = grid.predict(X_test_cat)
end_cat = timer()
pred_time_cat = end_cat - start_cat

r2_cat = r2_score(y_test_log, pred_cat)
rmse_cat = np.sqrt(mean_squared_error(y_test_log, pred_cat))

# %%
models = pd.DataFrame({'Model': ['Linear Regression', 'XGBRegressor', 'CatBoostRegressor'],
                       'RMSE Score (test data)': [rmse_scores_test_lr.mean(), rmse_scores_test_xgb.mean(), rmse_scores_test_cat.mean()]})

models.sort_values(by = 'RMSE Score (test data)', ascending = False, ignore_index = True)
# Out:
#                Model  RMSE Score (test data)
# 0  CatBoostRegressor               -0.086192
# 1       XGBRegressor               -0.087166
# 2  Linear Regression               -0.171113

# %%
training_time = pd.DataFrame({'Model': ['Linear Regression', 'XGBRegressor', 'CatBoostRegressor'],
                       'Time(s)': [train_time_lr, train_time_xgb, train_time_cat]})

training_time.sort_values(by = 'Time(s)', ascending = True, ignore_index = True)
# Out:
#                Model    Time(s)
# 0  Linear Regression   0.022732
# 1       XGBRegressor   8.676250
# 2  CatBoostRegressor  68.303094

# %%
import plotly.graph_objects as go

# %%
fig = go.Figure(data=[go.Bar(
            x=training_time['Model'], y=training_time['Time(s)'],
            text=training_time['Time(s)'],
            textposition='auto',
            width=0.5
            
        )])
fig.update_layout(
    title='Training Time(s)',
    width=600,
    height=600)
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-2.8.3.min.js"></script>                <div id="a89abef6-716f-469d-bd6f-354e5aad4b6f" class="plotly-graph-div" style="height:600px; width:600px;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("a89abef6-716f-469d-bd6f-354e5aad4b6f")) {                    Plotly.newPlot(                        "a89abef6-716f-469d-bd6f-354e5aad4b6f",                        [{"text":[0.02273203099980492,8.676250239999945,68.30309445300009],"textposition":"auto","width":0.5,"x":["Linear Regression","XGBRegressor","CatBoostRegressor"],"y":[0.02273203099980492,8.676250239999945,68.30309445300009],"type":"bar"}],                        {"template":{"data":{"bar":[{"error_x":{"color":"#2a3f5f"},"error_y":{"color":"#2a3f5f"},"marker":{"line":{"color":"#E5ECF6","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"bar"}],"barpolar":[{"marker":{"line":{"color":"#E5ECF6","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"barpolar"}],"carpet":[{"aaxis":{"endlinecolor":"#2a3f5f","gridcolor":"white","linecolor":"white","minorgridcolor":"white","startlinecolor":"#2a3f5f"},"baxis":{"endlinecolor":"#2a3f5f","gridcolor":"white","linecolor":"white","minorgridcolor":"white","startlinecolor":"#2a3f5f"},"type":"carpet"}],"choropleth":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"choropleth"}],"contour":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"contour"}],"contourcarpet":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"contourcarpet"}],"heatmap":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"heatmap"}],"heatmapgl":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"heatmapgl"}],"histogram":[{"marker":{"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"histogram"}],"histogram2d":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"histogram2d"}],"histogram2dcontour":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"histogram2dcontour"}],"mesh3d":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"mesh3d"}],"parcoords":[{"line":{"colorbar":{"outlinewidth":0,"ticks":""}},"type":"parcoords"}],"pie":[{"automargin":true,"type":"pie"}],"scatter":[{"marker":{"colorbar":{"outlinewidth":0,"ticks":""}},"type":"scatter"}],"scatter3d":[{"line":{"colorbar":{"outlinewidth":0,"ticks":""}},"marker":{"colorbar":{"outlinewidth":0,"ticks":""}},"type":"scatter3d"}],"sc ...

# %%
prediction_time = pd.DataFrame({'Model': ['Linear Regression', 'XGBRegressor', 'CatBoostRegressor'],
                       'Time(s)': [pred_time_lr, pred_time_xgb, pred_time_cat]})

prediction_time.sort_values(by = 'Time(s)', ascending = True, ignore_index = True)
# Out:
#                Model   Time(s)
# 0  Linear Regression  0.004809
# 1       XGBRegressor  0.135142
# 2  CatBoostRegressor  0.275554

# %%
fig = go.Figure(data=[go.Bar(
            x=prediction_time['Model'], y=prediction_time['Time(s)'],
            text=prediction_time['Time(s)'],
            textposition='auto',
            width=0.5
            
        )])
fig.update_layout(
    title='Prediction Time(s)',
    width=600,
    height=600)
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-2.8.3.min.js"></script>                <div id="41a87fc8-2505-450c-be1a-7c48472d40be" class="plotly-graph-div" style="height:600px; width:600px;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("41a87fc8-2505-450c-be1a-7c48472d40be")) {                    Plotly.newPlot(                        "41a87fc8-2505-450c-be1a-7c48472d40be",                        [{"text":[0.004808881998542347,0.13514228100029868,0.27555392800059053],"textposition":"auto","width":0.5,"x":["Linear Regression","XGBRegressor","CatBoostRegressor"],"y":[0.004808881998542347,0.13514228100029868,0.27555392800059053],"type":"bar"}],                        {"template":{"data":{"bar":[{"error_x":{"color":"#2a3f5f"},"error_y":{"color":"#2a3f5f"},"marker":{"line":{"color":"#E5ECF6","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"bar"}],"barpolar":[{"marker":{"line":{"color":"#E5ECF6","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"barpolar"}],"carpet":[{"aaxis":{"endlinecolor":"#2a3f5f","gridcolor":"white","linecolor":"white","minorgridcolor":"white","startlinecolor":"#2a3f5f"},"baxis":{"endlinecolor":"#2a3f5f","gridcolor":"white","linecolor":"white","minorgridcolor":"white","startlinecolor":"#2a3f5f"},"type":"carpet"}],"choropleth":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"choropleth"}],"contour":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"contour"}],"contourcarpet":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"contourcarpet"}],"heatmap":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"heatmap"}],"heatmapgl":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"heatmapgl"}],"histogram":[{"marker":{"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"histogram"}],"histogram2d":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"histogram2d"}],"histogram2dcontour":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"histogram2dcontour"}],"mesh3d":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"mesh3d"}],"parcoords":[{"line":{"colorbar":{"outlinewidth":0,"ticks":""}},"type":"parcoords"}],"pie":[{"automargin":true,"type":"pie"}],"scatter":[{"marker":{"colorbar":{"outlinewidth":0,"ticks":""}},"type":"scatter"}],"scatter3d":[{"line":{"colorbar":{"outlinewidth":0,"ticks":""}},"marker":{"colorbar":{"outlinewidth":0,"ticks":""}},"type":"scatte ...

# %% [markdown]
# <a style='text-decoration:none;line-height:16px;display:flex;color:#5B5B62;padding:10px;justify-content:end;' href='https://deepnote.com?utm_source=created-in-deepnote-cell&projectId=cbe598bf-8a86-49e0-9eca-c75439d09668' target="_blank">
# <img alt='Created in deepnote.com' style='display:inline;max-height:16px;margin:0px;margin-right:7.5px;' src='data:image/svg+xml;base64,...' > </img>
# Created in <span style='font-weight:600;margin-left:4px;'>Deepnote</span></a>
